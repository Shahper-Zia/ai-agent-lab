# %% [markdown]
# # Exploring Tools in LangChain

# %% [markdown]
# ## Exploring Built-in Tools

# %% [markdown]
# ### Exploring the Wikipedia Tool
#
# Enables you to tap into the Wikipedia API to search wikipedia pages for information

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

wiki_api_wrapper = WikipediaAPIWrapper(top_k_results=3,
                                       doc_content_chars_max=8000)
wiki_tool = WikipediaQueryRun(api_wrapper=wiki_api_wrapper, features="lxml")

# %%
wiki_tool.description
# Out:
# 'A wrapper around Wikipedia. Useful for when you need to answer general questions about people, places, companies, facts, historical events, or other subjects. Input should be a search query.'

# %%
wiki_tool.args
# Out:
# {'query': {'description': 'query to look up on wikipedia',
#   'title': 'Query',
#   'type': 'string'}}

# %%
print(wiki_tool.invoke({"query": "Microsoft"}))
# Out:
# Page: Microsoft
# Summary: Microsoft Corporation is an American multinational technology conglomerate headquartered in Redmond, Washington. Founded in 1975, the company became influential in the rise of personal computers through software like Windows, and has since expanded to Internet services, cloud computing, artificial intelligence, video gaming, and other fields. Often described as a Big Tech company, Microsoft is the largest software company by revenue, one of the most valuable public companies, and one of the most valuable brands globally.
# Founded by Bill Gates and Paul Allen to market BASIC interpreters for the Altair 8800, Microsoft rose to dominate the personal computer operating system market with MS-DOS in the mid-1980s, followed by Windows. During the 41 years from 1980 to 2021 Microsoft released 9 versions of MS-DOS with a median frequency of 2 years, and 13 versions of Windows with a median frequency of 3 years. The company's 1986 initial public offering (IPO) and subsequent rise in its share price created three billionaires and an estimated 12,000 millionaires among Microsoft employees. Since the 1990s, it has increasingly diversified from the operating system market. Steve Ballmer replaced Gates as CEO in 2000. He oversaw the then-largest of Microsoft's corporate acquisitions in Skype Technologies in 2011, an increased focus on hardware that led to its first in-house PC line, the Surface, in 2012, and the formation of Microsoft Mobile through Nokia. Since Satya Nadella took over as CEO in 2014, the company has changed focus towards cloud computing, as well as its acquisition of LinkedIn for $26.2 billion in 2016. Under Nadella's direction, the company has expanded its video gaming business to support the Xbox brand, establishing the Microsoft Gaming division in 2022 and the acquisition of Activision Blizzard for $68.7 billion in 2023.
# Microsoft has been dominant in the IBM PC–compatible operating system market and the office software suite market since the 1990s. Its best-known software products are the Windows line of operating systems and the Microsoft Office and Microsoft 365 suite of productivity applications, which most notably include the Word word processor, Excel spreadsheet editor, and the PowerPoint presentation program. Its flagship hardware products are the Surface lineup of personal computers and Xbox video game consoles, the latter of which includes the Xbox network; the company also provides a range of consumer Internet services such as Bing web search, the MSN web portal, the Outlook.com (Hotmail) email service and the Microsoft Store. In the enterprise and development fields, Microsoft most notably provides the Azure cloud computing platform, Microsoft SQL Server database software, and Visual Studio.
# In April 2019, Microsoft became the third public U.S. company to be valued at over $1 trillion. It has been criticized for its monopolistic practices, and the company's software received criticism for problems with ease of use, robustness, and security. More recently, it has been criticized for its role in providing services to Israel during the Gaza war.
#
# Page: Microsoft Windows
# Summary: Microsoft Windows is a proprietary graphical operating system developed and marketed by Microsoft.
# Windows is grouped into families that cater to particular sectors of the computing industry – Windows for personal computers, Windows Server for servers, and Windows IoT for embedded systems. Windows itself is further grouped into editions that cater to different users – Home for home users, Professional for advanced users, Education for schools, and Enterprise for corporations. Windows is sold both as a consumer retail product and to computer manufacturers, who bundle and distribute it with their systems.
# The first version of Windows, Windows 1.0, was released on November 20, 1985 as a graphical operating system shell for MS-DOS in response to growing interest in graphical user interfaces (GUIs). The name Windows is a reference to the windowing system in GUIs. The 1990 release of Windows 3.0 catapulted its market success and led to the launch of various other product families, including the (now-defunct) Windows Mobile, Windows Phone, and Windows CE/Embedded Compact.
# Windows is the most popular desktop operating system in the world, with a 72% market share as of October 2025, and the second-most popular operating system overall, behind Android. As of August 2025, Windows 11 is the most used desktop version of Windows, with a market share of 53%.
#
#
#
# Page: Microsoft Excel
# Summary: Microsoft Excel is a popular spreadsheet editor developed by Microsoft for Windows, macOS, Android, iOS and iPadOS. It features calculation or computation capabilities, graphing tools, pivot tables, and a macro programming language called Visual Basic for Applications (VBA).
# Excel forms part of the Microsoft 365 and Microsoft Office suites of software and has been developed since 1985.

# %%
print(wiki_tool.invoke({"query": "AI"}))
# Out:
# /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Page: Artificial intelligence
# Summary: Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
# High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore."
# Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, perception, and support for robotics. To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.
# Artificial intelligence was founded as an academic discipline in 1956, and the field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest vastly increased after 2012 when graphics processing units started being used to accelerate neural networks, and deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture. In the 2020s, an ongoing period of rapid progress in advanced generative AI became known as the AI boom. Generative AI's ability to create and modify content has led to several unintended consequences and harms. Ethical concerns have been raised about AI's long-term effects and potential existential risks, prompting discussions about regulatory policies to ensure the safety and benefits of the technology.
#
#
#
# Page: .ai
# Summary: .ai is the Internet country code top-level domain (ccTLD) for Anguilla, a British Overseas Territory in the Caribbean. It is administered by the government of Anguilla.
# It is a popular domain hack with companies and projects related to the artificial intelligence industry (AI).
# Google's ad targeting treats .ai as a generic top-level domain (gTLD) because "users and website owners frequently see [the domain] as being more generic than country-targeted."
# In 2021, Google Search analyst Gary Illyes announced that ".ai" had been added to Google’s list of generic country-code top-level domains, meaning that Google would no longer infer Anguilla-specific targeting from the ccTLD.
# Identity Digital began managing the domain as of January 2025.

# %%
from IPython.display import display, Markdown

display(Markdown(wiki_tool.run("Artificial Intelligence")))
# Out:
# Page: Artificial intelligence
# Summary: Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
# High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore."
# Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, perception, and support for robotics. To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Some companies, such as OpenAI, Google DeepMind and Meta, aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.
# Artificial intelligence was founded as an academic discipline in 1956, and the field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest vastly increased after 2012 when graphics processing units started being used to accelerate neural networks, and deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture. In the 2020s, an ongoing period of rapid progress in advanced generative AI became known as the AI boom. Generative AI's ability to create and modify content has led to several unintended consequences and harms. Ethical concerns have been raised about AI's long-term effects and potential existential risks, prompting discussions about regulatory policies to ensure the safety and benefits of the technology.
#
#
#
# Page: Artificial general intelligence
# Summary: Artificial general intelligence (AGI)—sometimes called human‑level AI—is a type of artificial intelligence that would match or surpass human capabilities across virtually all cognitive tasks.
# Beyond AGI, artificial superintelligence (ASI) would outperform the best human abilities across every domain by a wide margin. Unlike artificial narrow intelligence (ANI), whose competence is confined to well‑defined tasks, an AGI system can generalise knowledge, transfer skills between domains, and solve novel problems without task‑specific reprogramming. The concept does not, in principle, require the system to be an autonomous agent; a static model—such as a highly capable large language model—or an embodied robot could both satisfy the definition so long as human‑level breadth and proficiency are achieved.
# Creating AGI is a stated goal of AI technology companies such as OpenAI, Google, xAI, and Meta. A 2020 survey identified 72 active AGI research and development projects across 37 countries.
# AGI is a common topic in science fiction and futures studies.
# Contention exists over whether AGI represents an existential risk. Some AI experts and industry figures have stated that mitigating the risk of human extinction posed by AGI should be a global priority. Others find the development of AGI to be in too remote a stage to present such a risk.
#
#
#
# Page: History of artificial intelligence
# Summary: The history of artificial intelligence (AI) began in antiquity, with myths, stories, and rumors of artificial beings endowed with intelligence or consciousness by master craftsmen. The study of logic and formal reasoning from antiquity to the present led directly to the invention of the programmable digital computer in the 1940s, a machine based on abstract mathematical reasoning. This device and the ideas behind it inspired scientists to begin discussing the possibility of building an electronic brain.
# The field of AI research was founded at a workshop held on the campus of Dartmouth College in 1956. Attendees of the workshop became the leaders of AI research for decades. Many of them predicted that machines as intelligent as humans would exist within a generation. The U.S. government provided millions of dollars with the hope of making this vision come true.
# Eventually, it became obvious that researchers had grossly underestimated the difficulty of this feat. In 1974, criticism from James Lighthill and pressure from the U.S. Congress led the U.S. and British Governments to stop funding undirected research into artificial intelligence. Seven years later, a visionary initiative by the Japanese Government and the success of expert systems  reinvigorated investment in AI, and by the late 1980s, the industry had grown into a billion-dollar enterprise. However, investors' enthusiasm waned in the 1990s, and the field was criticized in the press and avoided by industry (a period known as an "AI winter"). Nevertheless, research and funding continued to grow under other names.
# In the early 2000s, machine learning was applied to a wide range of problems in academia and industry. The success was due to the availability of powerful computer hardware, the collection of immense data sets, and the application of solid mathematical methods. Soon after, deep learning proved to be a breakthrough technology, eclipsing all other methods. The transformer architecture debuted in 2017 and was used to produce impressive generative AI applications, amongst other use cases.
# Investment in AI boomed in the 2020s. The recent AI boom, initiated by the development of transformer architecture, led to the rapid scaling and public releases of large language models (LLMs) like ChatGPT. These models exhibit human-like traits of knowledge, attention, and creativity, and have been integrated into various sectors, fueling exponential investment in AI. However, concerns about the potential risks and ethical implications of advanced AI have also emerged, causing debate about the future of AI and its impact on society.

# %% [markdown]
# You can customize the default tool with its own name, description and so on as follows

# %%
from langchain.agents import Tool

wiki_tool_init = Tool(name="Wikipedia",
                      func=wiki_api_wrapper.run,
                      description="useful when you need a detailed answer about general knowledge")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain.tools import Tool
#       3 wiki_tool_init = Tool(name="Wikipedia",
#       4                       func=wiki_api_wrapper.run,
#       5                       description="useful when you need a detailed answer about general knowledge")
#
# ImportError: cannot import name 'Tool' from 'langchain.tools' (/media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain/tools/__init__.py)

# %%
wiki_tool_init.description

# %%
wiki_tool_init.args

# %%
print(wiki_tool_init.invoke({"tool_input": "AI"}))

# %% [markdown]
# ### Exploring the Tavily Search Tool
#
# Tavily Search API is a search engine optimized for LLMs and RAG, aimed at efficient, quick and persistent search results

# %%
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_results=8,
                                search_depth='advanced',
                                include_raw_content=True)

# %%
tavily_tool.args
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic', 'advanced'], 'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" (default) for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %%
tavily_tool.description
# Out:
# 'A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.'

# %%
results = tavily_tool.invoke({"query": "Tell me about Microsoft"})
results
# Out:
# {'query': 'Tell me about Microsoft',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Microsoft',
#    'title': 'Microsoft - Wikipedia',
#    'content': "Microsoft Corporation is an American multinational technology conglomerate headquartered in Redmond, Washington. Founded in 1975, the company became influential in the rise of personal computers through software like Windows, and has since expanded to Internet services, cloud computing, artificial intelligence, video gaming, and other fields. Often described as a Big Tech company, Microsoft is the largest software company by revenue, one of the most valuable public companies,( and one of the [...] Microsoft has been dominant in the IBM PC–compatible operating system market and the office software suite market since the 1990s. Its best-known software products are the Windows line of operating systems and the Microsoft Office and Microsoft 365 suite of productivity applications, which most notably include the Word word processor, Excel spreadsheet editor, and the PowerPoint presentation program. Its flagship hardware products are the Surface lineup of personal computers and Xbox video game [...] Founded by Bill Gates and Paul Allen to market BASIC interpreters for the Altair 8800, Microsoft rose to dominate the personal computer operating system market with MS-DOS in the mid-1980s, followed by Windows. During the 41 years from 1980 to 2021 Microsoft released 9 versions of MS-DOS with a median frequency of 2 years, and 13 versions of Windows with a median frequency of 3 years. The company's 1986 initial public offering (IPO) and subsequent rise in its share price created three",
#    'score': 0.9992792,
#    'raw_content': 'Microsoft - Wikipedia\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Microsoft#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 1](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 2: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 3: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [f]")\n\nSearch\n\n- [x] Appearance \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Microsoft "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Microsoft "You\'re encouraged to log in; however, it\'s not mandatory. [o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Microsoft "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Microsoft "You\'re encouraged to log in; however, it\'s not mandatory. [o]")\n\nContents\n--------\n\nmove to sidebar hide\n\n*   [(Top)](https://en.wikipedia.org/wiki/Microsoft#)\n*   [1 History](https://en.wikipedia.org/wiki/Microsoft#History)Toggle History subsection\n    *   [1.1 1972–1985: Founding](https://en.wikipedia.org/wiki/Microsoft#1972%E2%80%931985:_Founding)\n\n    *   [1.2 1985–1994: Windows and Office](https://en.wikipedia.org/wiki/Microsoft#1985%E2%80%931994:_Windows_and_Office)\n\n    *   [1.3 1995–2007: Foray into the Web, Windows 95, Windows XP, and Xbox](https://en.wikipedia.org/wiki/Microsoft#1995%E2%80%932007:_Foray_into_the_Web,_Windows_95,_Windows_XP,_and_Xbox)\n\n    *   [1.4 2007–2011: Microsoft Azure, Windows Vista, Windows 7, and Microsoft Stores](https://en.wikipedia.org/wiki/Microsoft#2007%E2%80%932011:_Microsoft_Azure,_Windows_Vista,_Windows_7,_and_Microsoft_Stores)\n\n    *   [1.5 2011–2014: Windows 8/8.1, Xbox One, Outlook.com, and Surface devices](https://en.wikipedia.org/wiki/Microsoft#2011%E2%80%932014:_Windows_8/8.1,_Xbox_One,_Outlook.com,_and_Surface_devices)\n\n    *   [1.6 2014–2020: Windows 10, Microsoft Edge, and HoloLens](https://en. ...
#   {'url': 'https://www.britannica.com/money/Microsoft-Corporation',
#    'title': 'Microsoft Corporation | History, Software, Cloud, & AI Innovations',
#    'content': 'Microsoft Corporation is an American multinational technology company that has been a key player in the computer industry since its founding in 1975. Headquartered in Redmond, Washington, Microsoft initially gained dominance in the operating systems market during the 1980s and ’90s with MS-DOS and Windows. Its strong market position eventually gave rise to the company’s diverse and extensive range of technological offerings, from personal computing and entertainment to enterprise cloud [...] Microsoft operates research labs in Cambridge, England (1997); Beijing (1998); Bengaluru, India (2005); Cambridge, Massachusetts (2008); New York (2012); and Montreal (2015). Microsoft’s operations can be divided into three major business segments: productivity and business processes, intelligent cloud, and more personal computing. Each segment consists of several products and services.\n\n## Productivity and business processes [...] By the mid-1990s Microsoft, which became a publicly owned corporation in 1986, had become one of the most powerful brand names and profitable companies in American history. It consistently earned profits of 25 cents on every sales dollar, an astonishing record. In the company’s 1996 fiscal year, it topped $2 billion in net income for the first time, and its unbroken string of profits continued, even during the Great Recession of 2007–09 (its net income had grown to more than $14 billion by',
#    'score': 0.99719906,
#    'raw_content': "[History & Society](/History-Society)[Science & Tech](/Science-Tech)[Biographies](/Biographies)[Animals & Nature](/Animals-Nature)[Geography & Travel](/Geography-Travel)[Arts & Culture](/Arts-Culture)[ProCon](/procon)[Games & Quizzes](/quiz/browse)[Videos](/videos)[On This Day](/on-this-day)[One Good Fact](/one-good-fact)[Dictionary](/dictionary)\n\n* [Lifestyles & Social Issues](/browse/Lifestyles-Social-Issues)\n* [Philosophy & Religion](/browse/Philosophy-Religion)\n* [Politics, Law & Government](/browse/Politics-Law-Government)\n* [World History](/browse/World-History)\n\n* [Health & Medicine](/browse/Health-Medicine)\n* [Science](/browse/Science)\n* [Technology](/browse/Technology)\n\n* [Browse Biographies](/browse/biographies)\n\n* [Birds, Reptiles & Other Vertebrates](/browse/Birds-Reptiles-Vertebrates)\n* [Environment](/browse/Environment)\n* [Fossils & Geologic Time](/browse/Fossil-Geologic-Time)\n* [Insects & Other Invertebrates](/browse/Bugs-Mollusks-Invertebrates)\n* [Mammals](/browse/Mammals)\n* [Plants](/browse/Plants)\n\n* [Geography & Travel](/browse/Geography-Travel)\n\n* [Entertainment & Pop Culture](/browse/Entertainment-Pop-Culture)\n* [Literature](/browse/Literature)\n* [Sports & Recreation](/browse/Sports-Recreation)\n* [Visual Arts](/browse/Visual-Arts)\n\n[Image Galleries](/gallery/browse)[Infographics](https://www.britannica.com/study/infographics)[Podcasts](/podcasts)[Summaries](/summary)[Top Questions](/question)[Britannica Kids](https://kids.britannica.com/)\n\nTable of Contents\n\n---\n\n* [Productivity and business processes](/money/Microsoft-Corporation#ref374339)\n* [Intelligent cloud](/money/Microsoft-Corporation#ref374340)\n* [More personal computing](/money/Microsoft-Corporation#ref374341)\n* [Founding and early growth](/money/Microsoft-Corporation#ref288467)\n* [The price of success: Regulatory scrutiny](/money/Microsoft-Corporation#ref374342)\n* [Chasing the Internet and a return of regulatory woes](/money/Microsoft-Corporation#ref288468)\n* [Entry into the gaming and mobile phone markets](/money/Microsoft-Corporation#ref288469)\n* [Windows evolution: XP, Vista, and Windows 7 (and 8, 9, 10, and 11)](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288470)\n* [Competition with Google](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288471)\n* [Microsoft after Bill Gates](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288472)\n* [The Nadella years: Cloud innovation and the AI revolution](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref374343)\n* [References](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref380624-references)\n\nRead More\n\n[Bill Gates](/money/Bill-Gates)[Sun Microsystems](/money/Sun-Microsystems-Inc)[Netscape Communications Corp.](/money/Netscape-Communications-Corp)\n\n# Microsoft Corporation\n\nAmerican company\n\n**Written by**Gregg Pascal Zachary,\n\n[Gregg Pascal Zachary](/money/author/Gregg-Pascal-Zachary/4278)\n\nSenior Special Writer, *Wall Street Journal.* Author of *Showstopper: The Breakneck Race to Create Windows NT and the Next Generation at Microsoft.*\n\nMark Hall,\n\n[Mark Hall](/money/author/Mark-Hall/4349)\n\nCoauthor of *Sunburst: The Ascent of Sun Microsystems.*\n\nKarl Montevirgen\n\n[Karl Montevirgen](/money/author/karl-montevirgen/12874516)\n\nKarl Montevirgen is a professional freelance writer who specializes in the fields of finance, cryptomarkets, content strategy, and the arts. Karl works with several organizations in the equities, futures, physical metals, and blockchain industries. He holds FINRA Series 3 and Series 34 licenses in addition to a dual MFA in critical studies/writing and music composition from the California Institute of the Arts.\n\n**Fact-checked by**The Editors of Encyclopaedia Britannica\n\n[The Edit ...
#   {'url': 'https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company',
#    'title': 'A Brief History of Microsoft - The Worlds Biggest Software Company',
#    'content': 'Microsoft is an American multinational computer technology corporation whose history started 4th April 1975. Formed by Harvard College dropout, Bill Gates and his childhood friend Paul Allen, Microsoft has now become the biggest software company. It is also one of the most valuable companies in the world (before you read on you can find out more about our Microsoft Services here).\n\n### So how did Microsoft become so successful? [...] Microsoft is engaged in developing, licensing and supporting a range of software products and services catering to different requirements. In 2000 Steve Ballmer was appointed the new CEO of Microsoft. Bill Gates had met Steve Ballmer at Harvard University before he left. Although there was some concern over Ballmer’s ability, Microsoft retained its top spot in both business and personal computer markets. Microsoft’s primary strengths and most of its profits were obtained from the business side. [...] Microsoft before 1990 was predominantly a supplier to the hardware manufacturers. That was their target market. As technology advanced and personal computers become so popular, the bulk of Microsoft’s revenue was generated from sales to consumers. It was the first software company to reach $1 Billion in revenues. As more and more versions of Microsoft Windows were launched, Microsoft captured a higher market share of the world’s PC (around 90%).',
#    'score': 0.994089,
#    'raw_content': 'A Brief History of Microsoft - The Worlds Biggest Software Company\n\n===============\n\nWe have to collect some data while you use this website. These cookies are used to collect information about how you interact with our website and allow us to remember you. We need this to make the site work, to keep it secure, and to comply with regulations.\n\nWe\'d also like your consent to collect data while you use this website to help us; We use this information in order to improve and customise your browsing experience and for analytics and metrics about our visitors both on this website and other media. To find out more about the cookies we use, see our [Cookie Policy](https://www.dsp.co.uk/cookies-policy).\n\nSelect I accept if it\'s okay for us to use cookies. Select I do not accept if you would like to browse the site without cookies, apart from those categorised as strictly necessary including session cookies to remember your selection. You can also manage individual consents to control which types of cookies we use.\n\nIf you decline, your information won’t be tracked when you visit this website. A single cookie will be used in your browser to remember your preference not to be tracked.\n\n[Cookie Setting Options](javascript:void(0);)\n\n[Accept](javascript:void(0);)[Decline](javascript:void(0);)\n\n[![Image 1: DSP From Ground to Cloud](https://content.dsp.co.uk/hubfs/Logos/DSP%20From%20Ground%20to%20Cloud/DSP-Logo-Colour-From-Ground-to-Cloud.svg)](https://dsp.co.uk/)\n\n[![Image 2: DSP From Ground to Cloud](https://content.dsp.co.uk/hs-fs/hubfs/2023/Logos/DSP/DSP-Logo-2019-White-600px.png?width=70&height=72&name=DSP-Logo-2019-White-600px.png)](https://dsp.co.uk/)\n\n*   [About](https://www.dsp.co.uk/about) \n    *   [About DSP](https://www.dsp.co.uk/about)\n    *   [What We Do](https://www.dsp.co.uk/what-we-do)\n    *   [DSP Group Board](https://www.dsp.co.uk/dsp-group-board)\n    *   [Careers](https://www.dsp.co.uk/careers)\n\n![Image 3: Oracle Partner, Microsoft Partner and Google Partner](https://content.dsp.co.uk/hubfs/logo-2021/Partner-logos/multiple-vendor/rectangle-2022/Partner-logos-rectangle-Nov21.svg)\n\n#### Getting to know us\n\n    *   [About us](https://www.dsp.co.uk/about)\n    *   [What we do](https://www.dsp.co.uk/what-we-do)\n    *   [Leadership](https://www.dsp.co.uk/dsp-product-leads)\n    *   [Careers](https://www.dsp.co.uk/careers)\n\n*   [Services](https://www.dsp.co.uk/services) \n    *   [Managed Services](https://www.dsp.co.uk/database-managed-services) \n        *   [Oracle Managed Services](https://www.dsp.co.uk/oracle-managed-services)\n        *   [SQL Server Managed Services](https://www.dsp.co.uk/sql-server-managed-services)\n        *   [Google Managed Services](https://www.dsp.co.uk/google-cloud-consultancy)\n        *   [MySQL](https://www.dsp.co.uk/mysql-support)\n\n    *   [Application Services](https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company) \n        *   [Oracle Applications](https://www.dsp.co.uk/oracle-applications-services)\n        *   [Oracle APEX](https://www.dsp.co.uk/oracle-apex-services)\n        *   [API Development Services](https://www.dsp.co.uk/api-development-services)\n\n    *   [Cloud Services](https://www.dsp.co.uk/managed-cloud-services) \n        *   [Oracle Cloud Infrastructure](https://www.dsp.co.uk/oracle-cloud-services)\n        *   [Microsoft Azure](https://www.dsp.co.uk/microsoft-azure-services)\n        *   [Google Cloud Platform](https://www.dsp.co.uk/gcp-database)\n        *   [Multi-cloud](https://www.dsp.co.uk/oracle-microsoft-multicloud)\n\n    *   [Data Science](https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company) \n        *   [Machine Learning](https://www.dsp.co.uk/machine-learning-consulting-services)\n        *   [Business Intelligence](https://www.dsp.co.uk/business-intelligence-services)\n\n    *   [Consulting Services](https://content.dsp.co.uk/a-b ...
#   {'url': 'https://en.wikipedia.org/wiki/List_of_Microsoft_software',
#    'title': 'List of Microsoft software - Wikipedia',
#    'content': 'Microsoft is a developer "Developer (software)") of personal computer software. It is best known for its Windows operating system, the Internet Explorer and subsequent Microsoft Edge "Microsoft Edge (series of web browsers)") web browsers, the Microsoft Office family of productivity software plus services, and the Visual Studio IDE. The company also publishes books (through Microsoft Press) and video games (through Xbox Game Studios), and produces its own line of hardware. The following is a [...] Microsoft Office\n  + Microsoft Access\n  + Microsoft Designer\n  + Microsoft Excel\n  + Microsoft Lens (mobile)\n  + Microsoft OneNote\n  + Microsoft Outlook\n  + Microsoft PowerPoint\n  + Microsoft Project\n  + Microsoft Publisher\n  + Microsoft Sway\n  + Microsoft Visio\n  + Microsoft Word\n  + Office Mobile\n  + Office Remote (mobile)\n Microsoft Power Platform\n  + Microsoft Power BI\n  + Power Apps\n  + Power Automate\n  + Power Automate Desktop\n  + Power Virtual Agents\n Microsoft Dynamics',
#    'score': 0.9908035,
#    'raw_content': '[Jump to content](#bodyContent)\n\n[Search](/wiki/Special:Search "Search Wikipedia [f]")\n\n## Contents\n\n* [1 Software development](#Software_development)\n* [2 3D](#3D)\n* [3 Educational](#Educational)\n  + [3.1 Subscription services](#Subscription_services)\n* [4 Maintenance and administration](#Maintenance_and_administration)\n* [5 Operating systems](#Operating_systems)\n* [6 Productivity](#Productivity)\n  + [6.1 Applications](#Applications)\n  + [6.2 Suites](#Suites)\n    - [6.2.1 Microsoft Office](#Microsoft_Office)\n    - [6.2.2 Microsoft Office for Mac](#Microsoft_Office_for_Mac)\n* [7 Servers](#Servers)\n* [8 Video games](#Video_games)\n  + [8.1 Xbox Game Studios](#Xbox_Game_Studios)\n  + [8.2 Bethesda Softworks](#Bethesda_Softworks)\n  + [8.3 Included with Windows](#Included_with_Windows)\n  + [8.4 For PCs running Windows](#For_PCs_running_Windows)\n* [9 Web services](#Web_services)\n* [10 Windows components](#Windows_components)\n* [11 Miscellaneous](#Miscellaneous)\n* [12 See also](#See_also)\n* [13 References](#References)\n\n# List of Microsoft software\n\n* [العربية](https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D9%8A%D8%A7%D8%AA_%D9%85%D8%A7%D9%8A%D9%83%D8%B1%D9%88%D8%B3%D9%88%D9%81%D8%AA "قائمة برمجيات مايكروسوفت – Arabic")\n* [Deutsch](https://de.wikipedia.org/wiki/Produkte_von_Microsoft "Produkte von Microsoft – German")\n* [فارسی](https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D9%86%D8%B1%D9%85%E2%80%8C%D8%A7%D9%81%D8%B2%D8%A7%D8%B1%D9%87%D8%A7%DB%8C_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D8%AA "فهرست نرم\u200cافزارهای مایکروسافت – Persian")\n* [Français](https://fr.wikipedia.org/wiki/Liste_des_programmes_de_Microsoft "Liste des programmes de Microsoft – French")\n* [한국어](https://ko.wikipedia.org/wiki/%EB%A7%88%EC%9D%B4%ED%81%AC%EB%A1%9C%EC%86%8C%ED%94%84%ED%8A%B8_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_%EB%AA%A9%EB%A1%9D "마이크로소프트 소프트웨어 목록 – Korean")\n* [ქართული](https://ka.wikipedia.org/wiki/%E1%83%95%E1%83%98%E1%83%99%E1%83%98%E1%83%9E%E1%83%94%E1%83%93%E1%83%98%E1%83%90:%E1%83%9B%E1%83%90%E1%83%98%E1%83%99%E1%83%A0%E1%83%9D%E1%83%A1%E1%83%9D%E1%83%A4%E1%83%A2%E1%83%98/%E1%83%A1%E1%83%90%E1%83%99%E1%83%9D%E1%83%9C%E1%83%99%E1%83%A3%E1%83%A0%E1%83%A1%E1%83%9D/20131011181800/Microsoft-%E1%83%98%E1%83%A1_%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%A3%E1%83%9A%E1%83%98_%E1%83%A3%E1%83%96%E1%83%A0%E1%83%A3%E1%83%9C%E1%83%95%E1%83%94%E1%83%9A%E1%83%A7%E1%83%9D%E1%83%A4%E1%83%90 "ვიკიპედია:მაიკროსოფტი/საკონკურსო/20131011181800/Microsoft-ის პროგრამული უზრუნველყოფა – Georgian")\n* [Nederlands](https://nl.wikipedia.org/wiki/Lijst_van_Microsoft-software "Lijst van Microsoft-software – Dutch")\n* [日本語](https://ja.wikipedia.org/wiki/%E3%83%9E%E3%82%A4%E3%82%AF%E3%83%AD%E3%82%BD%E3%83%95%E3%83%88%E3%81%AE%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E4%B8%80%E8%A6%A7 "マイクロソフトのソフトウェア一覧 – Japanese")\n* [Suomi](https://fi.wikipedia.org/wiki/Luettelo_Microsoftin_tuotteista "Luettelo Microsoftin tuotteista – Finnish")\n* [Türkçe](https://tr.wikipedia.org/wiki/Microsoft_yaz%C4%B1l%C4%B1mlar%C4%B1_listesi "Microsoft yazılımları listesi – Turkish")\n* [Українська](https://uk.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BD%D0%B5_%D0%B7%D0%B0%D0%B1%D0%B5%D0%B7%D0%BF%D0%B5%D1%87%D0%B5%D0%BD%D0%BD%D1%8F_%D0%B2%D0%B8%D1%80%D0%BE%D0%B1%D0%BD%D0%B8%D1%86%D1%82%D0%B2%D0%B0_Microsoft "Програмне забезпечення виробництва Microsoft – Ukrainian")\n* [中文](https://zh.wikipedia.org/wiki/%E5%BE%AE%E8%BD%AF%E8%BD%AF%E4%BB%B6%E4%BA%A7%E5%93%81%E5%88%97%E8%A1%A8 "微软软件产品列表 – Chinese")\n\n[Edit links](https://www.wikidata.org/wiki/Special:EntityPage/Q1851989#sitelinks-wikipedia "Edit interlanguage links")\n\n* [Article](/wiki/List_of_Microsoft_software "View the content page [c]")\n* [Talk](/wiki/Talk:List_of_Microsoft_software "Discuss improvements to the content page [t]")\n\n* [Read](/wiki/List_ ...
#   {'url': 'https://news.microsoft.com/facts-about-microsoft/',
#    'title': 'Facts About Microsoft - Stories',
#    'content': 'Skip to Main Content\n\nMicrosoft \n\nSource\n\n0 Cart 0 items in shopping cart\n\n# Facts About Microsoft\n\nMicrosoft creates platforms and tools powered by AI to deliver innovative solutions that meet the evolving needs of our customers. The technology company is committed to making AI available broadly and doing so responsibly, with a mission to empower every person and every organization on the planet to achieve more. [...] Corporate Address  \n Important Dates  \n Board of Directors  \n Operation Centers  \n Microsoft Subsidiaries  \n Financial Data  \n Employment Information  \n Real Estate Portfolio\n\n## Corporate Address\n\nMicrosoft Corporation  \n One Microsoft Way  \n Redmond, WA 98052-7329  \n USA  \n Tel: (425) 882-8080  \n Fax: (425) 706-7329\n\nView Larger Map  |  Get Directions  |  View Bird’s Eye\n\n## Important Dates [...] | Feb. 29, 2024 | Microsoft Copilot for Finance introduced |\n| March 21, 2024 | Microsoft introduces Surface Pro 10 for Business and Surface Laptop 6 for Business |\n| May 20, 2024 | Microsoft introduces Copilot+ PCs |\n| Oct. 1, 2024 | Microsoft introduces Copilot Labs and Copilot Vision |\n| Feb. 19, 2025 | Microsoft introduces Majorana 1 chip carving new path for quantum computing |\n| April 4, 2025 | Microsoft celebrates 50th anniversary |',
#    'score': 0.9213576,
#    'raw_content': '[Skip to Main Content](#main-content)\n\n[Microsoft](https://www.microsoft.com) \n\n[Source](https://news.microsoft.com/source)\n\n[0 Cart 0 items in shopping cart](https://www.microsoft.com/en-us/store/cart)\n\n# Facts About Microsoft\n\nMicrosoft creates platforms and tools powered by AI to deliver innovative solutions that meet the evolving needs of our customers. The technology company is committed to making AI available broadly and doing so responsibly, with a mission to empower every person and every organization on the planet to achieve more.\n\n[Corporate Address](#CorporateAddress)  \n [Important Dates](#ImportantDates)  \n [Board of Directors](#BOD)  \n [Operation Centers](#OperationCenters)  \n [Microsoft Subsidiaries](#Subsidiaries)  \n [Financial Data](#FinancialData)  \n [Employment Information](#EmploymentInfo)  \n [Real Estate Portfolio](#RealEstate)\n\n## Corporate Address\n\nMicrosoft Corporation  \n One Microsoft Way  \n Redmond, WA 98052-7329  \n USA  \n Tel: (425) 882-8080  \n Fax: (425) 706-7329\n\n[http://www.microsoft.com](http://www.microsoft.com/)\n\n[View Larger Map](https://www.bing.com/maps/?cp=47.640049~-122.129797&sty=r&lvl=16&sp=&mm_embed=map)\xa0 |\xa0 [Get Directions](https://www.bing.com/maps/?cp=47.640049~-122.129797&sty=r&lvl=16&rtp=~pos.47.640049_-122.129797____&mm_embed=dir)\xa0 |\xa0 [View Bird’s Eye](https://www.bing.com/maps/?cp=ry606m4tp7yq&sty=b&lvl=18&sp=&mm_embed=be)\n\n## Important Dates\n\n| Date | Event |\n| --- | --- |\n| 1975 | Microsoft founded |\n| Jan. 1, 1979 | Microsoft moves from Albuquerque, New Mexico to Bellevue, Washington |\n| June 25, 1981 | Microsoft incorporates |\n| Aug. 12, 1981 | IBM introduces its personal computer with Microsoft’s 16-bit operating system, MS-DOS 1.0 |\n| Feb. 26, 1986 | Microsoft moves to corporate campus in Redmond, Washington |\n| March 13, 1986 | Microsoft stock goes public |\n| Aug. 1, 1989 | Microsoft introduces earliest version of Office suite of productivity applications |\n| May 22, 1990 | Microsoft launches Windows 3.0 |\n| Aug. 24, 1995 | Microsoft launches Windows 95 |\n| Dec. 7, 1995 | Bill Gates outlines Microsoft’s commitment to supporting and enhancing the Internet |\n| June 25, 1998 | Microsoft launches Windows 98 |\n| Jan. 13, 2000 | Steve Ballmer named president and chief executive officer for Microsoft |\n| Feb. 17, 2000 | Microsoft launches Windows 2000 |\n| June 22, 2000 | Bill Gates and Steve Ballmer outline Microsoft’s .NET strategy for Web services |\n| May 31, 2001 | Microsoft launches Office XP |\n| Oct. 25, 2001 | Microsoft launches Windows XP |\n| Nov. 15, 2001 | Microsoft launches Xbox |\n| Jan. 15, 2002 | Bill Gates outlines Microsoft’s commitment to Trustworthy Computing |\n| April 24, 2003 | Microsoft launches Windows Server 2003 |\n| Oct. 21, 2003 | Microsoft launches Microsoft Office System |\n| July 20, 2004 | Microsoft announces plans to return up to $75 billion to shareholders in dividends and stock buybacks |\n| Nov. 22, 2005 | Microsoft launches Xbox 360 |\n| July 20, 2006 | Microsoft announces a new US$20 billion tender offer and authorizes an additional share-repurchase program of up to $20 billion over five years |\n| Jan. 30, 2007 | Microsoft launches Windows Vista and the 2007 Microsoft Office System to consumers worldwide |\n| Feb. 27, 2008 | Microsoft launches Windows Server 2008, SQL Server 2008 and Visual Studio 2008 |\n| June 27, 2008 | Bill Gates transitions from his day-to-day role at Microsoft to spend more time on his work at The Bill & Melinda Gates Foundation |\n| June 3, 2009 | Microsoft launches Bing decision engine |\n| Oct. 22, 2009 | Microsoft launches Windows 7; opens first physical store in Scottsdale, Arizona |\n| June 15, 2010 | Microsoft launches general availability of Office 2010 |\n| Nov. 10, 2010 | Microsoft launches Windows Phone 7 |\n| Nov. 17, 2010 | Microsoft announces availability of Microsoft Lync |\n| June 28, 2011 | Microsoft launches Office 365 | ...
#   {'url': 'https://www.history.com/this-day-in-history/april-4/microsoft-founded',
#    'title': 'Microsoft founded | April 4, 1975 - History.com',
#    'content': 'On April 4, 1975, at a time when most Americans used typewriters, childhood friends Bill Gates and Paul Allen found Microsoft, a company that makes computer software. Originally based in Albuquerque, New Mexico, Microsoft relocated to Washington State in 1979 and eventually grew into a major multinational technology corporation. In 1987, the year after Microsoft went public, 31-year-old Gates became the world’s youngest billionaire. [...] In 1985, Microsoft released a new operating system, Windows, with a graphical user interface that included drop-down menus, scroll bars and other features. The following year, the company moved its headquarters to Redmond, Washington, and went public at $21 a share, raising $61 million. By the late 1980s, Microsoft had become the world’s biggest personal-computer software company, based on sales. In 1995, amidst skyrocketing purchases of personal computers for home and office use, Windows 95 [...] By the end of 1978, Microsoft’s sales topped more than $1 million and in 1979 the business moved its headquarters to Bellevue, Washington, a suburb of Seattle, where Gates and Allen grew up. The company went on to license its MS-DOS operating system to IBM for its first personal computer, which debuted in 1981. Afterward, other computer companies started licensing MS-DOS, which had no graphical interface and required users to type in commands in order to open a program. In 1983, Allen departed',
#    'score': 0.91789335,
#    'raw_content': 'April\n\n|  |  |  |  |  |  |  |\n| --- | --- | --- | --- | --- | --- | --- |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n\nBy: HISTORY.com Editors\n\n1975\n\n# Microsoft founded\n\n[HISTORY.com Editors](/authors/history)\n\nPublished: October 09, 2015Last Updated: May 28, 2025\n\nOn April 4, 1975, at a time when most Americans used typewriters, childhood friends [Bill Gates](https://www.biography.com/people/bill-gates-9307520) and Paul Allen found Microsoft, a company that makes computer software. Originally based in Albuquerque, [New Mexico](/topics/us-states/new-mexico), Microsoft relocated to [Washington](/topics/us-states/washington) State in 1979 and eventually grew into a major multinational technology corporation. In 1987, the year after Microsoft went public, 31-year-old Gates became the world’s youngest billionaire.\n\nGates and Allen started Microsoft—originally called Micro-Soft, for microprocessors and software—in order to produce software for the Altair 8800, an early personal computer. Allen quit his job as a programmer in Boston and Gates left Harvard University, where he was a student, to focus on their new company, which was based in Albuquerque because the city was home to electronics firm MITS, maker of the Altair 8800.\n\n### History Uncut: Bill Gates unveils Microsoft Excel 1987\n\nHistory Uncut The History Channel: 1987 - A young Gates, donned with oversized glasses that refuse to stay in place, answers questions from the press about his dazzling new software Microsoft Excel, which "really improves the quality of your output." This video clip is courtesy of The History Channel.\n\n1:27m watch\n\nBy the end of 1978, Microsoft’s sales topped more than $1 million and in 1979 the business moved its headquarters to Bellevue, Washington, a suburb of Seattle, where Gates and Allen grew up. The company went on to license its MS-DOS operating system to IBM for its first personal computer, which debuted in 1981. Afterward, other computer companies started licensing MS-DOS, which had no graphical interface and required users to type in commands in order to open a program. In 1983, Allen departed Microsoft after being diagnosed with Hodgkin’s lymphoma; he was successfully treated for the disease and went on to pursue a variety of other business ventures.\n\nIn 1985, Microsoft released a new operating system, Windows, with a graphical user interface that included drop-down menus, scroll bars and other features. The following year, the company moved its headquarters to Redmond, Washington, and went public at $21 a share, raising $61 million. By the late 1980s, Microsoft had become the world’s biggest personal-computer software company, based on sales. In 1995, amidst skyrocketing purchases of personal computers for home and office use, Windows 95 made its debut. It included such innovations as the Start menu (TV commercials for Windows 95 featured the Rolling Stones singing “Start Me Up”) and 7 million copies of the new product were sold in the first five weeks. During the second half of the 1990s, Internet usage took off, and Microsoft introduced its web browser, Internet Explorer, in 1995.\n\nIn 1998, the U.S. Department of Justice and 20 state attorneys general charged Microsoft with violating antitrust laws by using its dominance to drive competitors out of business; in 2001, the company reached a settlement with the government that imposed restrictions on its corporate practices. Also in 2001, Microsoft joined the videogame market with the [launch of its Xbox](https://www.history.com/this-day-in-history/microsoft-releases-xbox-gaming-console) console.\n\n## Timeline\n\n## Also on This Day in History\n\nDiscover more of the major events, famous births, notable deaths and everything else history-making that happened on April 4th\n\n[1776\n\n### General George Washington begins march to New York\n\nAfter the successful sie ...
#   {'url': 'https://en.wikipedia.org/wiki/History_of_Microsoft',
#    'title': 'History of Microsoft - Wikipedia',
#    'content': "As of June 30, 2015, Microsoft has a global annual revenue of US$86.83 billion (~$112 billion in 2024) and 128,076 employees worldwide. It develops, manufactures, licenses, and supports a wide range of software products for computing devices.\n\n## 1975–1985: The founding of Microsoft\n\n[edit] [...] > is widely recognized as the most influential company in the microcomputer-software industry. Claiming more than a million installed MS-DOS machines, founder and chairman Bill Gates has decided to certify Microsoft's jump on the rest of the industry by dominating applications, operating systems, peripherals and, most recently, book publishing. Some insiders say Microsoft is attempting to be the IBM of the software industry. [...] that offered operating system, programming language, and application software for the new computer.",
#    'score': 0.89982784,
#    'raw_content': '[Jump to content](#bodyContent)\n\n[Search](/wiki/Special:Search "Search Wikipedia [f]")\n\n## Contents\n\n* [1 1975–1985: The founding of Microsoft](#1975–1985:_The_founding_of_Microsoft)\n* [2 1985–1994: Windows and Office](#1985–1994:_Windows_and_Office)\n* [3 1995–2007: Foray into the Web, Windows 95, Windows XP, and Xbox](#1995–2007:_Foray_into_the_Web,_Windows_95,_Windows_XP,_and_Xbox)\n* [4 2007–2011: Microsoft Azure, Windows Vista, Windows 7, and Microsoft Stores](#2007–2011:_Microsoft_Azure,_Windows_Vista,_Windows_7,_and_Microsoft_Stores)\n* [5 2011–2014: Windows 8, Xbox One, Outlook.com, and Surface devices](#2011–2014:_Windows_8,_Xbox_One,_Outlook.com,_and_Surface_devices)\n* [6 2014–2020: Windows 10, Windows 10 Mobile, Microsoft Edge and HoloLens](#2014–2020:_Windows_10,_Windows_10_Mobile,_Microsoft_Edge_and_HoloLens)\n* [7 2020–present: Acquisitions, Xbox Series X/S, and Windows 11](#2020–present:_Acquisitions,_Xbox_Series_X/S,_and_Windows_11)\n* [8 See also](#See_also)\n* [9 References](#References)\n* [10 External links](#External_links)\n\n# History of Microsoft\n\n* [العربية](https://ar.wikipedia.org/wiki/%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE_%D8%B4%D8%B1%D9%83%D8%A9_%D9%85%D8%A7%D9%8A%D9%83%D8%B1%D9%88%D8%B3%D9%88%D9%81%D8%AA "تاريخ شركة مايكروسوفت – Arabic")\n* [বাংলা](https://bn.wikipedia.org/wiki/%E0%A6%AE%E0%A6%BE%E0%A6%87%E0%A6%95%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%B8%E0%A6%AB%E0%A6%9F%E0%A7%87%E0%A6%B0_%E0%A6%87%E0%A6%A4%E0%A6%BF%E0%A6%B9%E0%A6%BE%E0%A6%B8 "মাইক্রোসফটের ইতিহাস – Bangla")\n* [Español](https://es.wikipedia.org/wiki/Historia_de_Microsoft "Historia de Microsoft – Spanish")\n* [فارسی](https://fa.wikipedia.org/wiki/%D9%BE%DB%8C%D8%B4%DB%8C%D9%86%D9%87_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D8%AA "پیشینه مایکروسافت – Persian")\n* [日本語](https://ja.wikipedia.org/wiki/%E3%83%9E%E3%82%A4%E3%82%AF%E3%83%AD%E3%82%BD%E3%83%95%E3%83%88%E3%81%AE%E6%AD%B4%E5%8F%B2 "マイクロソフトの歴史 – Japanese")\n* [پښتو](https://ps.wikipedia.org/wiki/%D8%AF_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D9%BC_%D8%AA%D8%A7%D8%B1%DB%8C%D8%AE "د مایکروسافټ تاریخ – Pashto")\n* [Русский](https://ru.wikipedia.org/wiki/%D0%98%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%8F_Microsoft "История Microsoft – Russian")\n* [தமிழ்](https://ta.wikipedia.org/wiki/%E0%AE%AE%E0%AF%88%E0%AE%95%E0%AF%8D%E0%AE%B0%E0%AF%8B%E0%AE%9A%E0%AE%BE%E0%AE%AA%E0%AF%8D%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BF%E0%AE%A9%E0%AF%8D_%E0%AE%B5%E0%AE%B0%E0%AE%B2%E0%AE%BE%E0%AE%B1%E0%AF%81 "மைக்ரோசாப்ட்டின் வரலாறு – Tamil")\n* [Türkçe](https://tr.wikipedia.org/wiki/Microsoft%27un_tarihi "Microsoft\'un tarihi – Turkish")\n\n[Edit links](https://www.wikidata.org/wiki/Special:EntityPage/Q3273141#sitelinks-wikipedia "Edit interlanguage links")\n\n* [Article](/wiki/History_of_Microsoft "View the content page [c]")\n* [Talk](/wiki/Talk:History_of_Microsoft "Discuss improvements to the content page [t]")\n\n* [Read](/wiki/History_of_Microsoft)\n* [Edit](/w/index.php?title=History_of_Microsoft&action=edit "Edit this page [e]")\n* [View history](/w/index.php?title=History_of_Microsoft&action=history "Past revisions of this page [h]")\n\n\n\nTools\n\nActions\n\n* [Read](/wiki/History_of_Microsoft)\n* [Edit](/w/index.php?title=History_of_Microsoft&action=edit "Edit this page [e]")\n* [View history](/w/index.php?title=History_of_Microsoft&action=history)\n\nGeneral\n\n* [What links here](/wiki/Special:WhatLinksHere/History_of_Microsoft "List of all English Wikipedia pages containing links to this page [j]")\n* [Related changes](/wiki/Special:RecentChangesLinked/History_of_Microsoft "Recent changes in pages linked from this page [k]")\n* [Upload file](//en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard "Upload files [u]")\n* [Permanent link](/w/index.php?title=History_of_Microsoft&oldid=1329042500 "Permanent link to this revision of this page")\n* [Page information](/w/index.php?title=History_of_Microsoft&action=info "More information about this page")\n* [Cite t ...
#   {'url': 'https://www.microsoft.com/en-us/about',
#    'title': 'Our Mission and Values | About Microsoft',
#    'content': 'Careers\n   \nNews & Stories\n       Official Microsoft Blog\n       Microsoft on the Issues\n       Microsoft Source\n       Microsoft Unlocked\n\n   \nFacts & Information\n       Facts about Microsoft\n       Senior leadership\n       Investor relations\n       Reports Hub\n       US locations\n       Worldwide sales offices\n       Contact us\n\n   More \n\n   \nAll Microsoft\n       Global [...] Our Mission and Values | About Microsoft\n\n This is the Trace Id: 06106678a6e35b1b85175c275b91a7cd \n\nImage 1\n\n\n\nImage 2Microsoft\n\nAbout\n\nAbout\n\n About \n\n   Home\n   Our commitments\n   \nAI & Innovation\n       Microsoft AI\n       Microsoft Copilot\n       Microsoft Cloud\n       Microsoft Research\n       Products & apps\n\n   \nCulture\n       Work & Life\n       Diversity & inclusion\n       Alumni network [...] Azure\n   Microsoft Developer\n   Microsoft Learn\n   Support for AI marketplace apps\n   Microsoft Tech Community\n   Microsoft Marketplace\n   Marketplace Rewards\n   Visual Studio\n\nCompany\n\n   Careers\n   About Microsoft\n   Company news\n   Privacy at Microsoft\n   Investors\n   Diversity and inclusion\n   Accessibility\n   Sustainability',
#    'score': 0.86522406,
#    'raw_content': 'Our Mission and Values | About Microsoft\n===============\n This is the Trace Id: 06106678a6e35b1b85175c275b91a7cd \n\n![Image 1](https://www.microsoft.com/en-us/about)\n\n[](https://www.microsoft.com/en-us/about)\n\n[Skip to main content](javascript:void(0))\n\n[![Image 2](https://uhf.microsoft.com/images/microsoft/RE1Mu3b.png)Microsoft](https://www.microsoft.com/)\n\nAbout\n\n[About](https://www.microsoft.com/en-us/about)\n\n About \n\n*   [Home](https://www.microsoft.com/en-us/about)\n*   [Our commitments](https://www.microsoft.com/en-us/corporate-responsibility)\n*   \nAI & Innovation\n    *   [Microsoft AI](https://www.microsoft.com/ai)\n    *   [Microsoft Copilot](https://www.microsoft.com/en-us/microsoft-copilot/learn)\n    *   [Microsoft Cloud](https://www.microsoft.com/microsoft-cloud)\n    *   [Microsoft Research](https://www.microsoft.com/en-us/research)\n    *   [Products & apps](https://www.microsoft.com/microsoft-products-and-apps)\n\n*   \nCulture\n    *   [Work & Life](https://news.microsoft.com/source/topics/work-life)\n    *   [Diversity & inclusion](https://www.microsoft.com/en-us/diversity)\n    *   [Alumni network](https://www.microsoftalumni.com/)\n\n*   [Careers](https://careers.microsoft.com/)\n*   \nNews & Stories\n    *   [Official Microsoft Blog](https://blogs.microsoft.com/)\n    *   [Microsoft on the Issues](https://blogs.microsoft.com/on-the-issues)\n    *   [Microsoft Source](https://news.microsoft.com/source)\n    *   [Microsoft Unlocked](https://unlocked.microsoft.com/)\n\n*   \nFacts & Information\n    *   [Facts about Microsoft](https://news.microsoft.com/facts-about-microsoft)\n    *   [Senior leadership](https://news.microsoft.com/leadership)\n    *   [Investor relations](https://www.microsoft.com/investor)\n    *   [Reports Hub](https://www.microsoft.com/en-us/corporate-responsibility/reports-hub)\n    *   [US locations](https://www.microsoft.com/en-us/about/office-locations)\n    *   [Worldwide sales offices](https://www.microsoft.com/en-us/worldwide.aspx)\n    *   [Contact us](https://support.microsoft.com/contactus)\n\n*   More \n\n*   \nAll Microsoft\n    *   Global\n------\n\n        *   [Microsoft 365](https://www.microsoft.com/microsoft-365)\n        *   [Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)\n        *   [Copilot](https://copilot.microsoft.com/)\n        *   [Windows](https://www.microsoft.com/en-us/windows/)\n        *   [Surface](https://www.microsoft.com/surface)\n        *   [Xbox](https://www.xbox.com/)\n        *   [Deals](https://www.microsoft.com/en-us/store/b/sale?icid=DSM_TopNavDeals)\n        *   [Small Business](https://www.microsoft.com/en-us/store/b/business)\n        *   [Support](https://support.microsoft.com/en-us)\n\n    *   Software Software\n        *   [Windows Apps](https://apps.microsoft.com/home)\n        *   [AI](https://www.microsoft.com/en-us/ai)\n        *   [Outlook](https://www.microsoft.com/en-us/microsoft-365/outlook/email-and-calendar-software-microsoft-outlook)\n        *   [OneDrive](https://www.microsoft.com/en-us/microsoft-365/onedrive/online-cloud-storage)\n        *   [Microsoft Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)\n        *   [OneNote](https://www.microsoft.com/en-us/microsoft-365/onenote/digital-note-taking-app)\n        *   [Microsoft Edge](https://www.microsoft.com/edge)\n        *   [Moving from Skype to Teams](https://support.microsoft.com/en-us/office/moving-from-skype-to-microsoft-teams-free-3c0caa26-d9db-4179-bcb3-930ae2c87570?icid=DSM_All_Skype)\n\n    *   PCs & Devices PCs & Devices \n        *   [Computers](https://www.microsoft.com/en-us/store/b/pc?icid=CNavDevicesPC)\n        *   [Shop Xbox](https://www.microsoft.com/en-us/store/b/xbox?icid=CNavDevicesXbox)\n        *   [Accessories](https://www.microsoft.com/en-us/store/b/accessories?icid=CNavDevicesAccessories)\n        *   [VR & mixed reality](https://www.microsoft.com/en-us/store/ ...
#  'response_time': 1.21,
#  'request_id': 'c9441d9e-f3aa-446d-af94-442647479b73'}

# %%
results = tavily_tool.invoke("Tell me about Microsoft")
results['results']
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Microsoft',
#   'title': 'Microsoft - Wikipedia',
#   'content': "Microsoft Corporation is an American multinational technology conglomerate headquartered in Redmond, Washington. Founded in 1975, the company became influential in the rise of personal computers through software like Windows, and has since expanded to Internet services, cloud computing, artificial intelligence, video gaming, and other fields. Often described as a Big Tech company, Microsoft is the largest software company by revenue, one of the most valuable public companies,( and one of the [...] Microsoft has been dominant in the IBM PC–compatible operating system market and the office software suite market since the 1990s. Its best-known software products are the Windows line of operating systems and the Microsoft Office and Microsoft 365 suite of productivity applications, which most notably include the Word word processor, Excel spreadsheet editor, and the PowerPoint presentation program. Its flagship hardware products are the Surface lineup of personal computers and Xbox video game [...] Founded by Bill Gates and Paul Allen to market BASIC interpreters for the Altair 8800, Microsoft rose to dominate the personal computer operating system market with MS-DOS in the mid-1980s, followed by Windows. During the 41 years from 1980 to 2021 Microsoft released 9 versions of MS-DOS with a median frequency of 2 years, and 13 versions of Windows with a median frequency of 3 years. The company's 1986 initial public offering (IPO) and subsequent rise in its share price created three",
#   'score': 0.9992792,
#   'raw_content': 'Microsoft - Wikipedia\n===============\n[Jump to content](https://en.wikipedia.org/wiki/Microsoft#bodyContent)\n\n- [x] Main menu \n\nMain menu\n\nmove to sidebar hide\n\n Navigation \n\n*   [Main page](https://en.wikipedia.org/wiki/Main_Page "Visit the main page [z]")\n*   [Contents](https://en.wikipedia.org/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")\n*   [Current events](https://en.wikipedia.org/wiki/Portal:Current_events "Articles related to current events")\n*   [Random article](https://en.wikipedia.org/wiki/Special:Random "Visit a randomly selected article [x]")\n*   [About Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:About "Learn about Wikipedia and how it works")\n*   [Contact us](https://en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")\n\n Contribute \n\n*   [Help](https://en.wikipedia.org/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")\n*   [Learn to edit](https://en.wikipedia.org/wiki/Help:Introduction "Learn how to edit Wikipedia")\n*   [Community portal](https://en.wikipedia.org/wiki/Wikipedia:Community_portal "The hub for editors")\n*   [Recent changes](https://en.wikipedia.org/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")\n*   [Upload file](https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")\n*   [Special pages](https://en.wikipedia.org/wiki/Special:SpecialPages)\n\n[![Image 1](https://en.wikipedia.org/static/images/icons/wikipedia.png)![Image 2: Wikipedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg)![Image 3: The Free Encyclopedia](https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg)](https://en.wikipedia.org/wiki/Main_Page)\n\n[Search](https://en.wikipedia.org/wiki/Special:Search "Search Wikipedia [f]")\n\nSearch\n\n- [x] Appearance \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Microsoft "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Microsoft "You\'re encouraged to log in; however, it\'s not mandatory. [o]")\n\n- [x] Personal tools \n\n*   [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en)\n*   [Create account](https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Microsoft "You are encouraged to create an account and log in; however, it is not mandatory")\n*   [Log in](https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Microsoft "You\'re encouraged to log in; however, it\'s not mandatory. [o]")\n\nContents\n--------\n\nmove to sidebar hide\n\n*   [(Top)](https://en.wikipedia.org/wiki/Microsoft#)\n*   [1 History](https://en.wikipedia.org/wiki/Microsoft#History)Toggle History subsection\n    *   [1.1 1972–1985: Founding](https://en.wikipedia.org/wiki/Microsoft#1972%E2%80%931985:_Founding)\n\n    *   [1.2 1985–1994: Windows and Office](https://en.wikipedia.org/wiki/Microsoft#1985%E2%80%931994:_Windows_and_Office)\n\n    *   [1.3 1995–2007: Foray into the Web, Windows 95, Windows XP, and Xbox](https://en.wikipedia.org/wiki/Microsoft#1995%E2%80%932007:_Foray_into_the_Web,_Windows_95,_Windows_XP,_and_Xbox)\n\n    *   [1.4 2007–2011: Microsoft Azure, Windows Vista, Windows 7, and Microsoft Stores](https://en.wikipedia.org/wiki/Microsoft#2007%E2%80%932011:_Microsoft_Azure,_Windows_Vista,_Windows_7,_and_Microsoft_Stores)\n\n    *   [1.5 2011–2014: Windows 8/8.1, Xbox One, Outlook.com, and Surface devices](https://en.wikipedia.org/wiki/Microsoft#2011%E2%80%932014:_Windows_8/8.1,_Xbox_One,_Outlook.com,_and_Surface_devices)\n\n    *   [1.6 2014–2020: Windows 10, Microsoft Edge, and HoloLens](https://en.w ...
#  {'url': 'https://www.britannica.com/money/Microsoft-Corporation',
#   'title': 'Microsoft Corporation | History, Software, Cloud, & AI Innovations',
#   'content': 'Microsoft Corporation is an American multinational technology company that has been a key player in the computer industry since its founding in 1975. Headquartered in Redmond, Washington, Microsoft initially gained dominance in the operating systems market during the 1980s and ’90s with MS-DOS and Windows. Its strong market position eventually gave rise to the company’s diverse and extensive range of technological offerings, from personal computing and entertainment to enterprise cloud [...] Microsoft operates research labs in Cambridge, England (1997); Beijing (1998); Bengaluru, India (2005); Cambridge, Massachusetts (2008); New York (2012); and Montreal (2015). Microsoft’s operations can be divided into three major business segments: productivity and business processes, intelligent cloud, and more personal computing. Each segment consists of several products and services.\n\n## Productivity and business processes [...] By the mid-1990s Microsoft, which became a publicly owned corporation in 1986, had become one of the most powerful brand names and profitable companies in American history. It consistently earned profits of 25 cents on every sales dollar, an astonishing record. In the company’s 1996 fiscal year, it topped $2 billion in net income for the first time, and its unbroken string of profits continued, even during the Great Recession of 2007–09 (its net income had grown to more than $14 billion by',
#   'score': 0.99719906,
#   'raw_content': "[History & Society](/History-Society)[Science & Tech](/Science-Tech)[Biographies](/Biographies)[Animals & Nature](/Animals-Nature)[Geography & Travel](/Geography-Travel)[Arts & Culture](/Arts-Culture)[ProCon](/procon)[Games & Quizzes](/quiz/browse)[Videos](/videos)[On This Day](/on-this-day)[One Good Fact](/one-good-fact)[Dictionary](/dictionary)\n\n* [Lifestyles & Social Issues](/browse/Lifestyles-Social-Issues)\n* [Philosophy & Religion](/browse/Philosophy-Religion)\n* [Politics, Law & Government](/browse/Politics-Law-Government)\n* [World History](/browse/World-History)\n\n* [Health & Medicine](/browse/Health-Medicine)\n* [Science](/browse/Science)\n* [Technology](/browse/Technology)\n\n* [Browse Biographies](/browse/biographies)\n\n* [Birds, Reptiles & Other Vertebrates](/browse/Birds-Reptiles-Vertebrates)\n* [Environment](/browse/Environment)\n* [Fossils & Geologic Time](/browse/Fossil-Geologic-Time)\n* [Insects & Other Invertebrates](/browse/Bugs-Mollusks-Invertebrates)\n* [Mammals](/browse/Mammals)\n* [Plants](/browse/Plants)\n\n* [Geography & Travel](/browse/Geography-Travel)\n\n* [Entertainment & Pop Culture](/browse/Entertainment-Pop-Culture)\n* [Literature](/browse/Literature)\n* [Sports & Recreation](/browse/Sports-Recreation)\n* [Visual Arts](/browse/Visual-Arts)\n\n[Image Galleries](/gallery/browse)[Infographics](https://www.britannica.com/study/infographics)[Podcasts](/podcasts)[Summaries](/summary)[Top Questions](/question)[Britannica Kids](https://kids.britannica.com/)\n\nTable of Contents\n\n---\n\n* [Productivity and business processes](/money/Microsoft-Corporation#ref374339)\n* [Intelligent cloud](/money/Microsoft-Corporation#ref374340)\n* [More personal computing](/money/Microsoft-Corporation#ref374341)\n* [Founding and early growth](/money/Microsoft-Corporation#ref288467)\n* [The price of success: Regulatory scrutiny](/money/Microsoft-Corporation#ref374342)\n* [Chasing the Internet and a return of regulatory woes](/money/Microsoft-Corporation#ref288468)\n* [Entry into the gaming and mobile phone markets](/money/Microsoft-Corporation#ref288469)\n* [Windows evolution: XP, Vista, and Windows 7 (and 8, 9, 10, and 11)](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288470)\n* [Competition with Google](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288471)\n* [Microsoft after Bill Gates](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref288472)\n* [The Nadella years: Cloud innovation and the AI revolution](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref374343)\n* [References](/money/Microsoft-Corporation/Windows-evolution-XP-Vista-and-Windows-7-and-8-9-10-and-11#ref380624-references)\n\nRead More\n\n[Bill Gates](/money/Bill-Gates)[Sun Microsystems](/money/Sun-Microsystems-Inc)[Netscape Communications Corp.](/money/Netscape-Communications-Corp)\n\n# Microsoft Corporation\n\nAmerican company\n\n**Written by**Gregg Pascal Zachary,\n\n[Gregg Pascal Zachary](/money/author/Gregg-Pascal-Zachary/4278)\n\nSenior Special Writer, *Wall Street Journal.* Author of *Showstopper: The Breakneck Race to Create Windows NT and the Next Generation at Microsoft.*\n\nMark Hall,\n\n[Mark Hall](/money/author/Mark-Hall/4349)\n\nCoauthor of *Sunburst: The Ascent of Sun Microsystems.*\n\nKarl Montevirgen\n\n[Karl Montevirgen](/money/author/karl-montevirgen/12874516)\n\nKarl Montevirgen is a professional freelance writer who specializes in the fields of finance, cryptomarkets, content strategy, and the arts. Karl works with several organizations in the equities, futures, physical metals, and blockchain industries. He holds FINRA Series 3 and Series 34 licenses in addition to a dual MFA in critical studies/writing and music composition from the California Institute of the Arts.\n\n**Fact-checked by**The Editors of Encyclopaedia Britannica\n\n[The Edito ...
#  {'url': 'https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company',
#   'title': 'A Brief History of Microsoft - The Worlds Biggest Software Company',
#   'content': 'Microsoft is an American multinational computer technology corporation whose history started 4th April 1975. Formed by Harvard College dropout, Bill Gates and his childhood friend Paul Allen, Microsoft has now become the biggest software company. It is also one of the most valuable companies in the world (before you read on you can find out more about our Microsoft Services here).\n\n### So how did Microsoft become so successful? [...] Microsoft is engaged in developing, licensing and supporting a range of software products and services catering to different requirements. In 2000 Steve Ballmer was appointed the new CEO of Microsoft. Bill Gates had met Steve Ballmer at Harvard University before he left. Although there was some concern over Ballmer’s ability, Microsoft retained its top spot in both business and personal computer markets. Microsoft’s primary strengths and most of its profits were obtained from the business side. [...] Microsoft before 1990 was predominantly a supplier to the hardware manufacturers. That was their target market. As technology advanced and personal computers become so popular, the bulk of Microsoft’s revenue was generated from sales to consumers. It was the first software company to reach $1 Billion in revenues. As more and more versions of Microsoft Windows were launched, Microsoft captured a higher market share of the world’s PC (around 90%).',
#   'score': 0.994089,
#   'raw_content': 'A Brief History of Microsoft - The Worlds Biggest Software Company\n\n===============\n\nWe have to collect some data while you use this website. These cookies are used to collect information about how you interact with our website and allow us to remember you. We need this to make the site work, to keep it secure, and to comply with regulations.\n\nWe\'d also like your consent to collect data while you use this website to help us; We use this information in order to improve and customise your browsing experience and for analytics and metrics about our visitors both on this website and other media. To find out more about the cookies we use, see our [Cookie Policy](https://www.dsp.co.uk/cookies-policy).\n\nSelect I accept if it\'s okay for us to use cookies. Select I do not accept if you would like to browse the site without cookies, apart from those categorised as strictly necessary including session cookies to remember your selection. You can also manage individual consents to control which types of cookies we use.\n\nIf you decline, your information won’t be tracked when you visit this website. A single cookie will be used in your browser to remember your preference not to be tracked.\n\n[Cookie Setting Options](javascript:void(0);)\n\n[Accept](javascript:void(0);)[Decline](javascript:void(0);)\n\n[![Image 1: DSP From Ground to Cloud](https://content.dsp.co.uk/hubfs/Logos/DSP%20From%20Ground%20to%20Cloud/DSP-Logo-Colour-From-Ground-to-Cloud.svg)](https://dsp.co.uk/)\n\n[![Image 2: DSP From Ground to Cloud](https://content.dsp.co.uk/hs-fs/hubfs/2023/Logos/DSP/DSP-Logo-2019-White-600px.png?width=70&height=72&name=DSP-Logo-2019-White-600px.png)](https://dsp.co.uk/)\n\n*   [About](https://www.dsp.co.uk/about) \n    *   [About DSP](https://www.dsp.co.uk/about)\n    *   [What We Do](https://www.dsp.co.uk/what-we-do)\n    *   [DSP Group Board](https://www.dsp.co.uk/dsp-group-board)\n    *   [Careers](https://www.dsp.co.uk/careers)\n\n![Image 3: Oracle Partner, Microsoft Partner and Google Partner](https://content.dsp.co.uk/hubfs/logo-2021/Partner-logos/multiple-vendor/rectangle-2022/Partner-logos-rectangle-Nov21.svg)\n\n#### Getting to know us\n\n    *   [About us](https://www.dsp.co.uk/about)\n    *   [What we do](https://www.dsp.co.uk/what-we-do)\n    *   [Leadership](https://www.dsp.co.uk/dsp-product-leads)\n    *   [Careers](https://www.dsp.co.uk/careers)\n\n*   [Services](https://www.dsp.co.uk/services) \n    *   [Managed Services](https://www.dsp.co.uk/database-managed-services) \n        *   [Oracle Managed Services](https://www.dsp.co.uk/oracle-managed-services)\n        *   [SQL Server Managed Services](https://www.dsp.co.uk/sql-server-managed-services)\n        *   [Google Managed Services](https://www.dsp.co.uk/google-cloud-consultancy)\n        *   [MySQL](https://www.dsp.co.uk/mysql-support)\n\n    *   [Application Services](https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company) \n        *   [Oracle Applications](https://www.dsp.co.uk/oracle-applications-services)\n        *   [Oracle APEX](https://www.dsp.co.uk/oracle-apex-services)\n        *   [API Development Services](https://www.dsp.co.uk/api-development-services)\n\n    *   [Cloud Services](https://www.dsp.co.uk/managed-cloud-services) \n        *   [Oracle Cloud Infrastructure](https://www.dsp.co.uk/oracle-cloud-services)\n        *   [Microsoft Azure](https://www.dsp.co.uk/microsoft-azure-services)\n        *   [Google Cloud Platform](https://www.dsp.co.uk/gcp-database)\n        *   [Multi-cloud](https://www.dsp.co.uk/oracle-microsoft-multicloud)\n\n    *   [Data Science](https://content.dsp.co.uk/a-brief-history-of-microsoft-the-worlds-biggest-software-company) \n        *   [Machine Learning](https://www.dsp.co.uk/machine-learning-consulting-services)\n        *   [Business Intelligence](https://www.dsp.co.uk/business-intelligence-services)\n\n    *   [Consulting Services](https://content.dsp.co.uk/a-br ...
#  {'url': 'https://en.wikipedia.org/wiki/List_of_Microsoft_software',
#   'title': 'List of Microsoft software - Wikipedia',
#   'content': 'Microsoft is a developer "Developer (software)") of personal computer software. It is best known for its Windows operating system, the Internet Explorer and subsequent Microsoft Edge "Microsoft Edge (series of web browsers)") web browsers, the Microsoft Office family of productivity software plus services, and the Visual Studio IDE. The company also publishes books (through Microsoft Press) and video games (through Xbox Game Studios), and produces its own line of hardware. The following is a [...] Microsoft Office\n  + Microsoft Access\n  + Microsoft Designer\n  + Microsoft Excel\n  + Microsoft Lens (mobile)\n  + Microsoft OneNote\n  + Microsoft Outlook\n  + Microsoft PowerPoint\n  + Microsoft Project\n  + Microsoft Publisher\n  + Microsoft Sway\n  + Microsoft Visio\n  + Microsoft Word\n  + Office Mobile\n  + Office Remote (mobile)\n Microsoft Power Platform\n  + Microsoft Power BI\n  + Power Apps\n  + Power Automate\n  + Power Automate Desktop\n  + Power Virtual Agents\n Microsoft Dynamics',
#   'score': 0.9908035,
#   'raw_content': '[Jump to content](#bodyContent)\n\n[Search](/wiki/Special:Search "Search Wikipedia [f]")\n\n## Contents\n\n* [1 Software development](#Software_development)\n* [2 3D](#3D)\n* [3 Educational](#Educational)\n  + [3.1 Subscription services](#Subscription_services)\n* [4 Maintenance and administration](#Maintenance_and_administration)\n* [5 Operating systems](#Operating_systems)\n* [6 Productivity](#Productivity)\n  + [6.1 Applications](#Applications)\n  + [6.2 Suites](#Suites)\n    - [6.2.1 Microsoft Office](#Microsoft_Office)\n    - [6.2.2 Microsoft Office for Mac](#Microsoft_Office_for_Mac)\n* [7 Servers](#Servers)\n* [8 Video games](#Video_games)\n  + [8.1 Xbox Game Studios](#Xbox_Game_Studios)\n  + [8.2 Bethesda Softworks](#Bethesda_Softworks)\n  + [8.3 Included with Windows](#Included_with_Windows)\n  + [8.4 For PCs running Windows](#For_PCs_running_Windows)\n* [9 Web services](#Web_services)\n* [10 Windows components](#Windows_components)\n* [11 Miscellaneous](#Miscellaneous)\n* [12 See also](#See_also)\n* [13 References](#References)\n\n# List of Microsoft software\n\n* [العربية](https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D9%8A%D8%A7%D8%AA_%D9%85%D8%A7%D9%8A%D9%83%D8%B1%D9%88%D8%B3%D9%88%D9%81%D8%AA "قائمة برمجيات مايكروسوفت – Arabic")\n* [Deutsch](https://de.wikipedia.org/wiki/Produkte_von_Microsoft "Produkte von Microsoft – German")\n* [فارسی](https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D9%86%D8%B1%D9%85%E2%80%8C%D8%A7%D9%81%D8%B2%D8%A7%D8%B1%D9%87%D8%A7%DB%8C_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D8%AA "فهرست نرم\u200cافزارهای مایکروسافت – Persian")\n* [Français](https://fr.wikipedia.org/wiki/Liste_des_programmes_de_Microsoft "Liste des programmes de Microsoft – French")\n* [한국어](https://ko.wikipedia.org/wiki/%EB%A7%88%EC%9D%B4%ED%81%AC%EB%A1%9C%EC%86%8C%ED%94%84%ED%8A%B8_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_%EB%AA%A9%EB%A1%9D "마이크로소프트 소프트웨어 목록 – Korean")\n* [ქართული](https://ka.wikipedia.org/wiki/%E1%83%95%E1%83%98%E1%83%99%E1%83%98%E1%83%9E%E1%83%94%E1%83%93%E1%83%98%E1%83%90:%E1%83%9B%E1%83%90%E1%83%98%E1%83%99%E1%83%A0%E1%83%9D%E1%83%A1%E1%83%9D%E1%83%A4%E1%83%A2%E1%83%98/%E1%83%A1%E1%83%90%E1%83%99%E1%83%9D%E1%83%9C%E1%83%99%E1%83%A3%E1%83%A0%E1%83%A1%E1%83%9D/20131011181800/Microsoft-%E1%83%98%E1%83%A1_%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%A3%E1%83%9A%E1%83%98_%E1%83%A3%E1%83%96%E1%83%A0%E1%83%A3%E1%83%9C%E1%83%95%E1%83%94%E1%83%9A%E1%83%A7%E1%83%9D%E1%83%A4%E1%83%90 "ვიკიპედია:მაიკროსოფტი/საკონკურსო/20131011181800/Microsoft-ის პროგრამული უზრუნველყოფა – Georgian")\n* [Nederlands](https://nl.wikipedia.org/wiki/Lijst_van_Microsoft-software "Lijst van Microsoft-software – Dutch")\n* [日本語](https://ja.wikipedia.org/wiki/%E3%83%9E%E3%82%A4%E3%82%AF%E3%83%AD%E3%82%BD%E3%83%95%E3%83%88%E3%81%AE%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E4%B8%80%E8%A6%A7 "マイクロソフトのソフトウェア一覧 – Japanese")\n* [Suomi](https://fi.wikipedia.org/wiki/Luettelo_Microsoftin_tuotteista "Luettelo Microsoftin tuotteista – Finnish")\n* [Türkçe](https://tr.wikipedia.org/wiki/Microsoft_yaz%C4%B1l%C4%B1mlar%C4%B1_listesi "Microsoft yazılımları listesi – Turkish")\n* [Українська](https://uk.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BD%D0%B5_%D0%B7%D0%B0%D0%B1%D0%B5%D0%B7%D0%BF%D0%B5%D1%87%D0%B5%D0%BD%D0%BD%D1%8F_%D0%B2%D0%B8%D1%80%D0%BE%D0%B1%D0%BD%D0%B8%D1%86%D1%82%D0%B2%D0%B0_Microsoft "Програмне забезпечення виробництва Microsoft – Ukrainian")\n* [中文](https://zh.wikipedia.org/wiki/%E5%BE%AE%E8%BD%AF%E8%BD%AF%E4%BB%B6%E4%BA%A7%E5%93%81%E5%88%97%E8%A1%A8 "微软软件产品列表 – Chinese")\n\n[Edit links](https://www.wikidata.org/wiki/Special:EntityPage/Q1851989#sitelinks-wikipedia "Edit interlanguage links")\n\n* [Article](/wiki/List_of_Microsoft_software "View the content page [c]")\n* [Talk](/wiki/Talk:List_of_Microsoft_software "Discuss improvements to the content page [t]")\n\n* [Read](/wiki/List_o ...
#  {'url': 'https://news.microsoft.com/facts-about-microsoft/',
#   'title': 'Facts About Microsoft - Stories',
#   'content': 'Skip to Main Content\n\nMicrosoft \n\nSource\n\n0 Cart 0 items in shopping cart\n\n# Facts About Microsoft\n\nMicrosoft creates platforms and tools powered by AI to deliver innovative solutions that meet the evolving needs of our customers. The technology company is committed to making AI available broadly and doing so responsibly, with a mission to empower every person and every organization on the planet to achieve more. [...] Corporate Address  \n Important Dates  \n Board of Directors  \n Operation Centers  \n Microsoft Subsidiaries  \n Financial Data  \n Employment Information  \n Real Estate Portfolio\n\n## Corporate Address\n\nMicrosoft Corporation  \n One Microsoft Way  \n Redmond, WA 98052-7329  \n USA  \n Tel: (425) 882-8080  \n Fax: (425) 706-7329\n\nView Larger Map  |  Get Directions  |  View Bird’s Eye\n\n## Important Dates [...] | Feb. 29, 2024 | Microsoft Copilot for Finance introduced |\n| March 21, 2024 | Microsoft introduces Surface Pro 10 for Business and Surface Laptop 6 for Business |\n| May 20, 2024 | Microsoft introduces Copilot+ PCs |\n| Oct. 1, 2024 | Microsoft introduces Copilot Labs and Copilot Vision |\n| Feb. 19, 2025 | Microsoft introduces Majorana 1 chip carving new path for quantum computing |\n| April 4, 2025 | Microsoft celebrates 50th anniversary |',
#   'score': 0.9213576,
#   'raw_content': '[Skip to Main Content](#main-content)\n\n[Microsoft](https://www.microsoft.com) \n\n[Source](https://news.microsoft.com/source)\n\n[0 Cart 0 items in shopping cart](https://www.microsoft.com/en-us/store/cart)\n\n# Facts About Microsoft\n\nMicrosoft creates platforms and tools powered by AI to deliver innovative solutions that meet the evolving needs of our customers. The technology company is committed to making AI available broadly and doing so responsibly, with a mission to empower every person and every organization on the planet to achieve more.\n\n[Corporate Address](#CorporateAddress)  \n [Important Dates](#ImportantDates)  \n [Board of Directors](#BOD)  \n [Operation Centers](#OperationCenters)  \n [Microsoft Subsidiaries](#Subsidiaries)  \n [Financial Data](#FinancialData)  \n [Employment Information](#EmploymentInfo)  \n [Real Estate Portfolio](#RealEstate)\n\n## Corporate Address\n\nMicrosoft Corporation  \n One Microsoft Way  \n Redmond, WA 98052-7329  \n USA  \n Tel: (425) 882-8080  \n Fax: (425) 706-7329\n\n[http://www.microsoft.com](http://www.microsoft.com/)\n\n[View Larger Map](https://www.bing.com/maps/?cp=47.640049~-122.129797&sty=r&lvl=16&sp=&mm_embed=map)\xa0 |\xa0 [Get Directions](https://www.bing.com/maps/?cp=47.640049~-122.129797&sty=r&lvl=16&rtp=~pos.47.640049_-122.129797____&mm_embed=dir)\xa0 |\xa0 [View Bird’s Eye](https://www.bing.com/maps/?cp=ry606m4tp7yq&sty=b&lvl=18&sp=&mm_embed=be)\n\n## Important Dates\n\n| Date | Event |\n| --- | --- |\n| 1975 | Microsoft founded |\n| Jan. 1, 1979 | Microsoft moves from Albuquerque, New Mexico to Bellevue, Washington |\n| June 25, 1981 | Microsoft incorporates |\n| Aug. 12, 1981 | IBM introduces its personal computer with Microsoft’s 16-bit operating system, MS-DOS 1.0 |\n| Feb. 26, 1986 | Microsoft moves to corporate campus in Redmond, Washington |\n| March 13, 1986 | Microsoft stock goes public |\n| Aug. 1, 1989 | Microsoft introduces earliest version of Office suite of productivity applications |\n| May 22, 1990 | Microsoft launches Windows 3.0 |\n| Aug. 24, 1995 | Microsoft launches Windows 95 |\n| Dec. 7, 1995 | Bill Gates outlines Microsoft’s commitment to supporting and enhancing the Internet |\n| June 25, 1998 | Microsoft launches Windows 98 |\n| Jan. 13, 2000 | Steve Ballmer named president and chief executive officer for Microsoft |\n| Feb. 17, 2000 | Microsoft launches Windows 2000 |\n| June 22, 2000 | Bill Gates and Steve Ballmer outline Microsoft’s .NET strategy for Web services |\n| May 31, 2001 | Microsoft launches Office XP |\n| Oct. 25, 2001 | Microsoft launches Windows XP |\n| Nov. 15, 2001 | Microsoft launches Xbox |\n| Jan. 15, 2002 | Bill Gates outlines Microsoft’s commitment to Trustworthy Computing |\n| April 24, 2003 | Microsoft launches Windows Server 2003 |\n| Oct. 21, 2003 | Microsoft launches Microsoft Office System |\n| July 20, 2004 | Microsoft announces plans to return up to $75 billion to shareholders in dividends and stock buybacks |\n| Nov. 22, 2005 | Microsoft launches Xbox 360 |\n| July 20, 2006 | Microsoft announces a new US$20 billion tender offer and authorizes an additional share-repurchase program of up to $20 billion over five years |\n| Jan. 30, 2007 | Microsoft launches Windows Vista and the 2007 Microsoft Office System to consumers worldwide |\n| Feb. 27, 2008 | Microsoft launches Windows Server 2008, SQL Server 2008 and Visual Studio 2008 |\n| June 27, 2008 | Bill Gates transitions from his day-to-day role at Microsoft to spend more time on his work at The Bill & Melinda Gates Foundation |\n| June 3, 2009 | Microsoft launches Bing decision engine |\n| Oct. 22, 2009 | Microsoft launches Windows 7; opens first physical store in Scottsdale, Arizona |\n| June 15, 2010 | Microsoft launches general availability of Office 2010 |\n| Nov. 10, 2010 | Microsoft launches Windows Phone 7 |\n| Nov. 17, 2010 | Microsoft announces availability of Microsoft Lync |\n| June 28, 2011 | Microsoft launches Office 365 |\ ...
#  {'url': 'https://www.history.com/this-day-in-history/april-4/microsoft-founded',
#   'title': 'Microsoft founded | April 4, 1975 - History.com',
#   'content': 'On April 4, 1975, at a time when most Americans used typewriters, childhood friends Bill Gates and Paul Allen found Microsoft, a company that makes computer software. Originally based in Albuquerque, New Mexico, Microsoft relocated to Washington State in 1979 and eventually grew into a major multinational technology corporation. In 1987, the year after Microsoft went public, 31-year-old Gates became the world’s youngest billionaire. [...] In 1985, Microsoft released a new operating system, Windows, with a graphical user interface that included drop-down menus, scroll bars and other features. The following year, the company moved its headquarters to Redmond, Washington, and went public at $21 a share, raising $61 million. By the late 1980s, Microsoft had become the world’s biggest personal-computer software company, based on sales. In 1995, amidst skyrocketing purchases of personal computers for home and office use, Windows 95 [...] By the end of 1978, Microsoft’s sales topped more than $1 million and in 1979 the business moved its headquarters to Bellevue, Washington, a suburb of Seattle, where Gates and Allen grew up. The company went on to license its MS-DOS operating system to IBM for its first personal computer, which debuted in 1981. Afterward, other computer companies started licensing MS-DOS, which had no graphical interface and required users to type in commands in order to open a program. In 1983, Allen departed',
#   'score': 0.91789335,
#   'raw_content': 'April\n\n|  |  |  |  |  |  |  |\n| --- | --- | --- | --- | --- | --- | --- |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n|  |  |  |  |  |  |  |\n\nBy: HISTORY.com Editors\n\n1975\n\n# Microsoft founded\n\n[HISTORY.com Editors](/authors/history)\n\nPublished: October 09, 2015Last Updated: May 28, 2025\n\nOn April 4, 1975, at a time when most Americans used typewriters, childhood friends [Bill Gates](https://www.biography.com/people/bill-gates-9307520) and Paul Allen found Microsoft, a company that makes computer software. Originally based in Albuquerque, [New Mexico](/topics/us-states/new-mexico), Microsoft relocated to [Washington](/topics/us-states/washington) State in 1979 and eventually grew into a major multinational technology corporation. In 1987, the year after Microsoft went public, 31-year-old Gates became the world’s youngest billionaire.\n\nGates and Allen started Microsoft—originally called Micro-Soft, for microprocessors and software—in order to produce software for the Altair 8800, an early personal computer. Allen quit his job as a programmer in Boston and Gates left Harvard University, where he was a student, to focus on their new company, which was based in Albuquerque because the city was home to electronics firm MITS, maker of the Altair 8800.\n\n### History Uncut: Bill Gates unveils Microsoft Excel 1987\n\nHistory Uncut The History Channel: 1987 - A young Gates, donned with oversized glasses that refuse to stay in place, answers questions from the press about his dazzling new software Microsoft Excel, which "really improves the quality of your output." This video clip is courtesy of The History Channel.\n\n1:27m watch\n\nBy the end of 1978, Microsoft’s sales topped more than $1 million and in 1979 the business moved its headquarters to Bellevue, Washington, a suburb of Seattle, where Gates and Allen grew up. The company went on to license its MS-DOS operating system to IBM for its first personal computer, which debuted in 1981. Afterward, other computer companies started licensing MS-DOS, which had no graphical interface and required users to type in commands in order to open a program. In 1983, Allen departed Microsoft after being diagnosed with Hodgkin’s lymphoma; he was successfully treated for the disease and went on to pursue a variety of other business ventures.\n\nIn 1985, Microsoft released a new operating system, Windows, with a graphical user interface that included drop-down menus, scroll bars and other features. The following year, the company moved its headquarters to Redmond, Washington, and went public at $21 a share, raising $61 million. By the late 1980s, Microsoft had become the world’s biggest personal-computer software company, based on sales. In 1995, amidst skyrocketing purchases of personal computers for home and office use, Windows 95 made its debut. It included such innovations as the Start menu (TV commercials for Windows 95 featured the Rolling Stones singing “Start Me Up”) and 7 million copies of the new product were sold in the first five weeks. During the second half of the 1990s, Internet usage took off, and Microsoft introduced its web browser, Internet Explorer, in 1995.\n\nIn 1998, the U.S. Department of Justice and 20 state attorneys general charged Microsoft with violating antitrust laws by using its dominance to drive competitors out of business; in 2001, the company reached a settlement with the government that imposed restrictions on its corporate practices. Also in 2001, Microsoft joined the videogame market with the [launch of its Xbox](https://www.history.com/this-day-in-history/microsoft-releases-xbox-gaming-console) console.\n\n## Timeline\n\n## Also on This Day in History\n\nDiscover more of the major events, famous births, notable deaths and everything else history-making that happened on April 4th\n\n[1776\n\n### General George Washington begins march to New York\n\nAfter the successful sieg ...
#  {'url': 'https://en.wikipedia.org/wiki/History_of_Microsoft',
#   'title': 'History of Microsoft - Wikipedia',
#   'content': "As of June 30, 2015, Microsoft has a global annual revenue of US$86.83 billion (~$112 billion in 2024) and 128,076 employees worldwide. It develops, manufactures, licenses, and supports a wide range of software products for computing devices.\n\n## 1975–1985: The founding of Microsoft\n\n[edit] [...] > is widely recognized as the most influential company in the microcomputer-software industry. Claiming more than a million installed MS-DOS machines, founder and chairman Bill Gates has decided to certify Microsoft's jump on the rest of the industry by dominating applications, operating systems, peripherals and, most recently, book publishing. Some insiders say Microsoft is attempting to be the IBM of the software industry. [...] that offered operating system, programming language, and application software for the new computer.",
#   'score': 0.89982784,
#   'raw_content': '[Jump to content](#bodyContent)\n\n[Search](/wiki/Special:Search "Search Wikipedia [f]")\n\n## Contents\n\n* [1 1975–1985: The founding of Microsoft](#1975–1985:_The_founding_of_Microsoft)\n* [2 1985–1994: Windows and Office](#1985–1994:_Windows_and_Office)\n* [3 1995–2007: Foray into the Web, Windows 95, Windows XP, and Xbox](#1995–2007:_Foray_into_the_Web,_Windows_95,_Windows_XP,_and_Xbox)\n* [4 2007–2011: Microsoft Azure, Windows Vista, Windows 7, and Microsoft Stores](#2007–2011:_Microsoft_Azure,_Windows_Vista,_Windows_7,_and_Microsoft_Stores)\n* [5 2011–2014: Windows 8, Xbox One, Outlook.com, and Surface devices](#2011–2014:_Windows_8,_Xbox_One,_Outlook.com,_and_Surface_devices)\n* [6 2014–2020: Windows 10, Windows 10 Mobile, Microsoft Edge and HoloLens](#2014–2020:_Windows_10,_Windows_10_Mobile,_Microsoft_Edge_and_HoloLens)\n* [7 2020–present: Acquisitions, Xbox Series X/S, and Windows 11](#2020–present:_Acquisitions,_Xbox_Series_X/S,_and_Windows_11)\n* [8 See also](#See_also)\n* [9 References](#References)\n* [10 External links](#External_links)\n\n# History of Microsoft\n\n* [العربية](https://ar.wikipedia.org/wiki/%D8%AA%D8%A7%D8%B1%D9%8A%D8%AE_%D8%B4%D8%B1%D9%83%D8%A9_%D9%85%D8%A7%D9%8A%D9%83%D8%B1%D9%88%D8%B3%D9%88%D9%81%D8%AA "تاريخ شركة مايكروسوفت – Arabic")\n* [বাংলা](https://bn.wikipedia.org/wiki/%E0%A6%AE%E0%A6%BE%E0%A6%87%E0%A6%95%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%B8%E0%A6%AB%E0%A6%9F%E0%A7%87%E0%A6%B0_%E0%A6%87%E0%A6%A4%E0%A6%BF%E0%A6%B9%E0%A6%BE%E0%A6%B8 "মাইক্রোসফটের ইতিহাস – Bangla")\n* [Español](https://es.wikipedia.org/wiki/Historia_de_Microsoft "Historia de Microsoft – Spanish")\n* [فارسی](https://fa.wikipedia.org/wiki/%D9%BE%DB%8C%D8%B4%DB%8C%D9%86%D9%87_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D8%AA "پیشینه مایکروسافت – Persian")\n* [日本語](https://ja.wikipedia.org/wiki/%E3%83%9E%E3%82%A4%E3%82%AF%E3%83%AD%E3%82%BD%E3%83%95%E3%83%88%E3%81%AE%E6%AD%B4%E5%8F%B2 "マイクロソフトの歴史 – Japanese")\n* [پښتو](https://ps.wikipedia.org/wiki/%D8%AF_%D9%85%D8%A7%DB%8C%DA%A9%D8%B1%D9%88%D8%B3%D8%A7%D9%81%D9%BC_%D8%AA%D8%A7%D8%B1%DB%8C%D8%AE "د مایکروسافټ تاریخ – Pashto")\n* [Русский](https://ru.wikipedia.org/wiki/%D0%98%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%8F_Microsoft "История Microsoft – Russian")\n* [தமிழ்](https://ta.wikipedia.org/wiki/%E0%AE%AE%E0%AF%88%E0%AE%95%E0%AF%8D%E0%AE%B0%E0%AF%8B%E0%AE%9A%E0%AE%BE%E0%AE%AA%E0%AF%8D%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%BF%E0%AE%A9%E0%AF%8D_%E0%AE%B5%E0%AE%B0%E0%AE%B2%E0%AE%BE%E0%AE%B1%E0%AF%81 "மைக்ரோசாப்ட்டின் வரலாறு – Tamil")\n* [Türkçe](https://tr.wikipedia.org/wiki/Microsoft%27un_tarihi "Microsoft\'un tarihi – Turkish")\n\n[Edit links](https://www.wikidata.org/wiki/Special:EntityPage/Q3273141#sitelinks-wikipedia "Edit interlanguage links")\n\n* [Article](/wiki/History_of_Microsoft "View the content page [c]")\n* [Talk](/wiki/Talk:History_of_Microsoft "Discuss improvements to the content page [t]")\n\n* [Read](/wiki/History_of_Microsoft)\n* [Edit](/w/index.php?title=History_of_Microsoft&action=edit "Edit this page [e]")\n* [View history](/w/index.php?title=History_of_Microsoft&action=history "Past revisions of this page [h]")\n\n\n\nTools\n\nActions\n\n* [Read](/wiki/History_of_Microsoft)\n* [Edit](/w/index.php?title=History_of_Microsoft&action=edit "Edit this page [e]")\n* [View history](/w/index.php?title=History_of_Microsoft&action=history)\n\nGeneral\n\n* [What links here](/wiki/Special:WhatLinksHere/History_of_Microsoft "List of all English Wikipedia pages containing links to this page [j]")\n* [Related changes](/wiki/Special:RecentChangesLinked/History_of_Microsoft "Recent changes in pages linked from this page [k]")\n* [Upload file](//en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard "Upload files [u]")\n* [Permanent link](/w/index.php?title=History_of_Microsoft&oldid=1329042500 "Permanent link to this revision of this page")\n* [Page information](/w/index.php?title=History_of_Microsoft&action=info "More information about this page")\n* [Cite th ...
#  {'url': 'https://www.microsoft.com/en-us/about',
#   'title': 'Our Mission and Values | About Microsoft',
#   'content': 'Careers\n   \nNews & Stories\n       Official Microsoft Blog\n       Microsoft on the Issues\n       Microsoft Source\n       Microsoft Unlocked\n\n   \nFacts & Information\n       Facts about Microsoft\n       Senior leadership\n       Investor relations\n       Reports Hub\n       US locations\n       Worldwide sales offices\n       Contact us\n\n   More \n\n   \nAll Microsoft\n       Global [...] Our Mission and Values | About Microsoft\n\n This is the Trace Id: 06106678a6e35b1b85175c275b91a7cd \n\nImage 1\n\n\n\nImage 2Microsoft\n\nAbout\n\nAbout\n\n About \n\n   Home\n   Our commitments\n   \nAI & Innovation\n       Microsoft AI\n       Microsoft Copilot\n       Microsoft Cloud\n       Microsoft Research\n       Products & apps\n\n   \nCulture\n       Work & Life\n       Diversity & inclusion\n       Alumni network [...] Azure\n   Microsoft Developer\n   Microsoft Learn\n   Support for AI marketplace apps\n   Microsoft Tech Community\n   Microsoft Marketplace\n   Marketplace Rewards\n   Visual Studio\n\nCompany\n\n   Careers\n   About Microsoft\n   Company news\n   Privacy at Microsoft\n   Investors\n   Diversity and inclusion\n   Accessibility\n   Sustainability',
#   'score': 0.86522406,
#   'raw_content': 'Our Mission and Values | About Microsoft\n===============\n This is the Trace Id: 06106678a6e35b1b85175c275b91a7cd \n\n![Image 1](https://www.microsoft.com/en-us/about)\n\n[](https://www.microsoft.com/en-us/about)\n\n[Skip to main content](javascript:void(0))\n\n[![Image 2](https://uhf.microsoft.com/images/microsoft/RE1Mu3b.png)Microsoft](https://www.microsoft.com/)\n\nAbout\n\n[About](https://www.microsoft.com/en-us/about)\n\n About \n\n*   [Home](https://www.microsoft.com/en-us/about)\n*   [Our commitments](https://www.microsoft.com/en-us/corporate-responsibility)\n*   \nAI & Innovation\n    *   [Microsoft AI](https://www.microsoft.com/ai)\n    *   [Microsoft Copilot](https://www.microsoft.com/en-us/microsoft-copilot/learn)\n    *   [Microsoft Cloud](https://www.microsoft.com/microsoft-cloud)\n    *   [Microsoft Research](https://www.microsoft.com/en-us/research)\n    *   [Products & apps](https://www.microsoft.com/microsoft-products-and-apps)\n\n*   \nCulture\n    *   [Work & Life](https://news.microsoft.com/source/topics/work-life)\n    *   [Diversity & inclusion](https://www.microsoft.com/en-us/diversity)\n    *   [Alumni network](https://www.microsoftalumni.com/)\n\n*   [Careers](https://careers.microsoft.com/)\n*   \nNews & Stories\n    *   [Official Microsoft Blog](https://blogs.microsoft.com/)\n    *   [Microsoft on the Issues](https://blogs.microsoft.com/on-the-issues)\n    *   [Microsoft Source](https://news.microsoft.com/source)\n    *   [Microsoft Unlocked](https://unlocked.microsoft.com/)\n\n*   \nFacts & Information\n    *   [Facts about Microsoft](https://news.microsoft.com/facts-about-microsoft)\n    *   [Senior leadership](https://news.microsoft.com/leadership)\n    *   [Investor relations](https://www.microsoft.com/investor)\n    *   [Reports Hub](https://www.microsoft.com/en-us/corporate-responsibility/reports-hub)\n    *   [US locations](https://www.microsoft.com/en-us/about/office-locations)\n    *   [Worldwide sales offices](https://www.microsoft.com/en-us/worldwide.aspx)\n    *   [Contact us](https://support.microsoft.com/contactus)\n\n*   More \n\n*   \nAll Microsoft\n    *   Global\n------\n\n        *   [Microsoft 365](https://www.microsoft.com/microsoft-365)\n        *   [Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)\n        *   [Copilot](https://copilot.microsoft.com/)\n        *   [Windows](https://www.microsoft.com/en-us/windows/)\n        *   [Surface](https://www.microsoft.com/surface)\n        *   [Xbox](https://www.xbox.com/)\n        *   [Deals](https://www.microsoft.com/en-us/store/b/sale?icid=DSM_TopNavDeals)\n        *   [Small Business](https://www.microsoft.com/en-us/store/b/business)\n        *   [Support](https://support.microsoft.com/en-us)\n\n    *   Software Software\n        *   [Windows Apps](https://apps.microsoft.com/home)\n        *   [AI](https://www.microsoft.com/en-us/ai)\n        *   [Outlook](https://www.microsoft.com/en-us/microsoft-365/outlook/email-and-calendar-software-microsoft-outlook)\n        *   [OneDrive](https://www.microsoft.com/en-us/microsoft-365/onedrive/online-cloud-storage)\n        *   [Microsoft Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)\n        *   [OneNote](https://www.microsoft.com/en-us/microsoft-365/onenote/digital-note-taking-app)\n        *   [Microsoft Edge](https://www.microsoft.com/edge)\n        *   [Moving from Skype to Teams](https://support.microsoft.com/en-us/office/moving-from-skype-to-microsoft-teams-free-3c0caa26-d9db-4179-bcb3-930ae2c87570?icid=DSM_All_Skype)\n\n    *   PCs & Devices PCs & Devices \n        *   [Computers](https://www.microsoft.com/en-us/store/b/pc?icid=CNavDevicesPC)\n        *   [Shop Xbox](https://www.microsoft.com/en-us/store/b/xbox?icid=CNavDevicesXbox)\n        *   [Accessories](https://www.microsoft.com/en-us/store/b/accessories?icid=CNavDevicesAccessories)\n        *   [VR & mixed reality](https://www.microsoft.com/en-us/store/b ...

# %% [markdown]
# ## Build your own tools in LangChain
#
# Tools are interfaces that an agent, chain, or LLM can use to interact with the world. They combine a few things:
#
# - The name of the tool
# - A description of what the tool is
# - JSON schema of what the inputs to the tool are
# - The function to call
# - Whether the result of a tool should be returned directly to the user
#
# It is useful to have all this information because this information can be used to build action-taking systems! The name, description, and JSON schema can be used to prompt the LLM so it knows how to specify what action to take, and then the function to call is equivalent to taking that action.

# %% [markdown]
# ### Building a Simple Math Tool
# We will start by building a simple tool which does some basic math

# %%
from langchain.tools import tool

@tool
def multiply(a, b):
    """Multiply two numbers."""
    return a * b

# Let's inspect some of the attributes associated with the tool.
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# Multiply two numbers.
# {'a': {'title': 'A'}, 'b': {'title': 'B'}}

# %%
type(multiply)
# Out:
# langchain_core.tools.structured.StructuredTool

# %%
multiply.invoke({"a": 2, "b": 3})
# Out:
# 6

# %%
multiply.invoke({"a": 2.1, "b": 3.2})
# Out:
# 6.720000000000001

# %%
multiply.invoke({"a": 2, "b": 'abc'})
# Out:
# 'abcabc'

# %% [markdown]
# Let's now build a tool with data type enforcing

# %%
from pydantic import BaseModel, Field
from langchain_core.tools import StructuredTool

class CalculatorInput(BaseModel):
    a: float = Field(description="first number")
    b: float = Field(description="second number")


def multiply(a: float, b: float) -> float:
    """Multiply two numbers."""
    return a * b

# we could also use the @tool decorator from before
multiply = StructuredTool.from_function(
    func=multiply,
    name="multiply",
    description="use to multiply numbers",
    args_schema=CalculatorInput,
    return_direct=True
    )

# Let's inspect some of the attributes associated with the tool.
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# use to multiply numbers
# {'a': {'description': 'first number', 'title': 'A', 'type': 'number'}, 'b': {'description': 'second number', 'title': 'B', 'type': 'number'}}

# %%
multiply.invoke({"a": 2, "b": 3})
# Out:
# 6.0

# %%
# this code will error out as abc is not a floating point number
multiply.invoke({"a": 2, "b": 'abc'})
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[21], line 2
#       1 # this code will error out as abc is not a floating point number
# ----> 2 multiply.invoke({"a": 2, "b": 'abc'})
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:629, in BaseTool.invoke(self, input, config, **kwargs)
#     621 @override
#     622 def invoke(
#     623     self,
#    (...)
#     626     **kwargs: Any,
#     627 ) -> Any:
#     628     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 629     return self.run(tool_input, **kwargs)
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:981, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     979 if error_to_raise:
#     980     run_manager.on_tool_error(error_to_raise)
# --> 981     raise error_to_raise
#     982 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     983 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:940, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     938 child_config = patch_config(config, callbacks=run_manager.get_child())
#     939 with set_config_context(child_config) as context:
# --> 940     tool_args, tool_kwargs = self._to_args_and_kwargs(
#     941         tool_input, tool_call_id
#     942     )
#     943     if signature(self._run).parameters.get("run_manager"):
#     944         tool_kwargs |= {"run_manager": run_manager}
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:842, in BaseTool._to_args_and_kwargs(self, tool_input, tool_call_id)
#     834 if (
#     835     self.args_schema is not None
#     836     and isinstance(self.args_schema, type)
#    (...)
#     839 ):
#     840     # StructuredTool with no args
#     841     return (), {}
# --> 842 tool_input = self._parse_input(tool_input, tool_call_id)
#     843 # For backwards compatibility, if run_input is a string,
#     844 # pass as a positional argument.
#     845 if isinstance(tool_input, str):
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:698, in BaseTool._parse_input(self, tool_input, tool_call_id)
#     696                 raise ValueError(msg)
#     697             tool_input[k] = tool_call_id
# --> 698     result = input_args.model_validate(tool_input)
#     699     result_dict = result.model_dump()
#     700 elif issubclass(input_args, BaseModelV1):
#     701     # Check args_schema for InjectedToolCallId
#
# File /media/ultron.legacy/HDD/GitHub/ai-agent-lab/.venv/lib/python3.10/site-packages/pydantic/main.py:716, in BaseModel.model_validate(cls, obj, strict, extra, from_attributes, context, by_alias, by_name)
#     710 if by_alias is False and by_name is not True:
#     711     raise PydanticUserError(
#     712         'At least one of `by_alias` or `by_name` must be set to True.',
#     713         code='validate-by-alias-and-name-false',
#     714     )
# --> 716 return cls.__pydantic_validator__.validate_python(
#     717     obj,
#     718     strict=strict,
#     719     extra=extra,
#     720     from_attributes=from_attributes,
#     721     context=context,
#     722     by_alias=by_alias,
#     723     by_name=by_name,
#     724 )
#
# ValidationError: 1 validation error for CalculatorInput
# b
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='abc', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/float_parsing

# %% [markdown]
# ### Build a Web Search & Information Extraction Tool

# %%
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_results=5,
                                search_depth='advanced',
                                include_raw_content=True)

result = tavily_tool.invoke("Tell me about Microsoft's Q4 2024 earning call report")
result['results']
# Out:
# [{'url': 'https://www.kavout.com/market-lens/key-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials',
#   'title': "Key Takeaways From Microsoft's Q4 FY2024: Cloud Challenges ...",
#   'content': 'On July 30, 2024, Microsoft held its Q4 FY2024 earnings call, revealing a mix of robust financial performance and some areas of concern, particularly in its cloud segment. This report aims to provide a comprehensive analysis of the key takeaways from the earnings call, synthesizing information from various sources to offer a balanced and insightful perspective. The analysis will cover Microsoft’s financial performance, cloud growth, AI investments, and future outlook, considering the broader [...] Microsoft’s Q4 FY2024 earnings call highlighted a strong financial performance, driven by robust revenue growth across its segments. However, the underperformance of the cloud segment and AI capacity constraints raised concerns among investors, leading to a decline in share prices. Despite these challenges, Microsoft’s significant investments in AI and its strategic focus on innovation position the company for long-term growth. [...] ## Financial Performance\n\n### Earnings and Revenue\n\nMicrosoft reported better-than-expected earnings and revenue for Q4 FY2024. The company achieved an earnings per share (EPS) of $2.95, surpassing the consensus estimate of $2.93. Revenue for the quarter was $64.73 billion, exceeding the expected $64.39 billion and marking a 15% year-over-year increase. Net income rose to $22.04 billion, up from $20.08 billion in the same quarter last year.\n\n### Segment Performance',
#   'score': 0.9770949,
#   'raw_content': '[Log in](/user/login)\n\n[🎄 Holiday Sale\n\nClaim 40% OFF\n\n🎄 Holiday Sale\n\n40%OFF All Plans\n\nLast sale of 2025 - Ends January 4th\n\n40%OFF All Plans\n\nLast sale of 2025 - Ends January 4th\n\n00\n\nDays\n\n00\n\nHours\n\n00\n\nMins\n\n00\n\nDays\n\n00\n\nHours\n\n00\n\nMins\n\nClaim 40% OFF →](/holiday-sale)\n\n[Pricing Plans](/pricing-plans)[Sign Up](/user/register?next=%2Fmarket-lens%2Fkey-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials)[Log in](/user/login?next=%2Fmarket-lens%2Fkey-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials)\n\n[Stock Analysis](/market-lens/category/stock-analysis)\n\n# Key Takeaways From Microsoft’s Q4 FY2024: Cloud Challenges Amid Strong Financials\n\nJul 31, 2024\n\nSHARE THIS ON:\n\nOn July 30, 2024, Microsoft held its Q4 FY2024 earnings call, revealing a mix of robust financial performance and some areas of concern, particularly in its cloud segment. This report aims to provide a comprehensive analysis of the key takeaways from the earnings call, synthesizing information from various sources to offer a balanced and insightful perspective. The analysis will cover Microsoft’s financial performance, cloud growth, AI investments, and future outlook, considering the broader implications for stakeholders and potential future developments.\n\n## **Financial Performance**\n\n### **Earnings and Revenue**\n\nMicrosoft reported better-than-expected earnings and revenue for Q4 FY2024. The company achieved an earnings per share (EPS) of $2.95, surpassing the consensus estimate of $2.93. Revenue for the quarter was $64.73 billion, exceeding the expected $64.39 billion and marking a 15% year-over-year increase. Net income rose to $22.04 billion, up from $20.08 billion in the same quarter last year.\n\n### **Segment Performance**\n\n* **Productivity and Business Processes**: This segment, which includes Office and LinkedIn, generated $20.32 billion, up 11% year-over-year and above the $20.13 billion consensus.\n* **Intelligent Cloud**: Revenue grew 19% year-over-year to $28.52 billion, slightly below the expected $28.68 billion. Azure and other cloud services grew by 29%, falling short of the anticipated 31%.\n* **More Personal Computing**: This segment reported $15.90 billion in revenue, up 14% and exceeding the $15.49 billion consensus.\n\nDespite the overall positive financial performance, Microsoft’s shares fell by approximately 3% in extended trading, reflecting investor concerns over the cloud segment’s performance.\n\n## **Cloud Growth and AI Capacity Constraints**\n\n### **Cloud Growth Missed Estimates**\n\nOne of the most significant takeaways from the earnings call was the underperformance of Microsoft’s cloud segment. While the Intelligent Cloud revenue grew by 19%, it fell short of analyst expectations. Azure’s growth of 29% also missed the anticipated 31%, marking the first time Azure’s growth missed forecasts since 2022. CFO Amy Hood attributed this shortfall to capacity constraints related to AI and weakness in some European regions.\n\n### **AI Capacity Constraints**\n\nMicrosoft is experiencing a lag in AI-related capacity, which is expected to continue until the second half of\n\n1. This has affected cloud revenue, which came in at the lower end of previous guidance. The demand for Azure AI services exceeded available capacity, contributing to the softer-than-expected cloud growth.\n\n## **Investment in AI**\n\n### **Significant AI Investments**\n\nMicrosoft is significantly ramping up its investments in AI, with nearly all of its $19 billion in capital expenditures allocated to cloud and AI initiatives. Half of this spending is focused on building infrastructure and data centers to support long-term monetization. This strategic investment underscores Microsoft’s commitment to maintaining its competitive edge in the rapidly evolving AI landscape.\n\n### **AI-Driven Growth**\n\nAI has been a critical driver of growth ...
#  {'url': 'https://www.microsoft.com/en-us/investor/earnings/fy-2024-q4/performance',
#   'title': 'FY24 Q4 - Performance - Investor Relations - Microsoft',
#   'content': 'This is the Trace Id: 6f25020fed0c792ed0fee3e0a2e83ccc   \n\nMicrosoft \n\nInvestor Relations\n\nInvestor Relations\n\n# Earnings Release FY24 Q4\n\n## Performance\n\n  \n\n### Fiscal Year 2024 Compared with Fiscal Year 2023\n\nRevenue increased $33.2 billion or 16% driven by growth across each of our segments. Intelligent Cloud revenue increased driven by Azure. Productivity and Business Processes revenue increased driven by Office 365 Commercial. More Personal Computing revenue increased driven by Gaming. [...] Operating expenses increased $4.0 billion or 7% driven by Gaming, with 7 points of growth from the Activision Blizzard acquisition, and investments in cloud engineering, offset in part by the prior year Q2 charge.\n\nOperating income increased $20.9 billion or 24% driven by growth across each of our segments. [...] Cost of revenue increased $8.3 billion or 13% driven by growth in Microsoft Cloud and Gaming, offset in part by a decline in Devices.\n\nGross margin increased $25.0 billion or 17% driven by growth across each of our segments.\n\n•  Gross margin percentage increased slightly. Excluding the impact of the change in accounting estimate for the useful lives of our server and network equipment, gross margin percentage increased 2 points driven by improvement in More Personal Computing.',
#   'score': 0.95667076,
#   'raw_content': ' This is the Trace Id: 6f25020fed0c792ed0fee3e0a2e83ccc   \n\n[Microsoft](https://www.microsoft.com) \n\nInvestor Relations\n\n[Investor Relations](/en-us/Investor/default)\n\n# Earnings Release FY24 Q4\n\n## Performance\n\n  \n\n### Fiscal Year 2024 Compared with Fiscal Year 2023\n\nRevenue increased $33.2 billion or 16% driven by growth across each of our segments. Intelligent Cloud revenue increased driven by Azure. Productivity and Business Processes revenue increased driven by Office 365 Commercial. More Personal Computing revenue increased driven by Gaming.\n\nCost of revenue increased $8.3 billion or 13% driven by growth in Microsoft Cloud and Gaming, offset in part by a decline in Devices.\n\nGross margin increased $25.0 billion or 17% driven by growth across each of our segments.\n\n•  Gross margin percentage increased slightly. Excluding the impact of the change in accounting estimate for the useful lives of our server and network equipment, gross margin percentage increased 2 points driven by improvement in More Personal Computing.\n\n•  Microsoft Cloud gross margin percentage decreased slightly to 71%. Excluding the impact of the change in accounting estimate, Microsoft Cloud gross margin percentage increased slightly driven by improvements in Azure and Office 365 Commercial, inclusive of scaling our AI infrastructure, offset in part by sales mix shift to Azure.\n\nOperating expenses increased $4.0 billion or 7% driven by Gaming, with 7 points of growth from the Activision Blizzard acquisition, and investments in cloud engineering, offset in part by the prior year Q2 charge.\n\nOperating income increased $20.9 billion or 24% driven by growth across each of our segments.\n\nPrior year gross margin, operating income, net income, and diluted EPS were negatively impacted by the Q2 charge, which resulted in decreases of $152 million, $1.2 billion, $946 million, and $0.13, respectively.\n\n*IMPORTANT NOTICE TO USERS (summary only, [click here](https://www.microsoft.com/en-us/Investor/long-disclaimer) \xa0for full text of notice);*All information is unaudited unless otherwise noted or accompanied by an audit opinion and is subject to the more comprehensive information contained in our SEC reports and filings. We do not endorse third-party information. All information speaks as of the last fiscal quarter or year for which we have filed a Form 10-K or 10-Q, or for historical information the date or period expressly indicated in or with such information. We undertake no duty to update the information. Forward-looking statements are subject to risks and uncertainties described in our\xa0 [Forms 10-Q and 10-K.](https://www.microsoft.com/en-us/Investor/sec-filings)\n\n### Download Earnings Related Files\n\nInformation contained in these documents is current as of the earnings date, and not restated for new accounting standards\n\n- Earnings Call Slides\n- Earnings Call Transcript\n- Financial Statements\n- Outlook\n- Press Release\n- 10K\n- FY24Q4 Product Release List\n ASSET PACKAGE\n\n#### Earnings Release Pages\n\n* [Metrics](/en-us/investor/earnings/fy-2024-q4/metrics)\n\n* [Performance](/en-us/investor/earnings/fy-2024-q4/performance)\n\n* [Press Release & Webcast](/en-us/investor/earnings/fy-2024-q4/press-release-webcast)\n\n* [Financial Statements](/en-us/investor/earnings/fy-2024-q4/income-statements)\n\n* [Segment Results](/en-us/investor/earnings/fy-2024-q4/productivity-and-business-processes-performance)\n\n* [Customer & Partner Highlights](https://aka.ms/FY24Q4Blog)\n\n#### Related Information\n\n* [Webcast](/en-us/investor/events/fy-2024/earnings-fy-2024-q4)\n\n* [SEC Filings](/en-us/investor/sec-filings)\n\n* [XBRL](/en-us/investor/sec-filings?year=2024&filing=xbrl)\n\n## Microsoft Corp (MSFT)\n\n###### 2025 ANNUAL REPORT\n\n[VIEW ONLINE](https://www.microsoft.com/investor/reports/ar25/index.html)\n\n[DOWNLOAD NOW](https://www.microsoft.com/investor/reports/ar25/download-center/index.html)\n\nFol ...
#  {'url': 'https://www.microsoft.com/en-us/investor/events/fy-2024/earnings-fy-2024-q4',
#   'title': 'Microsoft Fiscal Year 2024 Fourth Quarter Earnings Conference Call',
#   'content': 'Thank you, Satya, and good afternoon everyone. This quarter, revenue was $64.7 billion, up 15% and 16% in constant currency. Earnings per share was $2.95 cents and increased 10% and 11% in constant currency.\n\nIn our largest quarter of the year, we again delivered double-digit top and bottom-line growth with continued share gains across many of our businesses and record commitments to our Microsoft Cloud platform. [...] Now to More Personal Computing. Revenue was $15.9 billion, increasing 14% and 15% in constant currency, with 12 points of net impact from the Activision acquisition. Results were above expectations driven by Windows commercial and Search.\n\nThe PC market was as expected and Windows OEM revenue increased 4% year-over-year. [...] And in Gaming, revenue increased 44% with 48 points of net impact from the Activision acquisition. Xbox content and services revenue increased 61%, slightly ahead of expectations, with 58 points of net impact from the Activision acquisition. Stronger-than-expected performance in first-party content was partially offset by third-party content performance. Xbox hardware revenue decreased 42% and 41% in constant currency.',
#   'score': 0.923268,
#   'raw_content': "Microsoft Fiscal Year 2024 Fourth Quarter Earnings Conference Call\n===============\n This is the Trace Id: 33e93cd9408e5fadc166082ac779d851 \n\n![Image 1](https://www.microsoft.com/en-us/investor/events/fy-2024/earnings-fy-2024-q4)\n\n[](https://www.microsoft.com/en-us/investor/events/fy-2024/earnings-fy-2024-q4)\n\n[Skip to main content](javascript:void(0))\n\n[![Image 2](https://uhf.microsoft.com/images/microsoft/RE1Mu3b.png)Microsoft](https://www.microsoft.com/)\n\nInvestor Relations\n\n[Investor Relations](https://www.microsoft.com/en-us/investor/default)\n\n Investor Relations \n\n*   [Home](https://www.microsoft.com/en-us/investor/default)\n*   \nEarnings & Financials\n    *   Earnings Releases Earnings Releases\n        *   [Press Release & Webcast](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/press-release-webcast)\n        *   [Financial Statements](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/income-statements)\n        *   [Performance](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/performance)\n        *   [Metrics](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/metrics)\n        *   [Segment Results](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/productivity-and-business-processes-performance)\n\n    *   Financial Statements Financial Statements\n        *   [Income Statements](https://www.microsoft.com/en-us/Investor/earnings/FY-2025-Q4/income-statements)\n        *   [Comprehensive Income](https://www.microsoft.com/en-us/investor/earnings/fy-2025-q4/comprehensive-income)\n        *   [Balance Sheets](https://www.microsoft.com/en-us/investor/earnings/fy-2025-q4/balance-sheets)\n        *   [Cash Flows](https://www.microsoft.com/en-us/investor/earnings/fy-2025-q4/cash-flows)\n        *   [Segment Revenue & Operating Income](https://www.microsoft.com/en-us/investor/earnings/fy-2025-q4/segment-revenues)\n\n*   \nBoard & ESG\n    *   [Overview](https://www.microsoft.com/en-us/Investor/corporate-governance/overview)\n    *   Corporate Governance Corporate Governance\n        *   [Overview](https://www.microsoft.com/en-us/Investor/corporate-governance/framework)\n        *   [Board of Directors](https://news.microsoft.com/leadership/board-members/)\n        *   [Board Committees](https://www.microsoft.com/en-us/Investor/corporate-governance/board-of-directors)\n        *   [Policies and Guidelines](https://www.microsoft.com/en-us/Investor/corporate-governance/policies)\n\n    *   [Environment](https://www.microsoft.com/en-us/corporate-responsibility/sustainability)\n    *   Social Social\n        *   [Overview](https://www.microsoft.com/en-us/corporate-responsibility)\n        *   [Responsible AI](https://www.microsoft.com/en-us/ai/responsible-ai?ef_id=_k_60dc31553aed12d2c21a573941cc3017_k_&OCID=AIDcmm1o1fzy5i_SEM__k_60dc31553aed12d2c21a573941cc3017_k_&msclkid=60dc31553aed12d2c21a573941cc3017)\n        *   [Privacy & Cybersecurity](https://www.microsoft.com/en-us/corporate-responsibility/privacy)\n        *   [Workplace & Culture](https://www.microsoft.com/en-us/corporate-responsibility/empowering-employees)\n        *   [Diversity & Inclusion](https://www.microsoft.com/en-us/diversity/default.aspx)\n        *   [Human Rights](https://www.microsoft.com/en-us/corporate-responsibility/human-rights)\n        *   [Responsible Sourcing](https://www.microsoft.com/en-us/corporate-responsibility/responsible-sourcing)\n\n    *   [ESG Reports Hub](https://www.microsoft.com/en-us/corporate-responsibility/reports-hub)\n    *   [Awards & Recognition](https://www.microsoft.com/en-us/corporate-responsibility/recognition)\n\n*   [Annual Reports](https://www.microsoft.com/en-us/Investor/annual-reports)\n*   [SEC Filings](https://www.microsoft.com/en-us/Investor/sec-filings)\n*   \nInvestor Information\n    *   [Information for Investors](https://www.microsoft.com/en-us/investor/investor-information)\n    *   [Annual Meeting](https://www.micro ...
#  {'url': 'https://www.microsoft.com/en-us/investor/earnings/fy-2024-q4/press-release-webcast',
#   'title': 'FY24 Q4 - Press Releases - Investor Relations - Microsoft',
#   'content': 'Microsoft Corp. today announced the following results for the fiscal year ended June 30, 2024, as compared to the corresponding period of last fiscal year:\n\n·        Revenue was $245.1 billion and increased 16% (up 15% in constant currency)\n\n·        Operating income was $109.4 billion and increased 24%, and increased 22% non-GAAP (up 21% in constant currency)\n\n·        Net income was $88.1 billion and increased 22%, and increased 20% non-GAAP [...] This is the Trace Id: 49ce0526db3cfac6aa475ffc61c7fa38   \n\nMicrosoft \n\nInvestor Relations\n\nInvestor Relations\n\n# Press Release & Webcast\n\n## Earnings Release FY24 Q4\n\nMicrosoft Cloud Strength Drives Fourth Quarter Results\n\nREDMOND, Wash. — July 30, 2024 —Microsoft Corp. today announced the following results for the quarter ended June 30, 2024, as compared to the corresponding period of last fiscal year:\n\n·        Revenue was $64.7 billion and increased 15% (up 16% in constant currency) [...] ·        Operating income was $27.9 billion and increased 15% (up 16% in constant currency)\n\n·        Net income was $22.0 billion and increased 10% (up 11% in constant currency)\n\n·        Diluted earnings per share was $2.95 and increased 10% (up 11% in constant currency)',
#   'score': 0.9205687,
#   'raw_content': ' This is the Trace Id: 49ce0526db3cfac6aa475ffc61c7fa38   \n\n[Microsoft](https://www.microsoft.com) \n\nInvestor Relations\n\n[Investor Relations](/en-us/Investor/default)\n\n# Press Release & Webcast\n\n## Earnings Release FY24 Q4\n\n**Microsoft Cloud Strength Drives Fourth Quarter Results**\n\n**REDMOND, Wash. — July 30, 2024 —**Microsoft Corp. today announced the following results for the quarter ended June 30, 2024, as compared to the corresponding period of last fiscal year:\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Revenue was $64.7 billion and increased 15% (up 16% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Operating income was $27.9 billion and increased 15% (up 16% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Net income was\xa0$22.0 billion and increased 10% (up 11%\xa0in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Diluted earnings per\xa0share\xa0was $2.95 and increased 10% (up 11% in\xa0constant currency)\n\n“Our strong performance this fiscal year speaks both to our innovation and to the trust customers continue to place in Microsoft," said Satya Nadella, chairman and chief executive officer of Microsoft. “As a platform company, we are focused on meeting the mission-critical needs of our customers across our at-scale platforms today, while also ensuring we lead the AI era.”\n\n“We closed out our fiscal year with a solid quarter, highlighted by record bookings and Microsoft Cloud quarterly revenue of $36.8 billion, up 21% (up 22% in constant currency) year-over-year,” said Amy Hood, executive vice president and chief financial officer of Microsoft.\n\n**Business Highlights**\n\nRevenue in Productivity and Business Processes was $20.3 billion and increased 11% (up 12% in constant currency), with the following business highlights:\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Office Commercial products and cloud services revenue increased 12% (up 13% in constant currency) driven by Office 365 Commercial revenue growth of 13% (up 14% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Office Consumer products and cloud services revenue increased 3% (up 4% in constant currency) and Microsoft 365 Consumer subscribers grew to 82.5\xa0million\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0LinkedIn revenue increased 10% (up 9% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Dynamics products and cloud services revenue increased 16% driven by Dynamics 365 revenue growth of 19% (up 20% in constant currency)\n\nRevenue in Intelligent Cloud was $28.5 billion and increased 19% (up 20% in constant currency), with the following business highlights:\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Server products and cloud services revenue increased 21% (up 22% in constant currency) driven by Azure and other cloud services revenue growth of 29% (up 30% in constant currency)\n\nRevenue in More Personal Computing was $15.9 billion and increased 14% (up 15% in constant currency), with the following business highlights:\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Windows revenue increased 7% (up 8% in constant currency) with Windows OEM revenue growth of 4% and Windows Commercial products and cloud services revenue growth of 11% (up 12% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Devices revenue decreased 11% (down 9% in constant currency)\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Xbox content and services revenue increased 61% driven by 58 points of net impact from the Activision acquisition\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Search and news advertising revenue excluding traffic acquisition costs increased 19%\n\nMicrosoft returned $8.4 billion to shareholders in the form of share repurchases and dividends in the fourth quarter of fiscal year 2024.\n\n**Fiscal Year 2024 Results**\n\nMicrosoft Corp. today announced the following results for the fiscal year ended June 30, 2024, as compared to the corresponding period of last fiscal year:\n\n·\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Revenue was $245.1 billion an ...
#  {'url': 'https://www.cnbc.com/2024/07/30/microsoft-msft-q4-earnings-report-2024.html',
#   'title': 'Microsoft (MSFT) Q4 earnings report 2024 - CNBC',
#   'content': "The Productivity and Business Processes unit that includes Office software and LinkedIn produced $20.32 billion in revenue. That's up 11% and more than the $20.13 billion StreetAccount consensus.\n\nMicrosoft's More Personal Computing unit, with the Windows operating system, gaming, devices and search advertising, contributed $15.90 billion in revenue. That outcome is up 14% and higher than the StreetAccount consensus of $15.49 billion. [...] The company's top segment, Intelligent Cloud, generated $28.52 billion in revenue. It includes the Azure public cloud, Windows Server, Nuance and GitHub. The total was up about 19% and below the $28.68 billion consensus among analysts surveyed by StreetAccount. GitHub's revenue is now at an annual run rate exceeding $2 billion, Microsoft CEO Satya Nadella said on a conference call with analysts. [...] Here's how the company did in its report, posted after the bell on Tuesday, compared with the LSEG consensus:\n\n   Earnings per share: $2.95 vs. $2.93 expected\n   Revenue: $64.73 billion vs. $64.39 billion expected\n\nMicrosoft's revenue increased 15% year over year in the fiscal fourth quarter, which ended on June 30, according to a statement. Net income, at $22.04 billion, was up from $20.08 billion, or $2.69 per share, in the year-ago quarter.",
#   'score': 0.92005306,
#   'raw_content': 'Microsoft (MSFT) Q4 earnings report 2024\n\n===============\n\n[Skip Navigation](https://www.cnbc.com/2024/07/30/microsoft-msft-q4-earnings-report-2024.html#MainContent)\n\n[![Image 1: CNBC logo](https://static-redesign.cnbcfm.com/dist/d6085c9e81f4d7365c8d.svg)](https://www.cnbc.com/world/)\n\n[Markets](https://www.cnbc.com/markets/)\n\n*   [Pre-Markets](https://www.cnbc.com/pre-markets/)\n*   [U.S. Markets](https://www.cnbc.com/us-markets/)\n*   [Europe Markets](https://www.cnbc.com/markets-europe/)\n*   [China Markets](https://www.cnbc.com/china-markets/)\n*   [Asia Markets](https://www.cnbc.com/markets-asia-pacific/)\n*   [World Markets](https://www.cnbc.com/world-markets/)\n*   [Currencies](https://www.cnbc.com/currencies/)\n*   [Cryptocurrency](https://www.cnbc.com/cryptocurrency/)\n*   [Futures & Commodities](https://www.cnbc.com/futures-and-commodities/)\n*   [Bonds](https://www.cnbc.com/bonds/)\n*   [Funds & ETFs](https://www.cnbc.com/funds-and-etfs/)\n\n[Business](https://www.cnbc.com/business/)\n\n*   [Economy](https://www.cnbc.com/economy/)\n*   [Finance](https://www.cnbc.com/finance/)\n*   [Health & Science](https://www.cnbc.com/health-and-science/)\n*   [Media](https://www.cnbc.com/media/)\n*   [Real Estate](https://www.cnbc.com/real-estate/)\n*   [Energy](https://www.cnbc.com/energy/)\n*   [Climate](https://www.cnbc.com/climate/)\n*   [Transportation](https://www.cnbc.com/transportation/)\n*   [Investigations](https://www.cnbc.com/cnbc-investigations/)\n*   [Industrials](https://www.cnbc.com/industrials/)\n*   [Retail](https://www.cnbc.com/retail/)\n*   [Wealth](https://www.cnbc.com/wealth/)\n*   [Sports](https://www.cnbc.com/sports/)\n*   [Life](https://www.cnbc.com/life/)\n*   [Small Business](https://www.cnbc.com/small-business/)\n\n[Investing](https://www.cnbc.com/investing/)\n\n*   [Personal Finance](https://www.cnbc.com/personal-finance/)\n*   [Fintech](https://www.cnbc.com/fintech/)\n*   [Financial Advisors](https://www.cnbc.com/financial-advisors/)\n*   [Options Action](https://www.cnbc.com/options-action/)\n*   [ETF Street](https://www.cnbc.com/etf-street/)\n*   [Buffett Archive](https://buffett.cnbc.com/)\n*   [Earnings](https://www.cnbc.com/earnings/)\n*   [Trader Talk](https://www.cnbc.com/trader-talk/)\n\n[Tech](https://www.cnbc.com/technology/)\n\n*   [Cybersecurity](https://www.cnbc.com/cybersecurity/)\n*   [AI](https://www.cnbc.com/ai-artificial-intelligence/)\n*   [Enterprise](https://www.cnbc.com/enterprise/)\n*   [Internet](https://www.cnbc.com/internet/)\n*   [Media](https://www.cnbc.com/media/)\n*   [Mobile](https://www.cnbc.com/mobile/)\n*   [Social Media](https://www.cnbc.com/social-media/)\n*   [CNBC Disruptor 50](https://www.cnbc.com/cnbc-disruptors/)\n*   [Tech Guide](https://www.cnbc.com/tech-guide/)\n\n[Politics](https://www.cnbc.com/politics/)\n\n*   [White House](https://www.cnbc.com/white-house/)\n*   [Policy](https://www.cnbc.com/policy/)\n*   [Defense](https://www.cnbc.com/defense/)\n*   [Congress](https://www.cnbc.com/congress/)\n*   [Expanding Opportunity](https://www.cnbc.com/expanding-opportunity/)\n*   [Europe Politics](https://www.cnbc.com/europe-politics/)\n*   [China Politics](https://www.cnbc.com/china-politics/)\n*   [Asia Politics](https://www.cnbc.com/asia-politics/)\n*   [World Politics](https://www.cnbc.com/world-politics/)\n\n[Video](https://www.cnbc.com/tv/)\n\n*   [Latest Video](https://www.cnbc.com/latest-video/)\n*   [Full Episodes](https://www.cnbc.com/live-tv/full-episodes/)\n*   [Livestream](https://www.cnbc.com/live-tv/)\n*   [Top Video](https://www.cnbc.com/top-video/)\n*   [Live Audio](https://www.cnbc.com/live-audio/)\n*   [Europe TV](https://www.cnbc.com/europe-television/)\n*   [Asia TV](https://www.cnbc.com/asia-business-day/)\n*   [CNBC Podcasts](https://www.cnbc.com/podcast/)\n*   [CEO Interviews](https://www.cnbc.com/video-ceo-interviews/)\n*   [Digital Originals](https://www.cnbc.com/digital-original/)\n\n[Watchlist](https://www.c ...

# %%
result['results'][0]['url']
# Out:
# 'https://www.kavout.com/market-lens/key-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials'

# %%
from markitdown import MarkItDown

md = MarkItDown()
doc_content = md.convert(result['results'][0]['url'])

# %%
doc_content.title.strip()
# Out:
# 'Key Takeaways From Microsoft’s Q4 FY2024: Cloud Challenges Amid Strong Financials'

# %%
print(doc_content.text_content)
# Out:
# ![Kavout](/static/src/img/nav-logo-new.png)
#
# ## MarketLens
#
# [Log in](/user/login)
#
# [🎄
#
# ✨
#
# 🎄 Holiday Sale
#
# Claim 40% OFF
#
# 🎄 Holiday Sale
#
# 40%OFF All Plans
#
# Last sale of 2025 - Ends January 4th
#
# 40%OFF All Plans
#
# Last sale of 2025 - Ends January 4th
#
# 00
#
# Days
#
# 00
#
# Hours
#
# 00
#
# Mins
#
# 00
#
# Days
#
# 00
#
# Hours
#
# 00
#
# Mins
#
# Claim 40% OFF →](/holiday-sale)
#
# [Pricing Plans](/pricing-plans)[Sign Up](/user/register?next=%2Fmarket-lens%2Fkey-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials)[Log in](/user/login?next=%2Fmarket-lens%2Fkey-takeaways-from-microsofts-q4-fy2024-cloud-challenges-amid-strong-financials)
#
# [Stock Analysis](/market-lens/category/stock-analysis)
#
# # Key Takeaways From Microsoft’s Q4 FY2024: Cloud Challenges Amid Strong Financials
#
# Jul 31, 2024
#
# SHARE THIS ON:
#
# On July 30, 2024, Microsoft held its Q4 FY2024 earnings call, revealing a mix of robust financial performance and some areas of concern, particularly in its cloud segment. This report aims to provide a comprehensive analysis of the key takeaways from the earnings call, synthesizing information from various sources to offer a balanced and insightful perspective. The analysis will cover Microsoft’s financial performance, cloud growth, AI investments, and future outlook, considering the broader implications for stakeholders and potential future developments.
#
# ## **Financial Performance**
#
# ### **Earnings and Revenue**
#
# Microsoft reported better-than-expected earnings and revenue for Q4 FY2024. The company achieved an earnings per share (EPS) of $2.95, surpassing the consensus estimate of $2.93. Revenue for the quarter was $64.73 billion, exceeding the expected $64.39 billion and marking a 15% year-over-year increase. Net income rose to $22.04 billion, up from $20.08 billion in the same quarter last year.
#
# ### **Segment Performance**
#
# * **Productivity and Business Processes**: This segment, which includes Office and LinkedIn, generated $20.32 billion, up 11% year-over-year and above the $20.13 billion consensus.
# * **Intelligent Cloud**: Revenue grew 19% year-over-year to $28.52 billion, slightly below the expected $28.68 billion. Azure and other cloud services grew by 29%, falling short of the anticipated 31%.
# * **More Personal Computing**: This segment reported $15.90 billion in revenue, up 14% and exceeding the $15.49 billion consensus.
#
# Despite the overall positive financial performance, Microsoft’s shares fell by approximately 3% in extended trading, reflecting investor concerns over the cloud segment’s performance.
#
# ## **Cloud Growth and AI Capacity Constraints**
#
# ### **Cloud Growth Missed Estimates**
#
# One of the most significant takeaways from the earnings call was the underperformance of Microsoft’s cloud segment. While the Intelligent Cloud revenue grew by 19%, it fell short of analyst expectations. Azure’s growth of 29% also missed the anticipated 31%, marking the first time Azure’s growth missed forecasts since 2022. CFO Amy Hood attributed this shortfall to capacity constraints related to AI and weakness in some European regions.
#
# ### **AI Capacity Constraints**
#
# Microsoft is experiencing a lag in AI-related capacity, which is expected to continue until the second half of
#
# 1. This has affected cloud revenue, which came in at the lower end of previous guidance. The demand for Azure AI services exceeded available capacity, contributing to the softer-than-expected cloud growth.
#
# ## **Investment in AI**
#
# ### **Significant AI Investments**
#
# Microsoft is significantly ramping up its investments in AI, with nearly all of its $19 billion in capital expenditures allocated to cloud and AI initiatives. Half of this spending is focused on building infrastructure and data centers to support long-term monetization. This strategic investment underscores Microsoft’s commitment to maintaining its competitive edge in the rapidly evolving AI landscape.
#
# ### **AI-Driven Growth**
#
# AI has been a critical driver of growth for Microsoft. Azure’s share gains accelerated due to AI, with over 60,000 Azure AI customers, up nearly 60% year-over-year. GitHub Copilot adoption grew significantly, with over 77,000 organizations using it, contributing to GitHub’s annual revenue run rate reaching $2 billion. Additionally, Microsoft Fabric, the AI-powered data platform, now has over 14,000 paid customers, up 20% quarter-over-quarter.
#
# ## **Revenue Growth Outlook**
#
# ### **Fiscal 2025 Projections**
#
# Microsoft anticipates double-digit revenue growth in fiscal 2025, with cloud revenue expected to grow between 28% and 29% year-over-year in the first quarter. The company projected first-quarter revenue between $63.8 billion and $64.8 billion, implying 13.8% growth at the midpoint, but below the analyst consensus of $65.24 billion. Despite the positive outlook, the market reacted negatively, with shares dropping by as much as 7% in extended trading due to concerns over cloud revenue performance.
#
# ### **Long-Term Growth Drivers**
#
# CEO Satya Nadella emphasized the company’s focus on innovation, security, and leveraging AI across its product offerings. The introduction of Copilot Plus PCs, the fastest Windows PCs, received positive reviews, contributing to a 50% year-over-year increase in Windows 11 active devices. Microsoft Teams Premium also surpassed 3 million seats, up nearly 400% year-over-year.
#
# ## **Implications for Stakeholders**
#
# ### **Investors**
#
# For investors, the mixed performance of Microsoft’s cloud segment presents both challenges and opportunities. While the shortfall in cloud growth led to a decline in share prices, the company’s significant investments in AI and its strong overall financial performance suggest potential for long-term growth. Investors should closely monitor Microsoft’s progress in addressing AI capacity constraints and its ability to capitalize on AI-driven growth opportunities.
#
# ### **Customers**
#
# Microsoft’s continued focus on innovation and AI integration across its product offerings benefits customers by providing advanced tools and services. The adoption of AI-powered solutions like GitHub Copilot and Microsoft Fabric enhances productivity and efficiency for businesses. However, customers in regions affected by capacity constraints may experience delays in accessing these advanced services.
#
# ### **Competitors**
#
# Microsoft’s aggressive investment in AI and cloud infrastructure sets a high bar for competitors. Companies in the cloud and AI space will need to ramp up their investments and innovation efforts to keep pace with Microsoft’s advancements. The competitive landscape is likely to intensify as firms vie for market share in the burgeoning AI sector.
#
# ## **Conclusion**
#
# Microsoft’s Q4 FY2024 earnings call highlighted a strong financial performance, driven by robust revenue growth across its segments. However, the underperformance of the cloud segment and AI capacity constraints raised concerns among investors, leading to a decline in share prices. Despite these challenges, Microsoft’s significant investments in AI and its strategic focus on innovation position the company for long-term growth.
#
# The company’s projections for fiscal 2025 indicate continued revenue growth, with AI and cloud services playing a pivotal role. Stakeholders should remain vigilant in monitoring Microsoft’s progress in addressing capacity constraints and leveraging its AI investments to drive future growth. As the AI landscape evolves, Microsoft’s ability to innovate and adapt will be crucial in maintaining its competitive edge and delivering value to customers and investors alike.
#
# In summary, while Microsoft’s Q4 FY2024 earnings call revealed some areas of concern, the company’s strategic investments and strong financial performance underscore its potential for sustained growth and innovation in the years ahead.
#
# [MSFT](/stocks/nasdaq-msft/microsoft-corporation)
#
# SHARE THIS ON:
#
# ## Related Articles
#
# [![Key Economic Takeaways from Trump's Speech to Congress: Tax Cuts, DOGE Savings, and Energy Policies](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/mini_Untitled_5_eec4c88a69.jpg)](/market-lens/key-economic-takeaways-from-trump-s-speech-to-congress-tax-cuts-doge-savings-and-energy-policies)
#
# ### [Key Economic Takeaways from Trump's Speech to Congress: Tax Cuts, DOGE Savings, and Energy Policies](/market-lens/key-economic-takeaways-from-trump-s-speech-to-congress-tax-cuts-doge-savings-and-energy-policies "Key Economic Takeaways from Trump's Speech to Congress: Tax Cuts, DOGE Savings, and Energy Policies")
#
# Mar 05, 2025
#
# ### [Microsoft’s $80B AI Blitz: Which Stocks and Sectors Will Thrive?](/market-lens/microsofts-80b-ai-blitz-which-stocks-and-sectors-will-thrive "Microsoft’s $80B AI Blitz: Which Stocks and Sectors Will Thrive?")
#
# Jan 06, 2025
#
# [MSFT](/stocks/nasdaq-msft/microsoft-corporation)[LRCX](/stocks/nasdaq-lrcx/lam-research-corporation)[NVDA](/stocks/nasdaq-nvda/nvidia-corporation)
#
# [![Energy Transfer (ET): A Value Play Amid Data Center And LNG Expansion](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/mini_et_396c185eda.jpg)](/market-lens/energy-transfer-et-a-value-play-amid-data-center-and-lng-expansion)
#
# ### [Energy Transfer (ET): A Value Play Amid Data Center And LNG Expansion](/market-lens/energy-transfer-et-a-value-play-amid-data-center-and-lng-expansion "Energy Transfer (ET): A Value Play Amid Data Center And LNG Expansion")
#
# Mar 12, 2025
#
# [ET](/stocks/nyse-et/energy-transfer-lp)
#
# [![Alibaba's $53 Billion AI Bet: Kavout AI Stock Analysis Reveals the Path to $1 Trillion](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/2025092501_406049bbe1.jpg)](/market-lens/alibaba-s-53-billion-ai-bet-kavout-ai-stock-analysis-reveals-the-path-to-1-trillion)
#
# ### [Alibaba's $53 Billion AI Bet: Kavout AI Stock Analysis Reveals the Path to $1 Trillion](/market-lens/alibaba-s-53-billion-ai-bet-kavout-ai-stock-analysis-reveals-the-path-to-1-trillion "Alibaba's $53 Billion AI Bet: Kavout AI Stock Analysis Reveals the Path to $1 Trillion")
#
# Sep 25, 2025
#
# ## Category
#
# [Top](/discover)[Featured](/market-lens/category/all)[Pro Only](/market-lens/category/pro)[Stock Analysis](/market-lens/category/stock-analysis)[Investment Ideas](/market-lens/category/investment-ideas)[ETFs](/market-lens/category/etfs)[Crypto](/market-lens/category/crypto)[New Release](/market-lens/category/whats-new)
#
# ## You may also like
#
# No related articles available
#
# ## Breaking News
#
# [View All →](/discover?type=breaking-news)
#
# No topics available at the moment
#
# ## Featured Articles
#
# [![Gold and Silver Price Forecast 2026: Why Precious Metals Hit Record Highs and What Comes Next](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/mini_2025122701_237f372989.jpg)](/market-lens/gold-and-silver-price-forecast-2026-why-precious-metals-hit-record-highs-and-what-comes-next)
#
# ### [Gold and Silver Price Forecast 2026: Why Precious Metals Hit Record Highs and What Comes Next](/market-lens/gold-and-silver-price-forecast-2026-why-precious-metals-hit-record-highs-and-what-comes-next "Gold and Silver Price Forecast 2026: Why Precious Metals Hit Record Highs and What Comes Next")
#
# Dec 27, 2025
#
# [![Nvidia's $20 Billion Groq Deal: What It Means for AI in 2026](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/mini_2025122702_41bd7819f8.jpg)](/market-lens/nvidia-s-20-billion-groq-deal-what-it-means-for-ai-in-2026)
#
# ### [Nvidia's $20 Billion Groq Deal: What It Means for AI in 2026](/market-lens/nvidia-s-20-billion-groq-deal-what-it-means-for-ai-in-2026 "Nvidia's $20 Billion Groq Deal: What It Means for AI in 2026")
#
# Dec 27, 2025
#
# [![Applied Digital Stock Analysis: Why APLD Led the Market in 2025 and What to Expect in 2026](https://investgpt-test.oss-us-east-1.aliyuncs.com/strapi/2025122703_78924b8127.jpg)](/market-lens/applied-digital-stock-analysis-why-apld-led-the-market-in-2025-and-what-to-expect-in-2026)
#
# ### [Applied Digital Stock Analysis: Why APLD Led the Market in 2025 and What to Expect in 2026](/market-lens/applied-digital-stock-analysis-why-apld-led-the-market-in-2025-and-what-to-expect-in-2026 "Applied Digital Stock Analysis: Why APLD Led the Market in 2025 and What to Expect in 2026")
#
# Dec 27, 2025
#
# ## Top Headlines
#
# [View More →](/discover)
#
# Loading...
#
# ### Podcast
#
# [View More →](https://podcast.kavout.com/)
#
# MSFT
#
# [Advanced Chart](/stocks/nasdaq-msft/microsoft-corporation/advanced-technical-analysis)
#
# ### Home
#
# * [Kavout](https://kavout.com)
# * [Discover](/discover)
# * [Investgpt](/investgpt)
# * [Portfolio Toolbox](/portfolio-toolbox)
#
# ### Tools
#
# * [Watchlist](/watchlist)
# * [Market Movers](/market-movers/stocks/gainers/intraday/all-stocks)
# * [AI Stock Picker](/ai-stock-picker)
# * [Smart Signals](/smart-signals)
# * [Smart Money](/smart-money)
# * [Stocklist](/stock-list)
#
# ### Resources
#
# * [Affiliate Program](https://affiliate.kavout.com/)
# * [Academy](/academy)
# * [API for Signal DB](/product/list)
# * [Pricing Plans](/pricing-plans)
# * [Podcast](https://podcast.kavout.com)
#
# ### Other
#
# * [Privacy Policy](/privacy-policy)
# * [Terms of Use](/terms-of-use)
# * [Disclaimer](/disclaimer)
# * [About Us](/about-us)
# * [Contact Us](/contact-us)
#
# Disclaimer: The information and market data provided here and on kavout.com are for general informational purposes only. Real-time quotes and financial data are provided for U.S. stocks, ETFs, cryptocurrencies, and major forex pairs; quotes for certain other instruments, including commodity futures and indices, may be delayed by approximately 15–20 minutes. Nothing on this site constitutes investment, financial, trading, or any other form of advice, and Kavout makes no recommendations regarding any investment decisions. You are solely responsible for your investment decisions. Please conduct your own research and consult qualified financial advisors before investing. Past performance does not guarantee future results.
#
# © 2025 Kavout. All rights reserved.

# %%
doc_content = md.convert(result['results'][3]['url'])

# %%
print(doc_content.title.strip()) # Some website don't allow to web scrape
# Out:
# Your request has been blocked. This could be
#                         due to several reasons.

# %%
print(doc_content.text_content)
# Out:
# ![]()
#
# Skip
# to main content
#
# [![](https://img-prod-cms-rt-microsoft-com.akamaized.net/cms/api/am/imageFileData/RE1Mu3b?ver=5c31)Microsoft](https://www.microsoft.com)
#
# * [Microsoft 365](https://www.microsoft.com/microsoft-365)
# * [Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)
# * [Copilot](https://copilot.microsoft.com/)
# * [Windows](https://www.microsoft.com/en-us/windows/)
# * [Surface](https://www.microsoft.com/en-us/surface)
# * [Xbox](https://www.xbox.com/)
# * [Deals](https://www.microsoft.com/en-us/store/b/sale?icid=gm_nav_L0_salepage)
# * [Small Business](https://www.microsoft.com/en-us/store/b/business)
# * [Support](https://support.microsoft.com/en-us)
# * More
#
# * All
#   Microsoft
#   + - [Office](https://products.office.com/en-us/home)
#     - [Windows](https://www.microsoft.com/en-us/windows/)
#     - [Surface](https://www.microsoft.com/en-us/surface)
#     - [Xbox](https://www.xbox.com/)
#     - [Deals](https://www.microsoft.com/en-us/store/b/sale?icid=gm_nav_L0_salepage)
#     - [Support](https://support.microsoft.com/en-us)
#   + Software
#     - [Windows
#       Apps](https://www.microsoft.com/en-us/store/apps/windows?icid=CNavAppsWindowsApps)
#     - [OneDrive](https://onedrive.live.com/about/en-us/)
#     - [Outlook](https://outlook.live.com/owa/)
#     - [Skype](https://www.skype.com/en/)
#     - [OneNote](https://www.onenote.com/)
#     - [Microsoft
#       Teams](https://products.office.com/en-us/microsoft-teams/free?icid=SSM_AS_Promo_Apps_MicrosoftTeams)
#     - [Microsoft
#       Edge](https://www.microsoft.com/edge)
#   + PCs
#     &
#     Devices
#     - [Computers](https://www.microsoft.com/en-us/store/b/pc?icid=CNavDevicesPC)
#     - [Shop
#       Xbox](https://www.microsoft.com/en-us/store/b/xbox?icid=CNavDevicesXbox)
#     - [Accessories](https://www.microsoft.com/en-us/store/b/accessories?icid=CNavDevicesAccessories)
#     - [VR
#       &
#       mixed
#       reality](https://www.microsoft.com/en-us/store/b/virtualreality?icid=CNavVirtualReality)
#     - [Phones](https://www.microsoft.com/en-us/store/b/mobile?icid=CNavDevicesMobile)
#   + Entertainment
#     - [Xbox
#       Game
#       Pass
#       Ultimate](https://www.microsoft.com/en-us/p/xbox-game-pass-ultimate/cfq7ttc0khs0?WT.mc_id=CNavGamesXboxGamePassUltimate)
#     - [Xbox
#       Live
#       Gold](https://www.microsoft.com/en-us/p/xbox-live-gold/cfq7ttc0k5dj?WT.mc_id=CNavGamesXboxLiveGold)
#     - [Xbox
#       games](https://www.microsoft.com/en-us/store/b/xbox?icid=CNavDevicesXbox)
#     - [PC
#       games](https://www.microsoft.com/en-us/store/games/windows?icid=CNavGamesWindowsGames)
#     - [Windows
#       digital
#       games](https://www.microsoft.com/en-us/store/games/windows?icid=TopNavWindowsGames)
#     - [Movies
#       &
#       TV](https://www.microsoft.com/en-us/store/movies-and-tv?icid=TopNavMoviesTv)
#   + Business
#     - [Microsoft
#       Azure](https://azure.microsoft.com/en-us/)
#     - [Microsoft
#       Dynamics
#       365](https://www.microsoft.com/en-us/dynamics365/home)
#     - [Microsoft
#       365](https://www.microsoft.com/en-us/microsoft-365)
#     - [Microsoft
#       Industry](https://www.microsoft.com/en-us/enterprise)
#     - [Data
#       platform](https://www.microsoft.com/en-us/sql-server/)
#     - [Microsoft
#       Advertising](https://go.microsoft.com/fwlink/?linkid=2026638)
#     - [Licensing](https://www.microsoft.com/licensing/default)
#     - [Shop
#       Business](https://www.microsoft.com/en-us/store/b/business?icid=CNavBusinessStore)
#   + Developer
#     &
#     IT
#     - [.NET](https://www.microsoft.com/net/)
#     - [Visual
#       Studio](https://visualstudio.microsoft.com/)
#     - [Windows
#       Server](https://www.microsoft.com/cloud-platform/windows-server)
#     - [Windows
#       Dev
#       Center](https://developer.microsoft.com/en-us/windows)
#     - [Docs](https://docs.microsoft.com/en-us/)
#   + Other
#     - [Microsoft
#       Rewards](https://www.microsoft.com/rewards)
#     - [Free
#       downloads
#       &
#       security](https://www.microsoft.com/en-us/download/default.aspx)
#     - [Education](https://www.microsoft.com/en-us/education?icid=CNavMSCOML0_Studentsandeducation)
#     - [Store
#       locations](https://www.microsoft.com/en-us/store/locations/find-a-store?icid=TopNavStoreLocations)
#     - [Gift
#       cards](https://www.microsoft.com/en-us/store/b/gift-cards)
#   + [View
#     Sitemap](https://www.microsoft.com/en-us/sitemap.aspx)
#
# SearchSearch
# Microsoft.comCancel
#
# ## Your current User-Agent string appears to be from an automated process, if this is incorrect, please click this link:
#
# [United States English Microsoft Homepage](http://www.microsoft.com/en/us/default.aspx?redir=true)
#
# What's
# new
#
# * [Surface Laptop Studio 2](https://www.microsoft.com/en-us/d/Surface-Laptop-Studio-2/8rqr54krf1dz)
# * [Surface Laptop Go
#   3](https://www.microsoft.com/en-us/d/Surface-Laptop-Go-3/8p0wwgj6c6l2)
# * [Surface
#   Pro
#   9](https://www.microsoft.com/en-us/d/surface-pro-9/93VKD8NP4FVK?activetab=pivot:overviewtab)
# * [Surface Laptop 5](https://www.microsoft.com/en-us/d/surface-laptop-5/8XN49V61S1BN?activetab=pivot:overviewtab)
# * [Microsoft Copilot](https://www.microsoft.com/en-us/microsoft-copilot)
# * [Copilot in Windows](https://www.microsoft.com/en-us/windows/copilot-ai-features?r=1)
# * [Microsoft 365](https://www.microsoft.com/en-us/microsoft-365)
# * [Windows 11 apps](https://www.microsoft.com/en-us/windows/windows-11-apps)
#
# Microsoft
# Store
#
# * [Account
#   profile](https://account.microsoft.com/)
# * [Download
#   Center](https://www.microsoft.com/en-us/download)
# * [Microsoft
#   Store
#   support](https://support.microsoft.com/en-us/microsoft-store-and-billing?ocid=MS_Footer_StoreSupport)
# * [Returns](https://www.microsoft.com/en-us/store/b/returns)
# * [Order
#   tracking](https://account.microsoft.com/orders)
# * [Certified Refurbished](https://www.microsoft.com/en-us/store/b/certified-refurbished-products)
# * [Microsoft Store Promise](https://www.microsoft.com/en-us/store/b/why-microsoft-store?icid=footer_why-msft-store_7102020)
# * [Flexible Payments](https://www.microsoft.com/en-us/store/b/payment-financing-options?icid=footer_financing_vcc)
#
# Education
#
# * [Microsoft
#   in
#   education](https://www.microsoft.com/en-us/education)
# * [Devices for education](https://www.microsoft.com/en-us/education/devices/overview)
# * [Microsoft Teams for Education](https://www.microsoft.com/en-us/education/products/teams)
# * [Microsoft 365 Education](https://www.microsoft.com/en-us/education/products/microsoft-365)
# * [How to buy for your school](https://www.microsoft.com/en-us/education/how-to-buy)
# * [Educator training and development](https://learn.microsoft.com/en-us/training/educator-center/?source=mec)
# * [Deals for students and parents](https://www.microsoft.com/en-us/store/b/education)
# * [Azure for students](https://azure.microsoft.com/en-us/free/students/)
#
# Business
#
# * [Microsoft Cloud](https://www.microsoft.com/en-us/microsoft-cloud)
# * [Microsoft Security](https://www.microsoft.com/en-us/security)
# * [Dynamics 365](https://www.microsoft.com/en-us/dynamics-365)
# * [Microsoft 365](https://www.microsoft.com/en-us/microsoft-365/business)
# * [Microsoft Power Platform](https://www.microsoft.com/en-us/power-platform)
# * [Microsoft Teams](https://www.microsoft.com/en-us/microsoft-teams/group-chat-software)
# * [Copilot for Microsoft 365](https://www.microsoft.com/en-us/microsoft-365/business/copilot-for-microsoft-365)
# * [Small Business](https://www.microsoft.com/en-us/store/b/business?icid=CNavBusinessStore)
#
# Developer & IT
#
# * [Azure](https://azure.microsoft.com/en-us/)
# * [Developer Center](https://developer.microsoft.com/en-us/)
# * [Documentation](https://learn.microsoft.com/en-us/docs/)
# * [Microsoft Learn](https://learn.microsoft.com/en-us/)
# * [Microsoft Tech Community](https://techcommunity.microsoft.com/)
# * [Azure Marketplace](https://azuremarketplace.microsoft.com/en-us/)
# * [AppSource](https://appsource.microsoft.com/en-us/)
# * [Visual Studio](https://visualstudio.microsoft.com/)
#
# Company
#
# * [Careers](https://careers.microsoft.com/)
# * [About
#   Microsoft](https://www.microsoft.com/en-us/about)
# * [Company
#   news](https://news.microsoft.com/)
# * [Privacy
#   at
#   Microsoft](https://privacy.microsoft.com/en-us)
# * [Investors](https://www.microsoft.com/investor/default.aspx)
# * [Diversity
#   and
#   inclusion](https://www.microsoft.com/en-us/diversity/)
# * [Accessibility](https://www.microsoft.com/en-us/accessibility)
# * [Sustainability](https://www.microsoft.com/en-us/sustainability/)
#
# [English
# (United
# States)](http://www.microsoft.com/en-us/locale.aspx)
#
# * [Sitemap](https://www.microsoft.com/en-us/sitemap1.aspx)
# * [Contact
#   Microsoft](https://support.microsoft.com/contactus)
# * [Privacy](https://go.microsoft.com/fwlink/?LinkId=521839)
# * [Terms
#   of
#   use](https://go.microsoft.com/fwlink/?LinkID=206977)
# * [Trademarks](https://www.microsoft.com/trademarks)
# * [Safety
#   &
#   eco](https://www.microsoft.com/en-us/devices/safety-and-eco)
# * [Recycling](https://www.microsoft.com/en-us/legal/compliance/recycling)
# * [About
#   our
#   ads](https://choice.microsoft.com)
# * ©
#   Microsoft
#   2024.303

# %%
from markitdown import MarkItDown
from langchain_tavily import TavilySearch
from tqdm import tqdm
from langchain.tools import tool

tavily_tool = TavilySearch(max_results=5,
                                search_depth='advanced',
                                include_answers=False,
                                include_raw_content=True)

md = MarkItDown()

@tool
def search_web_extract_info(query:str) -> list:
    """Search the web for a query and extracts useful information from the search links"""
    results = tavily_tool.invoke(query)['results']
    print(f"Found {len(results)} results from web search for query: {query}")
    docs = []
    for result in tqdm(results):
        # Extracting all text content from the URL
        try:
            extracted_info = md.convert(result['url'])
            text_title = extracted_info.title.strip()
            text_content = extracted_info.text_content.strip()
            if text_title.startswith('Your request has been blocked.'):
                raise Exception('Blocked by website')
            docs.append(text_title + '\n' + text_content)
        except:
            print('Extraction blocked for url: ', result['url'])
            text_title = result['title'].strip()
            text_content = result['content'].strip()
            docs.append(text_title + '\n' + text_content)
            pass

    return docs

# %%
docs = search_web_extract_info.invoke({'query': 'OpenAI GPT-4o'})
# Out:
# Found 5 results from web search for query: OpenAI GPT-4o
#  20%|██        | 1/5 [00:00<00:02,  1.88it/s]
# Extraction blocked for url:  https://en.wikipedia.org/wiki/GPT-4o
#  40%|████      | 2/5 [00:06<00:11,  3.88s/it]
# Extraction blocked for url:  https://platform.openai.com/docs/models/gpt-4o
#  60%|██████    | 3/5 [00:07<00:04,  2.34s/it]
# Extraction blocked for url:  https://openai.com/index/hello-gpt-4o/
#  80%|████████  | 4/5 [00:07<00:01,  1.62s/it]
# Extraction blocked for url:  https://www.igmguru.com/blog/gpt-4
# 100%|██████████| 5/5 [00:08<00:00,  1.63s/it]
# Extraction blocked for url:  https://openai.com/index/gpt-4o-and-more-tools-to-chatgpt-free/

# %%
from IPython.display import display, Markdown

display(Markdown(docs[0]))
# Out:
# GPT-4o - Wikipedia
# GPT-4o ("o" for "omni") is a multilingual, multimodalgenerative pre-trained transformer developed by OpenAI and released in May 2024.( It can process and generate text, images and audio.(
#
# Upon release, GPT-4o was free in ChatGPT, though paid subscribers had higher usage limits.( GPT-4o was removed from ChatGPT in August 2025 when GPT-5 was released, but OpenAI reintroduced it for paid subscribers after users complained about the sudden removal.( [...] In August 2024, OpenAI introduced a new feature allowing corporate customers to customize GPT-4o using proprietary company data. This customization, known as fine-tuning "Fine-tuning (deep learning)"), enables businesses to adapt GPT-4o to specific tasks or industries, enhancing its utility in areas like customer service and specialized knowledge domains. Previously, fine-tuning was available only on the less powerful model GPT-4o mini.( [...] On March 25, 2025, OpenAI released an image-generation model that is native to GPT-4o, as the successor to DALL-E 3. The model was later named as GPT Image 1 (`gpt-image-1`) and introduced to the API on April 23. It was made available to paid users, with the rollout to free users being delayed.( The use of the feature was subsequently limited, with Sam Altman noting in a Tweet that "[their] GPUs were melting" from its unprecedented popularity.( OpenAI later revealed that over 130 million users

# %% [markdown]
# ### Build a Weather Tool

# %%
import os
import requests
from langchain.tools import tool

@tool
def get_weather(query: str) -> list:
    """Search weatherapi to get the current weather."""
    WEATHER_API_KEY=os.getenv("WEATHER_API_KEY")
    base_url = "http://api.weatherapi.com/v1/current.json"
    complete_url = f"{base_url}?key={WEATHER_API_KEY}&q={query}"

    response = requests.get(complete_url)
    data = response.json()
    if data.get("location"):
        return data
    else:
        return "Weather Data Not Found"

# %%
get_weather.invoke("Bangalore")
# Out:
# {'location': {'name': 'Bangalore',
#   'region': 'Karnataka',
#   'country': 'India',
#   'lat': 12.9833,
#   'lon': 77.5833,
#   'tz_id': 'Asia/Kolkata',
#   'localtime_epoch': 1766942515,
#   'localtime': '2025-12-28 22:51'},
#  'current': {'last_updated_epoch': 1766942100,
#   'last_updated': '2025-12-28 22:45',
#   'temp_c': 19.2,
#   'temp_f': 66.6,
#   'is_day': 0,
#   'condition': {'text': 'Mist',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#    'code': 1030},
#   'wind_mph': 8.9,
#   'wind_kph': 14.4,
#   'wind_degree': 96,
#   'wind_dir': 'E',
#   'pressure_mb': 1019.0,
#   'pressure_in': 30.09,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 83,
#   'cloud': 25,
#   'feelslike_c': 19.2,
#   'feelslike_f': 66.6,
#   'windchill_c': 17.2,
#   'windchill_f': 62.9,
#   'heatindex_c': 17.2,
#   'heatindex_f': 62.9,
#   'dewpoint_c': 11.7,
#   'dewpoint_f': 53.0,
#   'vis_km': 2.0,
#   'vis_miles': 1.0,
#   'uv': 0.0,
#   'gust_mph': 15.5,
#   'gust_kph': 24.9}}

# %%
import rich

result = get_weather.invoke("Zurich")
rich.print_json(data=result)
# Out:
# {
#   "location": {
#     "name": "Zurich",
#     "region": "",
#     "country": "Switzerland",
#     "lat": 47.3667,
#     "lon": 8.55,
#     "tz_id": "Europe/Zurich",
#     "localtime_epoch": 1766942666,
#     "localtime": "2025-12-28 18:24"
#   },
#   "current": {
#     "last_updated_epoch": 1766942100,
#     "last_updated": "2025-12-28 18:15",
#     "temp_c": 0.1,
#     "temp_f": 32.2,
#     "is_day": 0,
#     "condition": {
#       "text": "Overcast",
#       "icon": "//cdn.weatherapi.com/weather/64x64/night/122.png",
#       "code": 1009
#     },
#     "wind_mph": 2.2,
#     "wind_kph": 3.6,
#     "wind_degree": 42,
#     "wind_dir": "NE",
#     "pressure_mb": 1024.0,
#     "pressure_in": 30.24,
#     "precip_mm": 0.0,
#     "precip_in": 0.0,
#     "humidity": 86,
#     "cloud": 100,
#     "feelslike_c": -0.7,
#     "feelslike_f": 30.7,
#     "windchill_c": -2.1,
#     "windchill_f": 28.3,
#     "heatindex_c": -2.1,
#     "heatindex_f": 28.3,
#     "dewpoint_c": -3.6,
#     "dewpoint_f": 25.5,
#     "vis_km": 10.0,
#     "vis_miles": 6.0,
#     "uv": 0.0,
#     "gust_mph": 3.3,
#     "gust_kph": 5.3
#   }
# }

# %% [markdown]
# ## Explore LLM tool calling with custom tools
#
# An agent is basically an LLM which has the capability to automatically call relevant functions to perform complex or tool-based tasks based on input human prompts.
#
# Tool calling also popularly known as function calling is the ability to reliably enable such LLMs to call external tools and APIs.
#
# We will leverate the custom tools we created earlier in the previous section and try to see if the LLM can automatically call the right tools based on input prompts

# %% [markdown]
# ### Tool calling for LLMs with native support for tool or function calling
#
# Tool calling allows a model to respond to a given prompt by generating output that matches a user-defined schema. While the name implies that the model is performing some action, this is actually not the case! The model is coming up with the arguments to a tool, and actually running the tool (or not) is up to the user or agent defined by the user.
#
# Many LLM providers, including Anthropic, Cohere, Google, Mistral, OpenAI, and others, support variants of a tool calling feature. These features typically allow requests to the LLM to include available tools and their schemas, and for responses to include calls to these tools.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

print(llm.invoke("What's the weather like in New York City?"))
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# content='I don\'t have real-time access to live weather data, so I can\'t give you the *exact* current weather right this second.\n\nHowever, to get the most accurate and up-to-the-minute weather for New York City, I recommend checking:\n\n*   A weather app on your phone (like Apple Weather, Google Weather, AccuWeather, The Weather Channel)\n*   A reputable weather website (e.g., weather.com, accuweather.com, noaa.gov)\n*   A quick Google search for "weather New York City"' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b6611-bde4-7b32-8d9a-f7e5ef121f48-0' usage_metadata={'input_tokens': 12, 'output_tokens': 521, 'total_tokens': 533, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 399}}

# %%
tools = [multiply, search_web_extract_info, get_weather]
llm_with_tools = llm.bind_tools(tools)

# %%
# LLMs are still not perfect in tool calling so you might need to play around with the following prompt
prompt = """
            Given only the tools at your disposal, mention tool calls for the following tasks:
            Do not change the query given for any search tasks
            1. What is 2.1 times 3.5
            2. What is the current weather in Greenland today
            3. What are the 4 major Agentic AI Design Patterns
         """

results = llm_with_tools.invoke(prompt)

# %%
results
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_web_extract_info', 'arguments': '{"query": "4 major Agentic AI Design Patterns"}'}, '__gemini_function_call_thought_signatures__': {'b523c081-f7db-4917-ba4c-7798b4f95bdb': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6619-b9ae-73d3-8a4a-87e8732ff2ad-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2.1, 'b': 3.5}, 'id': 'b523c081-f7db-4917-ba4c-7798b4f95bdb', 'type': 'tool_call'}, {'name': 'get_weather', 'args': {'query': 'Greenland'}, 'id': '6a9930bb-8752-4b21-af2d-787fa2c6b5c6', 'type': 'tool_call'}, {'name': 'search_web_extract_info', 'args': {'query': '4 major Agentic AI Design Patterns'}, 'id': '59445be8-f059-4e06-896c-1940ecd118b9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 213, 'output_tokens': 191, 'total_tokens': 404, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 128}})

# %%
results.tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': 2.1, 'b': 3.5},
#   'id': 'b523c081-f7db-4917-ba4c-7798b4f95bdb',
#   'type': 'tool_call'},
#  {'name': 'get_weather',
#   'args': {'query': 'Greenland'},
#   'id': '6a9930bb-8752-4b21-af2d-787fa2c6b5c6',
#   'type': 'tool_call'},
#  {'name': 'search_web_extract_info',
#   'args': {'query': '4 major Agentic AI Design Patterns'},
#   'id': '59445be8-f059-4e06-896c-1940ecd118b9',
#   'type': 'tool_call'}]

# %%
multiply
# Out:
# StructuredTool(name='multiply', description='use to multiply numbers', args_schema=<class '__main__.CalculatorInput'>, return_direct=True, func=<function multiply at 0x77e717767490>)

# %%
toolkit = {
    "multiply": multiply,
    "search_web_extract_info": search_web_extract_info,
    "get_weather": get_weather
}

for tool_call in results.tool_calls:
    selected_tool = toolkit[tool_call["name"].lower()]
    print(f"Calling tool: {tool_call['name']}")
    tool_output = selected_tool.invoke(tool_call["args"])
    print(tool_output)
    print()
# Out:
# Calling tool: multiply
# 7.3500000000000005
#
# Calling tool: get_weather
# {'location': {'name': 'Nuuk', 'region': 'Vestgronland', 'country': 'Greenland', 'lat': 64.183, 'lon': -51.75, 'tz_id': 'America/Nuuk', 'localtime_epoch': 1766944577, 'localtime': '2025-12-28 15:56'}, 'current': {'last_updated_epoch': 1766943900, 'last_updated': '2025-12-28 15:45', 'temp_c': 3.1, 'temp_f': 37.6, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 26.2, 'wind_kph': 42.1, 'wind_degree': 172, 'wind_dir': 'S', 'pressure_mb': 1023.0, 'pressure_in': 30.21, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 87, 'cloud': 100, 'feelslike_c': -3.4, 'feelslike_f': 25.9, 'windchill_c': -4.1, 'windchill_f': 24.6, 'heatindex_c': 2.6, 'heatindex_f': 36.6, 'dewpoint_c': 0.9, 'dewpoint_f': 33.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.0, 'gust_mph': 38.2, 'gust_kph': 61.5}}
#
# Calling tool: search_web_extract_info
# Found 5 results from web search for query: 4 major Agentic AI Design Patterns
#  80%|████████  | 4/5 [00:05<00:01,  1.11s/it]
# Extraction blocked for url:  https://medium.com/@bijit211987/agentic-design-patterns-cbd0aae2962f
# 100%|██████████| 5/5 [00:06<00:00,  1.25s/it]
# ['Agentic AI Design Patterns Introduction and walkthrough | Amazon Web Services\n# YouTube\n\n## Agentic AI Design Patterns Introduction and walkthrough | Amazon Web Services\n\n### Video Metadata\n- **Keywords:** video, sharing, camera phone, video phone, free, upload\n- **Runtime:** PT9M54S\n\n### Description\nThe video explores four foundational design patterns in agentic AI systems: reflection, tool use, planning, and multi-agent collaboration. These patterns represent the evolution of AI from basic problem-solving to sophisticated autonomous systems capable of making complex decisions with minimal human oversight. Through practical examples using Amazon Bedrock, the video demonstrates how AI agents can self-evaluate, utilize external tools, break down complex tasks, and collaborate effectively. The presentation emphasizes how these patterns enable AI systems to work independently and cooperatively while adapting to various challenges, ultimately transforming traditional work processes and industry operations through enhanced decision-making capabilities.\n\nSubscribe to AWS: https://go.aws/subscribe\n\nSign up for AWS: https://go.aws/signup\nAWS free tier: https://go.aws/free\nExplore more: https://go.aws/more\nContact AWS: https://go.aws/contact\n\nNext steps:\nExplore on AWS in Analyst Research:  https://go.aws/reports\nDiscover, deploy, and manage software that runs on AWS: https://go.aws/marketplace\nJoin the AWS Partner Network: https://go.aws/partners\nLearn more on how Amazon builds and operates software: https://go.aws/library\n\nDo you have technical AWS questions?\nAsk the community of experts on AWS re:Post: https://go.aws/3lPaoPb\n\nWhy AWS?\nAmazon Web Services (AWS) is the world’s most comprehensive and broadly adopted cloud. Millions of customers—including the fastest-growing startups, largest enterprises, and leading government agencies—use AWS to be more agile, lower costs, and innovate faster.\n\n#AWS #AmazonWebServices #CloudComputing', 'One Agent For Many Worlds, Cross-Species Cell Embeddings, and more | Andrew Ng | 126 comments\nAgree & Join LinkedIn\n\nBy clicking Continue to join or sign in, you agree to LinkedIn’s [User Agreement](/legal/user-agreement?trk=linkedin-tc_auth-button_user-agreement), [Privacy Policy](/legal/privacy-policy?trk=linkedin-tc_auth-button_privacy-policy), and [Cookie Policy](/legal/cookie-policy?trk=linkedin-tc_auth-button_cookie-policy).\n\n[Skip to main content](#main-content)\n\n[LinkedIn](/?trk=public_post_nav-header-logo)\n\n* [Top Content](https://www.linkedin.com/top-content?trk=public_post_guest_nav_menu_topContent)\n* [People](https://www.linkedin.com/pub/dir/%2B/%2B?trk=public_post_guest_nav_menu_people)\n* [Learning](https://www.linkedin.com/learning/search?trk=public_post_guest_nav_menu_learning)\n* [Jobs](https://www.linkedin.com/jobs/search?trk=public_post_guest_nav_menu_jobs)\n* [Games](https://www.linkedin.com/games?trk=public_post_guest_nav_menu_games)\n\n[Sign in](https://www.linkedin.com/login?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fandrewyng_one-agent-for-many-worlds-cross-species-activity-7179159130325078016-_oXr&fromSignIn=true&trk=public_post_nav-header-signin)\n[Register now](https://www.linkedin.com/signup/cold-join?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fposts%2Fandrewyng_one-agent-for-many-worlds-cross-species-activity-7179159130325078016-_oXr&trk=public_post_nav-header-join)\n\n# Andrew Ng’s Post\n\n[![View profile for Andrew Ng]()](https://www.linkedin.com/in/andrewyng?trk=public_post_feed-actor-image)\n\n[Andrew Ng](https://www.linkedin.com/in/andrewyng?trk=public_post_feed-actor-name)\n\nAndrew Ng is an Influencer\n\n1y\n\n* [Report this post](/uas/login?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fposts%2Fandrewyng_one-agent-for-many-worlds-cross-species-activity-7179159130325078016-_oXr&trk=public_post_ellipsis-menu-semaphore-sign-in-redirect&guestReportContentType=POST&_f=guest-reporting)\n\nLast week ...

# %%
tools
# Out:
# [StructuredTool(name='multiply', description='use to multiply numbers', args_schema=<class '__main__.CalculatorInput'>, return_direct=True, func=<function multiply at 0x77e717767490>),
#  StructuredTool(name='search_web_extract_info', description='Search the web for a query and extracts useful information from the search links', args_schema=<class 'langchain_core.utils.pydantic.search_web_extract_info'>, func=<function search_web_extract_info at 0x77e717766cb0>),
#  StructuredTool(name='get_weather', description='Search weatherapi to get the current weather.', args_schema=<class 'langchain_core.utils.pydantic.get_weather'>, func=<function get_weather at 0x77e71767f520>)]

# %% [markdown]
# ### Tool calling for LLMs without native support for tool or function calling
#
# Some models like ChatGPT have been fine-tuned for tool calling and provide a dedicated API for tool calling. Generally, such models are better at tool calling than non-fine-tuned models, and are recommended for use cases that require tool calling.
#
# Here we will explore an alternative method to invoke tools if you're using a model that does not natively support tool calling (even though we use ChatGPT here which supports it, we will assume it could be any LLM which doesn't support tool calling).
#
# We'll do this by simply writing a prompt that will get the model to invoke the appropriate tools.

# %%
from langchain_core.tools import render_text_description

rendered_tools = render_text_description(tools)
print(rendered_tools)
# Out:
# multiply(a: float, b: float) -> float - use to multiply numbers
# search_web_extract_info(query: str) -> list - Search the web for a query and extracts useful information from the search links
# get_weather(query: str) -> list - Search weatherapi to get the current weather.

# %%
from langchain_core.prompts import ChatPromptTemplate

system_prompt = f"""\
You are an assistant that has access to the following set of tools.
Here are the names and descriptions for each tool:

{rendered_tools}

Given the user instructions, for each instruction do the following:
 - Return the name and input of the tool to use.
 - Return your response as a JSON blob with 'name' and 'arguments' keys.
 - The `arguments` should be a dictionary, with keys corresponding
   to the argument names and the values corresponding to the requested values.
"""

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("user", "{input}")
    ]
)

# %%
instructions = [
                  {"input" : "What is 2.1 times 3.5"},
                  {"input" : "What is the current weather in Greenland"},
                  {"input" : "Tell me about the current state of Agentic AI in the industry" }
               ]

# %%
from langchain_core.output_parsers import JsonOutputParser

chain = (prompt
            |
         llm
            |
         JsonOutputParser())

# %%
responses = chain.map().invoke(instructions)

# %%
responses
# Out:
# [{'name': 'multiply', 'arguments': {'a': 2.1, 'b': 3.5}},
#  {'name': 'get_weather', 'arguments': {'query': 'Greenland'}},
#  {'name': 'search_web_extract_info',
#   'arguments': {'query': 'current state of Agentic AI in the industry'}}]

# %%
toolkit = {
    "multiply": multiply,
    "search_web_extract_info": search_web_extract_info,
    "get_weather": get_weather
}

for tool_call in responses:
    selected_tool = toolkit[tool_call["name"].lower()]
    print(f"Calling tool: {tool_call['name']}")
    tool_output = selected_tool.invoke(tool_call["arguments"])
    print(tool_output)
    print()
# Out:
# Calling tool: multiply
# 7.3500000000000005
#
# Calling tool: get_weather
# {'location': {'name': 'Nuuk', 'region': 'Vestgronland', 'country': 'Greenland', 'lat': 64.183, 'lon': -51.75, 'tz_id': 'America/Nuuk', 'localtime_epoch': 1766944577, 'localtime': '2025-12-28 15:56'}, 'current': {'last_updated_epoch': 1766943900, 'last_updated': '2025-12-28 15:45', 'temp_c': 3.1, 'temp_f': 37.6, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 26.2, 'wind_kph': 42.1, 'wind_degree': 172, 'wind_dir': 'S', 'pressure_mb': 1023.0, 'pressure_in': 30.21, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 87, 'cloud': 100, 'feelslike_c': -3.4, 'feelslike_f': 25.9, 'windchill_c': -4.1, 'windchill_f': 24.6, 'heatindex_c': 2.6, 'heatindex_f': 36.6, 'dewpoint_c': 0.9, 'dewpoint_f': 33.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 0.0, 'gust_mph': 38.2, 'gust_kph': 61.5}}
#
# Calling tool: search_web_extract_info
# Found 5 results from web search for query: current state of Agentic AI in the industry
#  80%|████████  | 4/5 [12:06<04:45, 285.87s/it]
# Extraction blocked for url:  https://www.mckinsey.com/capabilities/quantumblack/our-insights/the-state-of-ai
# 100%|██████████| 5/5 [12:07<00:00, 145.59s/it]
# ['Discover the Top Agentic AI Trends for 2026\n[Kasmo](https://www.kasmodigital.com "Kasmo")\n\n[![kasmo-logo-update](https://www.kasmodigital.com/wp-content/uploads/2023/02/kasmo-logo-update.png)](https://www.kasmodigital.com)\n\nMenu\n\n* Services\n\n  + [Salesforce](https://www.kasmodigital.com/salesforce/)\n  + [Snowflake](https://www.kasmodigital.com/snowflake/)\n* Industries\n\n  + [BFSI](https://www.kasmodigital.com/banking-financial-services-industry/)\n  + [Manufacturing](https://www.kasmodigital.com/manufacturing-industry/)\n  + [Travel and Hospitality](https://www.kasmodigital.com/travel-and-hospitality/)\n  + [Healthcare & Lifesciences](https://www.kasmodigital.com/healthcare-industry/)\n* Insights\n\n  + [Blog](https://www.kasmodigital.com/blog/)\n  + [Case Studies](https://www.kasmodigital.com/case-studies/)\n  + [Webinars & Events](https://www.kasmodigital.com/webinar/)\n  + [Whitepapers](https://www.kasmodigital.com/whitepapers/)\n  + [Press Release](https://www.kasmodigital.com/press-release/)\n* [Partners](https://www.kasmodigital.com/partners/)\n* Company\n\n  + [About Us](https://www.kasmodigital.com/company/)\n  + [Careers](https://www.kasmodigital.com/careers/)\n  + [Contact Us](https://www.kasmodigital.com/contact-us/)\n\n[Linkedin-in](https://www.linkedin.com/company/kasmo-technologies-pvt-ltd)\n\n[Twitter](https://x.com/Kasmodigital)\n\n[Facebook-f](https://www.facebook.com/Kasmotechnologies)\n\n[Youtube](https://www.youtube.com/c/KasmoCloud/featured)\n\n# The Biggest Agentic AI Trends for 2026 and How They Will Transform Industries\n\n* [Salesforce](https://www.kasmodigital.com/category/salesforce/)\n* December 19, 2025\n\n![agentic AI Trends](https://www.kasmodigital.com/wp-content/uploads/2025/12/image-2025-12-19T121647.339-768x432.png)\n\n## Introduction\n\n2026 is shaping up to be the year agents start running the enterprise. What began as simple assistants is rapidly evolving into autonomous AI workers that plan, decide, and execute tasks with minimal human input. According to [Forrester’s](https://www.forrester.com/blogs/meet-the-ai-agents-redefining-b2b-gtm-strategies-and-approaches-at-b2b-summit-emea/#:~:text=Investment%20is%20on%20the%20rise,a%20product%20is%20utilized%20postsale.) recent survey, 74% of B2B and B2B2C organizations have already adopted AI agents, with another 14% set to join them. By 2026, this surge in adoption will reshape how businesses prioritize automation, decision-making, and operational workflows.\n\nCompanies are no longer asking how to use AI for efficiency; they’re looking for muti agent systems and self-optimizing systems. This shift marks a turning point where agentic AI becomes central to business strategy. As agentic AI moves deeper into enterprise architecture, it provides new possibilities in different sectors, including retail, manufacturing, healthcare, and more.\n\n## How are business priorities shifting with agentic AI adoption in 2026?\n\nBy 2026, organizations across industries are shifting their strategic priorities as agentic AI moves from experimentation to enterprise-wide adoption. Businesses are looking at agentic AI as a foundation for rethinking entire workflows, decision cycles, and value creation models. Leaders are prioritizing automation that collaborates with humans to enable faster response times, reduced operational bottlenecks, and continuous optimization across functions. This shift reflects a broader move toward autonomous systems that augment human expertise rather than simply support it.\n\nAnother major shift is the growing focus on connected, real-time decision-making. Instead of relying on fragmented data systems and manual reporting, enterprises are investing in AI agents that operate on unified data layers and can proactively trigger actions across departments. This is reshaping priorities around data strategy, governance, and cross-functional collaboration. Leading companies are adopting Salesforce Agentforce, which allows multip ...

# %%
for doc in tool_output:
    print(doc)
    print()
# Out:
# Discover the Top Agentic AI Trends for 2026
# [Kasmo](https://www.kasmodigital.com "Kasmo")
#
# [![kasmo-logo-update](https://www.kasmodigital.com/wp-content/uploads/2023/02/kasmo-logo-update.png)](https://www.kasmodigital.com)
#
# Menu
#
# * Services
#
#   + [Salesforce](https://www.kasmodigital.com/salesforce/)
#   + [Snowflake](https://www.kasmodigital.com/snowflake/)
# * Industries
#
#   + [BFSI](https://www.kasmodigital.com/banking-financial-services-industry/)
#   + [Manufacturing](https://www.kasmodigital.com/manufacturing-industry/)
#   + [Travel and Hospitality](https://www.kasmodigital.com/travel-and-hospitality/)
#   + [Healthcare & Lifesciences](https://www.kasmodigital.com/healthcare-industry/)
# * Insights
#
#   + [Blog](https://www.kasmodigital.com/blog/)
#   + [Case Studies](https://www.kasmodigital.com/case-studies/)
#   + [Webinars & Events](https://www.kasmodigital.com/webinar/)
#   + [Whitepapers](https://www.kasmodigital.com/whitepapers/)
#   + [Press Release](https://www.kasmodigital.com/press-release/)
# * [Partners](https://www.kasmodigital.com/partners/)
# * Company
#
#   + [About Us](https://www.kasmodigital.com/company/)
#   + [Careers](https://www.kasmodigital.com/careers/)
#   + [Contact Us](https://www.kasmodigital.com/contact-us/)
#
# [Linkedin-in](https://www.linkedin.com/company/kasmo-technologies-pvt-ltd)
#
# [Twitter](https://x.com/Kasmodigital)
#
# [Facebook-f](https://www.facebook.com/Kasmotechnologies)
#
# [Youtube](https://www.youtube.com/c/KasmoCloud/featured)
#
# # The Biggest Agentic AI Trends for 2026 and How They Will Transform Industries
#
# * [Salesforce](https://www.kasmodigital.com/category/salesforce/)
# * December 19, 2025
#
# ![agentic AI Trends](https://www.kasmodigital.com/wp-content/uploads/2025/12/image-2025-12-19T121647.339-768x432.png)
#
# ## Introduction
#
# 2026 is shaping up to be the year agents start running the enterprise. What began as simple assistants is rapidly evolving into autonomous AI workers that plan, decide, and execute tasks with minimal human input. According to [Forrester’s](https://www.forrester.com/blogs/meet-the-ai-agents-redefining-b2b-gtm-strategies-and-approaches-at-b2b-summit-emea/#:~:text=Investment%20is%20on%20the%20rise,a%20product%20is%20utilized%20postsale.) recent survey, 74% of B2B and B2B2C organizations have already adopted AI agents, with another 14% set to join them. By 2026, this surge in adoption will reshape how businesses prioritize automation, decision-making, and operational workflows.
#
# Companies are no longer asking how to use AI for efficiency; they’re looking for muti agent systems and self-optimizing systems. This shift marks a turning point where agentic AI becomes central to business strategy. As agentic AI moves deeper into enterprise architecture, it provides new possibilities in different sectors, including retail, manufacturing, healthcare, and more.
#
# ## How are business priorities shifting with agentic AI adoption in 2026?
#
# By 2026, organizations across industries are shifting their strategic priorities as agentic AI moves from experimentation to enterprise-wide adoption. Businesses are looking at agentic AI as a foundation for rethinking entire workflows, decision cycles, and value creation models. Leaders are prioritizing automation that collaborates with humans to enable faster response times, reduced operational bottlenecks, and continuous optimization across functions. This shift reflects a broader move toward autonomous systems that augment human expertise rather than simply support it.
#
# Another major shift is the growing focus on connected, real-time decision-making. Instead of relying on fragmented data systems and manual reporting, enterprises are investing in AI agents that operate on unified data layers and can proactively trigger actions across departments. This is reshaping priorities around data strategy, governance, and cross-functional collaboration. Leading companies are adopting Salesforce Agentforce, which allows multiple agents to work together across sales, service, operations, supply chain, and field teams. As a result, organizations are designing workflows that are predictive, context-aware, and self-improving.
#
# ## The Top Agentic AI Trends to Watch in 2026
#
# Below are a few impactful Agentic AI trends to observe-
#
# ![agentic AI Trends](https://www.kasmodigital.com/wp-content/uploads/2025/12/image-2025-12-19T120851.552.png)
#
# ### Multi-Agent Systems Become Standard
#
# Enterprises are shifting from isolated AI assistants to interconnected networks of AI agents that collaborate autonomously. Instead of a single AI assistant, businesses now rely on multiple specialized agents, like forecasting agents, customer service agents, supply chain agents, and security agents, each designed for a specific domain but able to collaborate. These multi-agent systems share information, divide tasks, and coordinate actions across departments. The result is a self-orchestrating enterprise where tasks move seamlessly from one agent to another, reducing manual work, improving process accuracy, and accelerating end-to-end execution. In 2026, enterprises will treat multi-agent ecosystems as a core operating model, not an experimental technology.
#
# ### Agents Take Over Complex Decision Workflows
#
# Agentic AI is evolving beyond simple task execution to handling decisions that previously required expert judgment. Using large context windows, real-time data, domain grounding, and chain-of-thought reasoning, agents can evaluate scenarios, weigh trade-offs, and choose the best action plan. They don’t just analyze data; they reason through trade-offs, predict outcomes, and recommend or perform the next best action. This shift enables companies to automate high-value decisions like production planning, pricing optimization, risk evaluation, and customer routing. The biggest impact is speed; decisions that once took hours now happen instantly, with far greater accuracy.
#
# ### Integration of AI Agents With the Physical World
#
# The digital and physical enterprise worlds are converging as AI agents gain the ability to monitor, control, and optimize hardware systems. Through IoT networks, robotics, sensors, and connected infrastructure, agents can interact with machines, environments, and physical assets. AI Agents integrate with IoT devices, robotics, shop-floor systems, and industrial equipment. This connection allows agents to monitor real-time physical conditions, temperature, vibration, throughput, quality readings, and respond immediately. They can adjust machine parameters, halt defective runs, reroute work orders, or even coordinate robot actions autonomously. This convergence of digital intelligence with physical operations creates safer factories, smarter supply chains, and dramatically reduced downtime.
#
# ### Autonomous Customer Experience
#
# Customer-facing AI agents are transforming how brands engage with consumers. Ahead of chatbots or scripted workflows, autonomous CX agents can understand intent, personalize recommendations, resolve service issues, manage returns, initiate transactions, and do more with less human intervention. This helps businesses ensure a 24/7, consistent experience that minimizes wait times and reduces operational workload. By 2026, autonomous CX will become a competitive differentiator across retail, financial services, telecom, and healthcare.
#
# ### AI Safety and Security Agents
#
# As agentic AI becomes deeply embedded into core business operations, ensuring safe and controlled automation becomes a strategic priority. New categories of governance agents and security agents emerge to monitor, audit, and regulate other AI agents. These agents enforce organizational policies, ensure alignment with compliance frameworks, block unauthorized actions, and continuously evaluate risks. They provide oversight by detecting anomalies, hallucinations, data leakage attempts, or deviation from approved workflows. Enterprises rely on these safety mechanisms to maintain trust and prevent operational or reputational risks associated with autonomous systems.
#
# ## [![agentic AI Trends](https://www.kasmodigital.com/wp-content/uploads/2025/12/image-2025-12-19T120858.136.png)](https://www.kasmodigital.com/agentic-ai-in-compliance-because-spreadsheets-cant-keep-up-anymore/)Industry Examples: How Agentic AI Will Transform Key Sectors by 2026
#
# ### Manufacturing
#
# Agentic AI will fundamentally reshape factory operations by acting as an autonomous decision layer across production, quality, maintenance, and supply chain processes. AI agents will monitor machines through IoT data, detect anomalies, and trigger corrective actions before failures occur, significantly reducing downtime. Multi-agent systems will coordinate production schedules, optimize material flows, and adjust resource allocation. Human workers will collaborate with agents through voice or chat interfaces to retrieve insights, run diagnostics, or initiate workflows instantly. By 2026, manufacturers will rely on AI agents as virtual supervisors that keep operations stable, efficient, and resilient amidst fluctuating demand and supply chain uncertainty.
#
# ### Healthcare
#
# In healthcare, agentic AI can deliver a transformative impact for both medical teams and patients, with 2026 marking a major shift toward widespread adoption. Unlike traditional chatbots that assist with single tasks, AI agents will manage entire care pathways, from gathering patient history to coordinating treatment plans, aftercare instructions. Administrative agents will automate tasks like prior authorizations, appointment scheduling, claim routing, and discharge coordination. Patient-interaction agents will deliver personalized guidance, answer queries, and monitor care progress across digital channels. They help hospitals and care teams operate to provide smoother care delivery, reduced processing time, and enhanced patient outcomes.
#
# ### Retail
#
# In retail, agentic AI will transform how companies manage inventory, engage customers, and optimize supply chains. Retailers will rely on AI agents to run more accurate merchandising strategies, deliver seamless omnichannel experiences, and boost customer loyalty through hyper-personalization.
#
# * Demand forecasting agents will monitor sales trends, weather patterns, and supply signals to optimize stock levels and prevent shortages.
# * Store operations agents will coordinate workforce schedules, track patterns, and identify operational inefficiencies.
# * Customer-facing agents will provide real-time product recommendations, resolve service queries instantly, and support personalized journeys across eCommerce and physical stores.
#
# ### Travel and Hospitality
#
# Agentic AI is set to transform the travel and hospitality landscape by embedding intelligence across guest services, operations, and real-time decision-making. Customer service agents will manage booking updates, handle itinerary changes, and proactively resolve issues like flight delays or room preferences. Operational agents will optimize housekeeping schedules, track maintenance needs, and coordinate front-desk tasks to reduce check-in friction. In airports and hotels, AI agents will act as real-time intelligence hubs, analyzing crowd flow, predicting demand spikes, and orchestrating staff allocation. All these specific agents improve travel experience and handle operations end-to-end.
#
# ## The Salesforce Advantage in the Agentic AI Revolution
#
# Salesforce stands at the forefront of the agentic AI movement by offering a unified, trusted platform designed to deploy autonomous AI agents at enterprise scale. Salesforce combines data, automation, workflows, and intelligence in one interoperable system. With Einstein 1, Agentforce, and Agnetforce 360, Salesforce enables organizations to deploy autonomous, domain-specific AI agents that can act across sales, service, marketing, commerce, and operations. This integrated architecture ensures that every AI agent operates with clean, governed, real-time data while maintaining enterprise-grade security, auditability, and control.
#
# Instead of isolated chatbots, enterprises gain AI agents that can understand customer intent, execute multi-step workflows, access CRM data, trigger backend actions, and collaborate with human teams. Salesforce also integrates seamlessly with enterprise systems, enabling multi-agent orchestration across platforms and business units. Customer 360 apps, Field Service, Revenue Cloud, and industry-specific clouds give AI agents immediate access to established business logic, historical records, customer context, and operational processes. As organizations shift toward autonomous enterprise models in 2026, Salesforce provides the most reliable foundation to build, deploy, and maintain AI agents.
#
# ## Challenges Enterprises Must Solve Before Adopting agentic AI Trends
#
# While agentic AI promises autonomous workflows and exponential productivity, enterprises must address foundational gaps before deploying agents. These challenges span data quality, governance, security, operational readiness, and cultural adoption. A few points to consider are-
#
# **Low-Quality Data:** Agentic AI relies on accurate and quality data to make autonomous decisions. If data lives in silos or contains inconsistencies, agents may generate incorrect actions or recommendations. Enterprises must unify and clean data to ensure reliable agent behavior.
#
# **Clear Governance and Control:** AI agents act independently, which increases the need for strict oversight. Without governance, autonomy can introduce compliance risks or unintended actions.
#
# **Security and Risks Management:** Agents interact with sensitive systems, customer data, and operational workflows. Enterprises must implement least-privilege access policies for all agent types.
#
# **Operational Readiness:** Many legacy processes are not built for autonomous execution. To scale agentic AI, enterprises must re-engineer workflows, modernize systems, and clearly define the tasks agents can safely own.
#
# **Workforce Adaptation:** Employees must understand how to work alongside AI agents and trust their decisions. Without proper training and change management, teams may resist adoption or misuse of agent capabilities.
#
# ## Conclusion
#
# Agentic AI has become the foundation of next-generation enterprises. AI agents evolve from simple task automation to autonomous, multi-agent ecosystems. Salesforce is enabling this transformation with Agentforce, trusted and enterprise-ready AI agents. Salesforce enables multi-agent ecosystems that can work across sales, service, marketing, operations, and industry clouds.
#
# As a Salesforce Summit Partner and winner of the Partner Innovation Award, Kasmo helps enterprises with deep expertise in AI, automation, and industry-specific transformation. We help enterprises design AI-ready data foundations, build secure multi-agent workflows, and implement Salesforce Agentforce solutions. Together, Salesforce and Kasmo empower businesses to adopt agentic AI trends and drive measurable outcomes.
#
# [![agentic AI Trends](https://www.kasmodigital.com/wp-content/uploads/2025/12/image-2025-12-19T120854.287.png)](https://www.kasmodigital.com/contact-us/)
#
# * [agentic AI Trends](https://www.kasmodigital.com/tag/agentic-ai-trends/), [salesforce agentforce](https://www.kasmodigital.com/tag/salesforce-agentforce/), [security agents](https://www.kasmodigital.com/tag/security-agents/)
#
# [PrevPreviousWant to Future-Proof Your Retail and CPG Strategy? Start with the Retail Data Cloud](https://www.kasmodigital.com/want-to-future-proof-your-retail-and-cpg-strategy-start-with-the-retail-data-cloud/)
#
# [NextModernizing a Beauty and Wellness SaaS Platform with a Scalable Cloud Migration StrategyNext](https://www.kasmodigital.com/modernizing-a-beauty-and-wellness-saas-platform-with-a-scalable-cloud-migration-strategy/)
#
# ## Interested to learn more, talk to our experts
#
# [Contact Us](https://www.kasmodigital.com/contact-us/)
#
# Services
#
# * [Salesforce](https://www.kasmodigital.com/salesforce/)
# * [Snowflake](https://www.kasmodigital.com/snowflake/)
#
# Industries
#
# * [BFSI](https://www.kasmodigital.com/banking-financial-services-industry/)
# * [Manufacturing](https://www.kasmodigital.com/manufacturing-industry/)
# * [Travel and Hospitality](https://www.kasmodigital.com/travel-and-hospitality/)
# * [Healthcare & Lifesciences](https://www.kasmodigital.com/healthcare-industry/)
#
# Insights
#
# * [Blog](https://www.kasmodigital.com/blog/)
# * [Case Studies](https://www.kasmodigital.com/case-studies/)
# * [Webinars & Events](https://www.kasmodigital.com/webinar/)
# * [Whitepapers](https://www.kasmodigital.com/whitepapers/)
#
# About Us
#
# * [Company](https://www.kasmodigital.com/company/)
# * [Careers](https://www.kasmodigital.com/careers/)
# * [Partners](https://www.kasmodigital.com/partners/)
# * [Contact Us](https://www.kasmodigital.com/contact-us/)
# * [Privacy Policy](https://www.kasmodigital.com/privacy-policy/)
# * [Cookie Policy](https://www.kasmodigital.com/cookie-policy/)
#
# [![kasmo-logo-update](https://www.kasmodigital.com/wp-content/uploads/elementor/thumbs/kasmo-logo-update-rfpgca02zk2rjtz5st9541l8jjkle2ppeukigvctmo.png)](https://www.kasmodigital.com)
#
# **USA** :
#
# 13355, Noel Rd,
#
# Ste #1100, Dallas, TX, 75240
#
# +1 (302) 319 9952
#
# **Bengaluru** :
# Vista Pixel, 8/2B and 8/2C, Jakkuru Layout, Jakkuru, Bengaluru, Karnataka 560092
# +91 74115 60378
#
# **Hyderabad:**
#
# Cyber Crown, Sec-II Village, HUDA Techno Enclave, Madhapur, Hyderabad, Telangana 500081
#
# [Linkedin-in](https://www.linkedin.com/company/kasmo-technologies-pvt-ltd)
#
# [Twitter](https://x.com/Kasmodigital)
#
# [Facebook-f](https://www.facebook.com/Kasmotechnologies)
#
# [Youtube](https://www.youtube.com/c/KasmoCloud/featured)
#
# © 2025 Kasmo | All rights reserved
#
# ![](https://www.kasmodigital.com/wp-content/plugins/wpfront-scroll-top/images/icons/1.png)
#
# We are using cookies to give you the best experience on our website.
#
# You can find out more about which cookies we are using or switch them off in settings.
#
# Close GDPR Cookie Banner
#
# Accept All Cookies
# Customize
#
# Close GDPR Cookie Banner
#
# Change cookie settings
#
# Close GDPR Cookie Settings
#
# ![](https://www.kasmodigital.com/wp-content/uploads/2023/03/Kasmo-blue-01-300x97.png)
#
# * Privacy Overview
# * Strictly Necessary Cookies
# * 3rd Party Cookies
# * Cookie Policy
#
# Privacy Overview
#
# This website uses cookies so that we can provide you with the best user experience possible. Cookie information is stored in your browser and performs functions such as recognising you when you return to our website and helping our team to understand which sections of the website you find most interesting and useful.
#
# Strictly Necessary Cookies
#
# Strictly Necessary Cookie should be enabled at all times so that we can save your preferences for cookie settings.
#
# Enable or Disable Cookies
# [x]
#
# If you disable this cookie, we will not be able to save your preferences. This means that every time you visit this website you will need to enable or disable cookies again.
#
# 3rd Party Cookies
#
# This website uses Google Analytics to collect anonymous information such as the number of visitors to the site, and the most popular pages.
#
# Keeping this cookie enabled helps us to improve our website.
#
# Enable or Disable Cookies
# [ ]
#
# Please enable Strictly Necessary Cookies first so that we can save your preferences!
#
# Cookie Policy
#
# More information about our [Cookie Policy](https://www.kasmodigital.com/privacy-policy/)
#
# Enable All
# Save Changes
#
# OpenOcean - The state of agentic AI in 2025: what’s working, what isn’t, and what’s next
# [About us](/about)[Philosophy](/philosophy)[Portfolio](/portfolio)[Team](/team)[Jobs](https://jobs.openocean.vc/)[News](/news)
#
# Resources
#
# [Automation Market Map](/market-map)
#
# [Compliance](/more/compliance)
#
# ESG
#
# [ESG Starter Pack](https://www.openocean.vc/more/esg-starter-pack)[SFDR Disclosure](https://www.openocean.vc/more/sfdr-disclosure)[Sustainable Finance](https://www.openocean.vc/more/sustainable-finance)
#
# [About us](/about)[Philosophy](/philosophy)[Portfolio](/portfolio)[Team](/team)[Jobs](https://jobs.openocean.vc/)[News](/news)[Contact](/contact)
#
# Resources
#
# [Automation Market Map](/market-map)[Compliance](https://www.openocean.vc/more/compliance)[ESG Starter Pack](https://www.openocean.vc/more/esg-starter-pack)[SFDR Disclosure](https://www.openocean.vc/more/sfdr-disclosure)[Sustainable Finance](https://www.openocean.vc/more/sustainable-finance)
#
# [All articles](/news-highlights)
#
# August 22, 2025
#
# ·
#
# 10
#
# min read
#
# Joanna Graiver
#
# Investment Associate
#
# # The state of agentic AI in 2025: what’s working, what isn’t, and what’s next
#
# Insights
#
# ![The state of agentic AI in 2025: what’s working, what isn’t, and what’s next](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/6911ebec4954bc6e9d860b46_Joanna%20update.webp)
#
# ##### At the start of the year, “2025: The Year of Agents” sounded like headline bait. Eight months in, it feels like an understatement. Sam Altman said agents would “join the workforce” in 2025. Satya Nadella expects them to replace segments of knowledge work. Marc Benioff wants Salesforce to be the “#1 provider of digital labour.” That’s not future tense anymore - today, agents are moving tickets, shipping code, and digesting documents.
#
# What actually changed this year? A handful of innovations did the heavy lifting: vibe coding agents, browser use, stronger reasoning models, deep-research agents, and models that excel at agentic benchmarks. Together, they have unlocked billions of dollars in enterprise value, both in revenue for the companies building them and in productivity gains for the businesses deploying them.
#
# The wins so far have clear similarities: agents thrive when tasks are structured, data is rich, and results are easy to judge. Beyond that, things get harder. Agents still struggle with nuance, real-world conditions, and the enterprise demand for reliability and oversight.
#
# To understand what’s working, what isn’t, and what’s next, we will explore:
#
# * **A framework for measuring agent utility**: what have been the most compelling and successful use cases so far, and why have they worked?
# * **Agentic limitations - looking past the hype**: where have AI agents have fallen behind expectations or struggled to gain traction, and why?
# * **The next frontier**: what breakthroughs are required to unlock tougher domains, such as robotics and real-world decision-making?
#
# ‍
#
# #### **A framework for measuring agent utility**
#
# Some agents we expected to thrive in 2025 did, but others did not. Why?
#
# The use cases where AI agents dominated had these three traits in common:
#
# 1. **Ease of task verification -**  the outputs were straightforward to check. For example, reasoning models began with math and coding, where exact answers could be quickly verified and replicated.
# 2. **Rich and abundant data -** the models were trained on large amounts of high-quality data, much of it publicly available and already curated.
# 3. **Clarity of scope** - the tasks were well-defined and tightly bounded, meaning real-world data wasn’t too different from the training data.
#
# Perhaps the sector that showcases this success the most is software development. Ironically, computer scientists have long joked that “the first thing to get automated is the domain we know best” - coding.
#
# ‍
#
# **Coding automation**
#
# When I was deciding what to study at university, computer science felt like a safe bet - a stable path with strong career prospects. Over the last few months, however, The New York Times and Wall Street Journal reported that unemployment among CS graduates in the US has risen to 6.1% - more than twice the rate for biology or art history majors.
#
# Whilst I do believe (and hope) this is just a temporary readjustment for CS grads, it’s been striking to see the positive impact this technology has had on so many people. New tools like [Cursor](https://cursor.com/en) and [Lovable](https://lovable.dev/) have enabled those with little to no background in software engineering to build apps and platforms with near-native proficiency - at a fraction of the time, cost, and resources.
#
# It’s no surprise, then, that Cursor was one of the fastest companies in history to reach $100M ARR, and surged past $500M ARR this June. Lovable isn’t far behind - the company claims to power over 10% of all new websites monthly and is projected to hit $250M ARR by year-end.
#
# They have been able to develop extremely powerful and reliable AI coding agents because:
#
# * **Training data for the models is plentiful:** GitHub repos, documentation, code review history, and compiler output all offer dense, structured data.
# * **Verifiability is high:** success can be measured via test outcomes, performance metrics, or bug reduction.
# * **Feedback loops are rapid:** errors surface quickly, enabling fast iteration.
#
# ‍
#
# **Customer service & revenue workflows**
#
# Another clear success story for agentic AI is in customer service, where agents are replacing brittle chatbots with context-aware support. Notably, Gartner predicts that by 2029, agentic AI will autonomously resolve 80% of common customer issues without human intervention. These systems don’t respond; they resolve.
#
# This is a KPI-rich and high-volume sector where performance is judged on resolution time, customer satisfaction scores, and retention, making it easier to verify good from bad. It’s no surprise these workflows have transitioned rapidly from rule-based logic to agentic orchestration.
#
# [Parloa](https://www.parloa.com/) is a great example of this. The German startup recently achieved unicorn status after raising $120M from General Catalyst, EQT, and others. Their AI platform is used regularly by multiple Fortune 200 companies to automate and scale enterprise customer communications across channels, such as email, chat, and instant messaging.
#
# ‍
#
# **Deep research and document-centric work**
#
# Sectors that rely on structured document analysis, particularly in industries that are highly regulated and have substantial text-based documentation, such as law, healthcare, and finance, have also been reaping the benefits of AI agents. These systems can ingest, synthesise, and analyse large volumes of text, delivering faster, more consistent insights for professionals working across these functions.
#
# This trend has been especially evident with the meteoric rise of legal tech startups, which have seen huge funding rounds over the past year. US-based [Harvey](https://www.harvey.ai/), for example, raised a $300M Series E round led by Kleiner Perkins (having only been founded three years ago), and here in Europe, [Legora](https://legora.com/) (formerly Leya) raised $80M from Iconiq and General Catalyst. Startups like these - alongside newer players like [Flank](https://www.flank.ai/) and [Wordsmith](https://www.wordsmith.ai/) - are transforming legal operations by doing much of what junior associates used to do, faster, at scale, and with ever-improving reliability. Looking ahead, [AI2027](https://ai-2027.com/) predicts that by early 2026, we will see the rise of research-optimised agents capable of accelerating AI innovation itself, producing R&D outcomes faster and more reliably than human teams. This next wave could enable breakthroughs not just in legal and compliance work, but in science, medicine, and engineering.
#
# Enterprise knowledge and analytics agents are also gaining steam. Platforms like [Glean](https://www.glean.com/), which reached $100M ARR by early 2025 and now supports 100 million agent actions annually, are enabling teams to turn internal data into dashboards, graphs, personalized insights, and automated workflows. Similarly, AI assistant startups like [Onyx](https://www.onyx.app/) - which connects across Google Drive, Slack, Salesforce, GitHub, and more - raised a $10M seed round by promising insight-driven enterprise search with lower hallucination rates. And in workflow automation, [n8n](https://n8n.io/) (backed by Felicis, Sequoia, and others) has grown its community to more than 100,000 active users monthly, positioning itself as a backbone for orchestrating multi-agent systems across enterprise stacks.
#
# ‍
#
# **Mapping what’s to come**
#
# As we said earlier, most successful AI agents to date share three qualities:
#
# * Outputs are highly verifiable
# * There is abundant, high-quality training data
# * Tasks are well-defined and bounded
#
# But what happens when we move away from these conditions? To make sense of which have thrived and which have further to go, we mapped agentic use cases across two dimensions:
#
# **X-Axis:** Accessibility of Training Data: volume, quality, structure, and historical labels that show “what good looks like.”
#
# **Y-Axis:** Verifiability of Outcomes: how cheaply and confidently we can score correctness or business impact after each action.
#
# ![](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/68a830f510be3797fbcd770b_AD_4nXf5W8ypcM_wmXdGssleFvPEZYxlMOI5BT9IjzVCYXZ5f0WBPJPI-5lKo7S_BWe1n9v1r81-N5xn5DMlzHVMU2anTHorFhpZGlKQKCUz_iZm5-eDh0qj-eoETJh_J3CMe3HwXL-XoA.webp)
#
# ‍
#
# ![](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/68a830f510be3797fbcd7716_AD_4nXcYF4KE-dvbBexvEW6k3iN5uCDGH2Iweim60FK_g17yCf_uUUIcoXkLL848hNqsyQf_sb2lPKEnLPVYWJwdv-zyT6Xjh0wjYJYKbA-C4DcvNJE_3rICbuhZJKzjc3jea-6FMU_Auw.webp)
#
# Alongside this framework, it’s helpful to see the companies driving real progress. **Below is a market map** of some of the most promising startups building with agentic AI today.
#
# ![](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/68a830f510be3797fbcd7713_AD_4nXc0TiUPXDUkbrdstvzJDOk6nFMSCEVHoT2Sq9P_I90nxE8CfP5nZ52-DKTwKQVgmjfH8HMCV_W2s2q4zG8C--nta2L6yXHP7G5R4O8ZYpb3dUtwq-JFNem3h8_u7c_dXXH6tpTO.webp)
#
# ‍
#
# #### **Agent limitations - looking past the hype**
#
# While momentum is strong, unlocking the next level of agentic performance across all industries will require solving several foundational challenges:
#
# **Lack of human behavioural data**
#
# Agents need a deep understanding of user context, decision-making processes, and nuanced personal preferences -the kinds of cues humans absorb intuitively but that rarely exist in structured data. This information is essential for building agents that can handle open-ended, personalised tasks like scheduling, triaging inboxes, or anticipating intent. Startups like [Perplexity](https://www.perplexity.ai/) and [Strawberry](https://strawberrybrowser.com/) are experimenting with browsers that passively capture ambient signals across workflows, creating a continuous feed of context. Big tech is moving the same way: OpenAI is reportedly working with Sir Jony Ive on a hardware device designed for ambient assistance, and Apple’s recent product updates point toward deeper on-device intelligence that can tap into personal context. Together, these moves signal a coming shift from reactive tools to truly situationally aware agents that live alongside the user.
#
# ‍
#
# **Limited verifiability**
#
# In high-stakes domains like healthcare or finance, we often lack a consistent, objective ground truth. Was a doctor’s diagnosis truly the optimal one, or just the most likely given incomplete information? Did a financial advisor’s recommendation maximise long-term outcomes, or merely align with short-term constraints? Even if human experts agree on an action, we rarely store that judgment in a structured, queryable way, let alone capture the full reasoning chain behind it. Without reliable labelled preference data or clear performance metrics, it becomes nearly impossible to evaluate, reward, or improve an agent’s decision-making. The result: progress stalls, models overfit to proxy metrics, and “success” gets defined by what’s easiest to measure rather than what actually matters. This also applies to broader domains that require a level of subjectivity. For example, how do we consistently decide what the best writing style looks like?
#
# ‍
#
# **Real-world limitations:**
#
# In the bottom-left of our matrix sits embodied AI. Robotics remains limited by the physical world.
#
# Unlike the internet, this data is scarce, environments vary, and verification requires time, sensors, and often human safety protocols. These workflows are evolving, and advances in simulation, sensor tech, and low-cost robotics could unlock new forms of agentic intelligence in physical environments.
#
# ‍
#
# **Trust, hallucinations, and regulation:**
#
# Enterprises need guarantees, not just capabilities. Startups like [Alinia](https://alinia.ai/), [Cala AI](https://www.cala.ai/), and [LatticeFlow](https://latticeflow.ai/) are tackling hallucination mitigation, model alignment, and secure deployment pipelines. In regulated industries, especially, agents must be compliant, traceable, and safe by design. The future here lies in hybrid models that combine automation with human judgment, bridging trust and scale.
#
# ‍
#
# #### **The next frontier**
#
# Agentic AI is not a passing trend - it’s redefining how businesses are built. We’re moving from prompt-based interfaces to truly collaborative, goal-driven systems.
#
# The early success stories show what’s possible when data quality and task clarity intersect. However, unlocking the next generation of AI agents will require deeper changes.
#
# Going forward, we expect several trends to define the second half of 2025 and beyond:
#
# * **Vertical agents will go deeper.** Domain-specific agents will increasingly demonstrate real, measurable ROI by combining LLMs with proprietary knowledge and workflows.
#
# * **Ambient data capture will evolve from an enabler to a category-defining advantage.** The next breakthroughs in personalisation and proactivity will come from systems that learn passively through observation - be it across browser sessions, documents, calendars, or even conversations stored in long-term memory.
#
# * **Agent orchestration frameworks will evolve from novelty to necessity.** The most advanced use cases will rely on teams of agents working in coordination, governed by high-level goals, and connected across the tools enterprises already use. A key enabler here is the rise of interoperability standards like [Anthropic’s Model Context Protocol](https://www.anthropic.com/news/model-context-protocol) (MCP), which allows agents to plug directly into thousands of applications without bespoke integrations. Startups such as [LangChain](https://www.langchain.com/), [CrewAI](https://www.crewai.com/), and [n8n](https://n8n.io/) are already experimenting with frameworks that let multiple agents collaborate and automate end-to-end workflows. As these orchestration layers mature, we’ll move from simple tasks to complex, multi-agent systems that can span entire organisations - bringing both new capabilities and new challenges around reliability, security, and governance
#
# * **Enterprise AI procurement will shift from exploration to platforms.** Rather than experimenting with LLM wrappers, companies will demand robust, modular agent platforms with strong security, observability, and integration standards.
#
# ‍
#
# It’s been an extraordinary year for AI agents. While there’s still plenty to solve, the speed of progress makes it hard to imagine these changes are far off. The real question now is how we choose to shape them: will agents become partners we trust, labour we delegate, or something altogether different?
#
# If you’re a founder building in this space, or an investor looking to dive deeper - get in touch! I’d love to connect.
#
# [## How to manage high-performance individuals in 2025](/articles/how-to-manage-high-performance-individuals-in-2025)
#
# [## Enterprise automation market industry update: automation after GenAI](/articles/enterprise-automation-market-industry-update-automation-after-genai)
#
# [## What we’ve learned from the front lines of AI-enabled services](/articles/what-weve-learned-from-the-front-lines-of-ai-enabled-services)
#
# [## Quantum computing in Europe: lessons from IQM and OpenOcean](/articles/quantum-computing-in-europe-lessons-from-iqm-and-openocean)
#
# ## News from our network
#
# [All news](/news)
#
# [![What founders get wrong about speed and scale](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/6911ebae4954bc6e9d85d50a_Dups%20update.webp)
#
# October 30, 2025
#
# ·
#
# 5
#
# min read
#
# ## What founders get wrong about speed and scale
#
# Every founder faces the same question: how fast should you go? In conversation with our Venture Partner, Duleepa “Dups” Wijayawardhana, we explored why so many startups struggle to balance speed, quality and scale, and how to get it right (at least most of the time). As Dups puts it, for every rule there is an exception, and for every exception there is something to learn.
#
# Duleepa “Dups” Wijayawardhana
#
# Venture Partner](/articles/what-founders-get-wrong-about-speed-and-scale)
#
# [![Quantum computing in Europe: lessons from IQM and OpenOcean](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/6911ebd020883cad9987d738_IQM%20update.webp)
#
# September 29, 2025
#
# ·
#
# 9
#
# min read
#
# ## Quantum computing in Europe: lessons from IQM and OpenOcean
#
# When we met Jan Goetz, Professor Mikko Möttönen and the rest of the IQM founding team in late 2018, we knew we were seeing something rare. The science was hard to grasp, even for my colleague Patrik Backman, who had studied physics and some quantum theory, but the ambition was unmistakable.
#
# Tom Henriksson
#
# General Partner](/articles/quantum-computing-in-europe-lessons-from-iqm-and-openocean)
#
# [![What we’ve learned from the front lines of AI-enabled services](https://cdn.prod.website-files.com/627df74f79858fa879bb51b1/6911ec0fc12fc4cfb341cdf0_Cyrus%20update.webp)
#
# June 23, 2025
#
# ·
#
# 9
#
# min read
#
# ## What we’ve learned from the front lines of AI-enabled services
#
# Last November, we laid out a vision for AI-native services: businesses rebuilt from the ground up to combine the margins of software with the resilience and depth of services markets. Since then, we have taken dozens of first meetings, explored more than 15 verticals, backed our first deals, and sharpened our thesis along the way.](/articles/what-weve-learned-from-the-front-lines-of-ai-enabled-services)
#
# How to scale your business into a European success?
#
# Subscribe to our newsletter
#
# Your submission has been received
#
# Oops! Something went wrong while submitting the form.
#
# [About us](/about)
#
# [Philosophy](/philosophy)
#
# [Portfolio](/portfolio)
#
# [Team](/team)
#
# [News](/news-highlights)
#
# [Contact](/contact)
#
# [Automation Market Map](/market-map)
#
# [ESG Starter Pack](/more/esg-starter-pack)
#
# [Compliance](/more/compliance)
#
# [Submit your pitch](/contact)
#
# [Subscribe to our newsletter](https://eepurl.com/izISMQ)
#
# [Privacy notice](/more/privacy-notice)
#
# The funds are supported by the European Union through the Competitiveness and Innovation Framework Programme (CIP).
#
# © 2022 OpenOcean Oy
#
# © 2022 Open Ocean Ventures Oy
#
# State of the Agentic AI Market Report 2025 | ISG
# Search ISG
#
# No results found
#
# Please enter some search terms
#
# Searching...
#
# * ####
#
# There are {{resultsCount}} results in this search.
# These are the top {{results.length}} results.
# See all results
#
# [Careers](/careers)
# [About Us](/about-us)
#
# [Log In](https://research.isg-one.com/login)
# Search
#
# [ISG](/)
#
# * Sourcing & Advisory
#
#   ### Sourcing & Advisory
#
#   Drive your transformation from a full set of target solutions.
#
#   [Articles](/all-articles)
#
#   [Sourcing](/advisory/sourcing)
#   Powered by [ISG Tango](/advisory/sourcing/isg-tango-sourcing-solution-platform), *The* Sourcing Solution Platform
#
#   [Artificial Intelligence](/advisory/artificial-intelligence-advisory)
#   [Benchmarking](/advisory/benchmarking)
#   [Business Operations](/advisory/business-operations)
#   [Cloud Transformation](/advisory/cloud)
#   [Contact Center](/advisory/contact-center)
#   [Cost Optimization](/advisory/cost-optimization)
#   [Cybersecurity](/advisory/cybersecurity)
#   [Data & Analytics Transformation](/advisory/data-analytics-transformation)
#   [Digital Engineering](/advisory/digital-engineering)
#   [Experience Assessments](/advisory/experience-assessment-center)
#   [Future of Work](/advisory/future-of-work)
#   [Global Capability Center](/advisory/global-capability-center)
#   [HR Technology and Transformation](/advisory/hr-technology-and-transformation)
#   [M&A and Divestiture Services](/advisory/m-a-and-divestiture-services)
#   [Network & Connectivity Services](/advisory/network-advisory-select)
#   [Operating Model](/advisory/operating-model-agile-innovation)
#   [Organizational Change Management](/advisory/organizational-change-management)
#   [SAP](/advisory/sap)
#   [Software](/advisory/software-advisory-services)
#   [Supplier & Contract Management](/advisory/supplier-contract-management)
#   [Training as a Service](/advisory/training-as-a-service)
# * Industries
#
#   ### Industries
#
#   Expertise and solutions tailored to specific industry challenges
#
#   [Articles](/all-articles)
#
#   [Banking & Financial Services](/industries/banking-financial-services)
#   [Chemicals](/industries/chemicals-industry)
#   [Consumer Packaged Goods](/industries/consumer-goods)
#   [Energy & Utilities](/industries/utilities)
#   [Healthcare](/industries/healthcare)
#   [Higher Education](/industries/higher-education)
#   [Insurance](/industries/insurance)
#   [Life Sciences](/industries/life-sciences)
#   [Manufacturing](/industries/manufacturing)
#   [Media, Technology and Communications](/industries/media-entertainment)
#   [Oil & Gas](/industries/oil-and-gas)
#   [Private Equity](/industries/private-equity-and-m-a)
#   [Public Sector](/industries/public-sector)
#   [Retail](/industries/retail)
#   [Travel, Transportation and Hospitality](/industries/travel-and-transportation)
# * Platforms
#
#   ### Platforms
#
#   Deploy our industry-leading data.
#
#   [ISG Governx®
#   SaaS platform to govern all third-party relationships and risk.](/platforms/isg-governx)
#
#   [ISG Inform™
#   Benchmark your entire IT landscape, from cost to service quality and team productivity.](/platforms/isg-inform)
#
#   [ISG ProBenchmark®
#   Leverage the most in-depth price benchmarks for IT services.](/platforms/isg-probenchmark)
#
#   [ISG Executive Insights™
#   An integrated data services platform that empowers you to drive operational excellence and make strategic decisions.](/platforms/isg-executive-insights-for-enterprises)
# * [Research](/research)
# * Events
#
#   ### Events
#
#   ISG’s flagship events fuel learning, sharing and connecting.
#
#   [![ISG Events](https://isg-one.com/images/default-source/resourcepackages/isg2021/svg/icons/event.svg?sfvrsn=be51d931_2)
#
#   ISG Events](/events/events-landing)
#
#   [![Webinars](https://isg-one.com/images/default-source/resourcepackages/isg2021/svg/icons/webinar.svg?sfvrsn=567fd231_2)
#
#   Webinars](/events/webinars)
# * [Articles](/all-articles)
#
# Contact Us
#
# ![AgenticAI Report](/images/default-source/default-album/agenticai-report---background-image_v2.png?sfvrsn=3890a831_2 "AgenticAI Report - Background Image_v2")
#
# 2025 Report
#
# # State of the Agentic AI Market Report
#
# ###### **What your business needs to know about agentic AI now.**
#
# Access in-depth agentic AI market data, learn adoption challenges, how to prepare your organization and how to invest in the right data foundation.
#
# [Download the Report](/advisory/artificial-intelligence-advisory/state-of-the-agentic-ai-market-report-2025#DownloadReport)    [Learn More](/advisory/artificial-intelligence-advisory/state-of-the-agentic-ai-market-report-2025#LearnMore)
#
# ## IT Dominates **Functional Use Cases**
#
# A few horizontal offerings and industry-specific value chains are leading the agentic AI market. Among functional-specific applications of agentic AI, over half are found in IT, while marketing, sales and finance each account for only about 10%. And within IT use cases, DevOps is the number one use case so far.
#
# [Get the Details](/advisory/artificial-intelligence-advisory/state-of-the-generative-ai-market-report-2024#DownloadReport)
#
# ![it dominates functional use cases agentic ai](/images/default-source/default-album/web---it-8.png?sfvrsn=e22ea931_0 "it dominates functional use cases agentic ai")
#
# ![Industry Solutions for agentic ai](/images/default-source/default-album/industry-solutions-1.png?sfvrsn=a42da931_1 "Industry Solutions for agentic ai")
#
# ## Comparing Early Generative & Agentic AI **Industry** **Use Cases**
#
# For providers in our study, 70% of use cases/proofs-of-concept (POCs) in agentic AI came from one of three industries: BFSI, retail or manufacturing. This demonstrates how providers are focusing narrowly, looking for unique intersections of internal capabilities and high ROI potential for their agentic AI investments. This is a difference from early generative AI use cases, wherein providers experimented across nearly all industries.
#
# [Go Deeper](/advisory/artificial-intelligence-advisory/state-of-the-generative-ai-market-report-2024#DownloadReport)
#
# ## In the age of agents, will we need applications?
#
# Agentic AI has the potential to completely change how we access data. In most cases, the value of an app is that it adds context to raw data, a lot of times via black box semantic logic that only exists inside that application. With agents, we could directly access data without the need for an app.
#
# [Get Access to the Full Report](/advisory/artificial-intelligence-advisory/state-of-the-generative-ai-market-report-2024#DownloadReport)
#
# ![Agents Today and Tomorrow - the apps question](/images/default-source/default-album/agents-today-and-tomorrow-1.png?sfvrsn=152ea931_0 "Agents Today and Tomorrow - the apps question")
#
# ## Let's dive in...
#
# ##### Bring your agentic AI questions to the table as you sit down with this report.
#
# Complete the form to download the report.
#
# **Download Report**
#
# ## Meet the authors
#
# #### Loren Absher
#
# Director, Americas Lead – AI Advisory
#
# ## Loren Absher
#
# Loren Absher leads ISG’s AI Advisory practice in the Americas. He helps clients unlock business value from AI by bringing together all the elements required for success: the foundational data enablement strategies that make AI possible, the selection of the right use cases aligned to business priorities, the sourcing strategies that connect enterprises with the right provider ecosystem, and the implementation and adoption frameworks that drive sustained results, ensuring client strategies are consistently translated into outcomes.
#
# [View articles by Loren Absher](/who-we-are/people/loren-absher)
#
# #### Olga Kupriyanova
#
# Principal Consultant, AI & Data Engineering
#
# ## Olga Kupriyanova
#
# In ISG, Olga supports our advisory capability in developing digital solutions with special focus on data and analytics. Olga’s extensive knowledge of analytics and data engineering framework combined with hands on experience in complex transformational projects results in unique insights invaluable for effectively assessing the data analytics solutions for ISG’s clients.
#
# [View articles by Olga Kupriyanova](/who-we-are/people/olga-kupriyanova)
#
# ## Do you have a question, comment or suggestion?
#
# ![Bar](https://isg-stg.sitefinity.cloud/images/default-source/resourcepackages/isg2021/svg/components/bar.svg "Bar")
#
# Contact Us
#
# [ISG](/)
#
# **Company**
#
# * [About Us](/about-us)
# * [Careers](/careers)
# * [Investors](/investors)
# * [Leadership Team](/about-us/leadership-team)
# * [Newsroom](/newsroom)
#
# **ISG**
#
# * [ISG GovernX®](/platforms/isg-governx)
# * [Sourcing](/advisory/sourcing)
# * [Benchmarking](/advisory/benchmarking)
#
# **Helpful Links**
#
# * [Articles](/research/articles)
# * [Connection Center](/connection-center)
# * [Unsubscribe page](/unsubscribe-page)
#
# ---
#
# * [Privacy Policy](/privacy-policy)
# * /
# * [Terms of Use](/terms-of-use)
# * /
# * [Cookie Policy](/cookie-policy)
# * /
# * [Other Policies](/other-policies)
#
# © ISG. 2025 All rights reserved.
#
# When you visit or interact with our sites, services or tools, we or our authorised service providers may use cookies for storing information to help provide you with a better, faster and safer experience and for marketing purposes.
#
# The State of AI: Global Survey 2025
# ...
#
# ### The jagged frontier: Ethan Mollick on AI agents in the workforce
#
# ![](/content/dam/insights/icons/svg/icon-alert.svg)
#
# Ethan Mollick is a professor at the Wharton School of the University of Pennsylvania and author of *Co-Intelligence: Living and Working with AI*. A leading voice on the practical applications of AI in business and education, he is known for his research on how organizations can effectively adopt and integrate AI into their operations.
#
# Q: **What does the transition from AI as a tool to AI as a workforce look like in practice?**
#
# A: Leaders in many organizations aren’t clear on what this means. There tends to be a lot of hand-waving and statements like “AI will do stuff” or “you’ll manage a bunch of agents.” But that doesn’t happen without rethinking and redoing the way organizations operate.
#
# I find it’s not actually a technology problem. It’s a process problem. It means you have to understand the jagged frontier. AI has gotten very good at math and coding, which has an obvious impact on math and coding tasks, but also a less apparent impact on tasks like analysis or meeting with people. Workers will have to adjust their time in their jobs to do different things. It’s not that AI agents do everything; they do the basic grunt work, so I can call more organizations to interview them instead. Leaders have to be able to articulate that future.
#
# **Q: What do organizations need to consider in terms of agent-first process redesign?**
#
# A:You need three things to do AI work: leadership, lab, and crowd. First, you need the crowd: everyone in the organization using these systems. Second, you need the lab, which is actively doing 24/7 experimentation, taking ideas from the crowd, and turning them into real products. And finally, you need aligned leadership. Leaders have to think about organizational design. For example, if you can code 10 times or 100 times faster than you did before, are you still doing Agile development? Agile doesn’t work at that speed, so you don’t need to be doing it.
#
# **Q: What workforce skills are the most important?**
#
# A: There’s a “using AI” skill that we don't exactly know how to measure or train for yet. It probably involves agency and willingness to experiment, being incentivized properly, and being a subject matter expert in your field.
#
# **Q: When do you expect agents to take over operations?**
#
# A:I don’t know, but agents are already better than people think. True agents are already here. You’re just not using them. And you have to build them. But it’s doable today. There’s no future timeframe. Because you absolutely can build economically valuable agents right now with current technology, and companies are building agentic workflows that do a lot of work autonomously at high accuracy levels. Do they replace all work yet? No, nor do I want them to. But if you're waiting until the technology is more mature, you're going to be in trouble because it’s already there.[22](#endnote-22)
#
# Show more
#
# ###
#
# ### by
#
# #### Jim Rowan
#
# United States
#
# ### Jim Rowan
#
# Head of AI | Principal | Deloitte Consulting LLP
#
# United States
#
# Jim Rowan is the US head of AI at Deloitte and collaborates with external technology organizations, clients, and Deloitte’s business leaders to help our clients achieve their AI ambitions. Beyond his client work, Rowan is a principal in Deloitte Consulting LLP. His experience spans the life sciences, health care, and telecommunications industries, with a strong focus on applying analytics, planning, forecasting, and digital transformation to enhance finance functions.
#
# *jimrowan@deloitte.com*
#
# *+1 617 437 3470*
#
# #### Nitin Mittal
#
# United States
#
# ### Nitin Mittal
#
# Global AI leader | Principal | Deloitte Consulting LLP
#
# United States
#
# Nitin Mittal is a principal at Deloitte and leads Deloitte’s global AI program. He advises organizations on AI applications and the implications of emerging technologies on the strategy and competitive positioning of businesses. At Deloitte, Mittal is responsible for shaping the AI market and creating new business opportunities by harnessing emerging technologies. He is also leading Deloitte’s own effort to be a global AI-fueled organization and transform how they deliver professional services.
#
# *nmittal@deloitte.com*
#
# *+1 617 831 4128*
#
# #### Parth Patwari
#
# United States
#
# ### Parth Patwari
#
# Principal | Offering leader, AI and data | Deloitte Consulting LLP
#
# United States
#
# Parth Patwari leads Deloitte’s AI and data practice across all industries in the United States. He has extensive experience working with capital markets and payments institutions to architect, design, and implement large-scale systems that support mission-critical customer, finance, risk, regulatory, and compliance functions. Patwari drives efficiency agendas using AI, analytics, and data management capabilities.
#
# *ppatwari@deloitte.com*
#
# *+1 703 251 1650*
#
# #### Ed Burns
#
# United States
#
# ### Ed Burns
#
# Manager | Office of the CTO | Deloitte Consulting LLP
#
# United States
#
# Ed Burns leads the client stories initiative within the Office of the CTO known as Trend Lines. This project serves as a key research input to Tech Trends and other eminence. Prior to his current role, he led a tech news publication that covered all things AI, analytics, and data management.
#
# *edburns@deloitte.com*
#
# *+16174372486*
#
# * Share
#   + linkedin
#   + twitter
#   + facebook
# * Print
#
# ### Endnotes
#
# 1. The Henry Ford, “[Henry Ford quotations](https://www.thehenryford.org/collections-and-research/digital-resources/popular-topics/henry-ford-quotes),” accessed Nov. 6, 2025.
# 2. Gartner, Inc., “[Gartner predicts over 40% of agentic AI projects will be canceled by end of 2027](https://www.gartner.com/en/newsroom/press-releases/2025-06-25-gartner-predicts-over-40-percent-of-agentic-ai-projects-will-be-canceled-by-end-of-2027?utm_source=chatgpt.com),” press release, June 25, 2025.
# 3. 2025 Deloitte Emerging Technology Trends in the Enterprise Survey, publication in process.
# 4. Gartner, Inc., “[Gartner predicts over 40% of agentic AI projects will be canceled by end of 2027](https://www.gartner.com/en/newsroom/press-releases/2025-06-25-gartner-predicts-over-40-percent-of-agentic-ai-projects-will-be-canceled-by-end-of-2027?utm_source=chatgpt.com).”
# 5. 2025 Tech Value Survey by Deloitte Center for Integrated Research, fielded June 2025.
# 6. Gartner, Inc., “[Gartner predicts over 40% of agentic AI projects will be canceled by end of 2027](https://www.gartner.com/en/newsroom/press-releases/2025-06-25-gartner-predicts-over-40-percent-of-agentic-ai-projects-will-be-canceled-by-end-of-2027?utm_source=chatgpt.com).”
# 7. Bruce Gil, “‘[Workslop’: AI-generated work content is slowing everything down](https://gizmodo.com/workslop-ai-generated-work-content-is-slowing-everything-down-2000662646),” Gizmodo, Sept. 23, 2025.
# 8. Deloitte On Cloud podcast interview with Brent Collins, vice president of AI strategy, Intel, Aug. 27, 2025 <https://www.deloitte.com/us/en/what-we-do/capabilities/cloud-transformation/collections/cloud-podcast.html>.
# 9. Marie Myers (executive vice president and chief financial officer, HPE), interview with Deloitte, March 1, 2025.
# 10. John Roese (chief technology officer and chief AI officer, Dell Technologies), interview with Deloitte, Sept. 29, 2025.
# 11. Maribel Solanas Gonzalez (group chief data officer, Mapfre Insurance), interview with Deloitte, June 18, 2024.
# 12. "Reimagining operations with agentic AI at Toyota,” **Deloitte Insights**, Dec. 3, 2025.
# 13. Tracey Franklin (chief people and digital technology officer, Moderna), interview with Deloitte, Sept. 26, 2025.
# 14. Aditya Challapally, Chris Pease, Ramesh Raskar, and Pradyumna Chari, “[**The gen AI divide: State of AI in business 2025**](https://mlq.ai/media/quarterly_decks/v0.1_State_of_AI_in_Business_2025_Report.pdf),” July 2025.
# 15. Anthropic, PBC, “[**Introducing the model context protocol**](https://www.anthropic.com/news/model-context-protocol?utm_source=chatgpt.com),” Nov. 25, 2024.
# 16. Rao Surapaneni, Miku Jha, Michael Vakoc, and Todd Segal, “[**Announcing the Agent2Agent Protocol (A2A)**](https://developers.googleblog.com/en/a2a-a-new-era-of-agent-interoperability/),” Google for Developers, April 9, 2025.
# 17. AgentCommunicationProtocol.dev, “[**Welcome**](https://agentcommunicationprotocol.dev/introduction/welcome),” accessed Nov. 6, 2025.
# 18. Saad Merchant, “[**ACP: Future of offline AI agent collaboration**](https://www.alumio.com/blog/acp-agent-communication-protocol-ai-standard?utm_source=chatgpt.com),” Alumio, Oct. 24, 2025.
# 19. Kearney, “[**FinOps for AI and AI for FinOps**](https://www.kearney.com/service/digital-analytics/article/finops-for-ai-and-ai-for-finops?utm_source=chatgpt.com),” Jan. 28, 2025.
# 20. Jake Latimer, “[**Will AI be taxed? The debate over AI-powered businesses: The 2025 tech-tax tussle**](https://medium.com/%40jakemlatimer/will-ai-be-taxed-the-debate-over-ai-powered-businesses-the-2025-tech-tax-tussle-721d748098a8),” *Medium*, March 13, 2025.
# 21. Ken Huang, “[**Agentic AI identity management approach**](https://www.cloudsecurityalliance.org/blog/2025/03/11/agentic-ai-identity-management-approach),” Cloud Security Alliance, March 11, 2025.
# 22. Ethan Mollick (professor, Wharton School of the University of Pennsylvania), Deloitte interview, Jan. 1, 2025.
#
# COPY
#
# ##### ENDNOTE
#
# COPY
#
# ### Acknowledgments
#
# ![](/content/dam/insights/icons/svg/icon-alert.svg)
#
# The authors would like to thank executive sponsor **Bill Briggs**, as well as the Office of the CTO Tech Market Presence team, without whom this report would not be possible: **Caroline Brown**, **Preetha Devan**, **Bri Henley**, **Dana Kublin**, **Makarand Kukade**, **Haley Gove Lamb**, **Heidi Morrow**, **Sarah Mortier**, **Abria Perry**, **Catarina Pires**,and **Kelly Raskovich**.
#
# Much gratitude goes to the many subject matter leaders across Deloitte who contributed to our research for the Information chapter: **Jinlei Liu**, **Baris Sarer**, **Kate Fusillo Schmidt**, **Prakul Sharma**, **Akash Tayal**,and **Ashish Verma**.
#
# Additionally, the authors would like to acknowledge and thank **Katarina Alaupovic**, **Allison Cizowski**, **Deanna Gorecki**, **Ben Hebbe**, **Mikaeli Robinson**, and **Madelyn Scott**; **Amanpreet Arora** and **Nidhi John**;as well as the *Deloitte Insights* team, the Marketing Excellence team, the NExT team, and the Knowledge Services team.
#
# Cover image by: **Jim Slatton**; Getty Images, Adobe Stock
#
# ### Copyright
#
# Copyright © 2025 Deloitte Development LLC. All rights reserved.
# Member of Deloitte Touche Tohmatsu Limited
#
# ### Related content
#
# [### Reimagining operations with agentic AI at Toyota
#
# Agentic AI isn’t enough. Toyota’s Jason Ballard shares how process redesign and people are key to driving competitive advantage in their transformation.
#
# Article
#
#  •
#
# 4-min read](/us/en/insights/topics/technology-management/tech-trends/2025/toyota-digital-transformation-ai.html)
#
# [### TMT Predictions 2026: The AI gap narrows but persists
#
# Deloitte predicts 2026 will see the gap between the promise and reality of AI narrow, as further movements towards getting it to scale are made
#
# Article
#
#  •
#
# 9-min read](/us/en/insights/industry/technology/technology-media-and-telecom-predictions.html)
#
# [### Agentic AI is set to change how business gets done
#
# Tech leaders at ServiceNow anticipate that AI bots and other tools will cause a fundamental shift in work—from automating training to developing new offerings
#
# Article
#
#  •
#
# 3-min read](/us/en/insights/topics/technology-management/tech-trends/2025/servicenow-and-agentic-ai-set-to-change-how-business-gets-done.html)
#
# ![](/content/dam/insights/icons/svg/icon-alert.svg)
#
# Deloitte Insights and our research centers deliver proprietary research designed to help organizations turn their aspirations into action.
#
# #### DELOITTE INSIGHTS
#
# * [Home](/us/en/insights.html?icid=dibottom_insights)
# * [Deloitte Insights Magazine](/us/en/insights/deloitte-insights-magazine.html?icid=dibottom_deloitte-insights-magazine)
# * [Top 10 Reading Guide](/us/en/insights/top-10-business-insights.html?icid=dibottom_top-10-business-insights)
# * [Weekly Global Economic Outlook](/us/en/insights/topics/economy/global-economic-outlook/weekly-update.html?icid=dibottom_weekly-update)
# * [About Deloitte Insights](/us/en/insights/about/about-deloitte-insights.html?icid=dibottom_about-deloitte-insights)
#
# #### DELOITTE RESEARCH CENTERS
#
# * [Cross-Industry](/us/en/insights/research-centers/center-for-integrated-research.html?icid=dibottom_center-for-integrated-research)
# * [Economics](/us/en/insights/research-centers/economics.html?icid=dibottom_economics)
# * [Consumer](/us/en/insights/research-centers/consumer-industry-center.html?icid=dibottom_consumer-industry-center)
# * [Energy & Industrials](/us/en/insights/research-centers/center-energy-industrials.html?icid=dibottom_center-energy-industrials)
# * [Financial Services](/us/en/insights/research-centers/center-for-financial-services.html?icid=dibottom_center-for-financial-services)
# * [Government & Public Services](/us/en/insights/research-centers/center-for-government-insights.html?icid=dibottom_center-for-government-insights)
# * [Life Sciences & Health Care](/us/en/insights/research-centers/center-for-health-solutions.html?icid=dibottom_center-for-health-solutions)
# * [Tech, Media & Telecom](/us/en/insights/research-centers/center-for-technology-media-telecommunications.html?icid=dibottom_center-for-technology-media-telecommunications)
#
# [![Deloitte logo](/content/dam/insights/icons/svg/DEL_SEC_RGB_70x15.png "DELOITTE")](/us/en.html)
#
# ![](/content/dam/insights/icons/svg/icon-alert.svg)
#
# Learn about Deloitte’s offerings, people, and culture as a global provider of audit, assurance, consulting, financial advisory, risk advisory, tax, and related services.
#
# © 2025. See [Terms of Use](https://www2.deloitte.com/us/en/legal/legal.html) for more information.
#
# Deloitte refers to one or more of Deloitte Touche Tohmatsu Limited, a UK private company limited by guarantee ("DTTL"), its network of member firms, and their related entities. DTTL and each of its member firms are legally separate and independent entities. DTTL (also referred to as "Deloitte Global") does not provide services to clients. In the United States, Deloitte refers to one or more of the US member firms of DTTL, their related entities that operate using the "Deloitte" name in the United States and their respective affiliates. Certain services may not be available to attest clients under the rules and regulations of public accounting. Please see [www.deloitte.com/about](https://www.deloitte.com/us/en/about/governance/network-brand-alliances/about-the-network.html) to learn more about our global network of member firms.
#
# * [Terms of Use](/us/en/legal/legal.html?icid=dibottom_legal)
# * [Privacy](/us/en/legal/privacy/privacy-index.html?icid=dibottom_privacy-index)
# * [Data Privacy Framework](/us/en/legal/privacy/data-privacy-framework.html?icid=dibottom_data-privacy-framework)
# * [Cookie Notice](https://cookienotice.deloitte.com/?icid=dibottom_https://cookienotice.deloitte.com/)
# * [Cookie Settings](#?icid=dibottom_#)
# * [Legal Information for Job Seekers](/us/en/legal/join-deloitte-legal-information-for-job-seekers.html?icid=dibottom_join-deloitte-legal-information-for-job-seekers)
# * [Labor Condition Applications](/us/en/about/content/labor-condition-applications.html?icid=dibottom_labor-condition-applications)
# * [Do Not Sell or Share My Personal Information](/us/en/legal/privacy/do-not-sell-my-personal-information.html?icid=dibottom_do-not-sell-my-personal-information)
#
# Please enable JavaScript to view the site.
#
# ![](https://px.ads.linkedin.com/collect/?pid=5930770&fmt=gif)
