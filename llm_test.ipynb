# %% [markdown]
# ## Groq model from Langchain Groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
response = llm.invoke("What's the capital of Italy?")

# %%
response
# Out:
# AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.006964273, 'completion_tokens_details': None, 'prompt_time': 0.002099471, 'prompt_tokens_details': None, 'queue_time': 0.051281009, 'total_time': 0.009063744}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c14bf-4a62-77d3-89a0-62eee2338a42-0', usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50})

# %%
response.content
# Out:
# 'The capital of Italy is Rome.'

# %%
x = dict(response)
x.keys()
# Out:
# dict_keys(['content', 'additional_kwargs', 'response_metadata', 'type', 'name', 'id', 'tool_calls', 'invalid_tool_calls', 'usage_metadata'])

# %% [markdown]
# ## Gemini model from [Google](https://aistudio.google.com/)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
response = llm.invoke("What's the capital of Italy?")

# %%
response
# Out:
# AIMessage(content='The capital of Italy is **Rome**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bd001-724c-78b0-aa98-873d35cf4de8-0', usage_metadata={'input_tokens': 9, 'output_tokens': 33, 'total_tokens': 42, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 25}})

# %%
response.content
# Out:
# 'The capital of Italy is **Rome**.'

# %%
from IPython.display import display, Markdown
display(Markdown(response.content))
# Out:
# The capital of Italy is **Rome**.

# %%
x = dict(response)
x.keys()
# Out:
# dict_keys(['content', 'additional_kwargs', 'response_metadata', 'type', 'name', 'id', 'tool_calls', 'invalid_tool_calls', 'usage_metadata'])
